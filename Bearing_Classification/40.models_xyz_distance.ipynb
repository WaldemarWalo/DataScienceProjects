# %% [markdown]
# # Setup and Imports

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

from sklearn.preprocessing import StandardScaler, PowerTransformer

# %%
(X, y) = t.from_pkl(f'{processed_data_path}/all_b1_b2_xyz_distance.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 72)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__p01', 'x__p10', 'x__p20', 'x__p30', 'x__p99', 'x__p90',
#        'x__p80', 'x__p70', 'x__iqr', 'x__kurtosis', 'x__skew', 'y__amin',
#        'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std', 'y__var',
#        'y__p01', 'y__p10', 'y__p20', 'y__p30', 'y__p99', 'y__p90', 'y__p80',
#        'y__p70', 'y__iqr', 'y__kurtosis', 'y__skew', 'z__amin', 'z__amax',
#        'z__sum', 'z__median', 'z__mean', 'z__std', 'z__var', 'z__p01',
#        'z__p10', 'z__p20', 'z__p30', 'z__p99', 'z__p90', 'z__p80', 'z__p70',
#        'z__iqr', 'z__kurtosis', 'z__skew', 'xyz__amin', 'xyz__amax',
#        'xyz__sum', 'xyz__median', 'xyz__mean', 'xyz__std', 'xyz__var',
#        'xyz__p01', 'xyz__p10', 'xyz__p20', 'xyz__p30', 'xyz__p99', 'xyz__p90',
#        'xyz__p80', 'xyz__p70', 'xyz__iqr', 'xyz__kurtosis', 'xyz__skew'],
#       dtype='object')
# (200,)
# 0    100
# 1    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

from sklearn.metrics import roc_auc_score, log_loss

from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# # First Run

# %%
n_est_list = [100, 200, 400]
models_and_params = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5)
metrics = [ roc_auc_score, log_loss ]

_ = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)
# Out:
# <style type="text/css">
# #T_a17a8_row0_col3, #T_a17a8_row3_col7, #T_a17a8_row12_col6, #T_a17a8_row16_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_a17a8_row0_col4, #T_a17a8_row1_col6, #T_a17a8_row1_col7, #T_a17a8_row7_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_a17a8_row0_col5, #T_a17a8_row12_col8 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_a17a8_row0_col6, #T_a17a8_row0_col7, #T_a17a8_row1_col4, #T_a17a8_row15_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a17a8_row0_col8, #T_a17a8_row15_col5 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a17a8_row0_col9, #T_a17a8_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_a17a8_row1_col3, #T_a17a8_row2_col7, #T_a17a8_row11_col6, #T_a17a8_row15_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_a17a8_row1_col5, #T_a17a8_row11_col8 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_a17a8_row1_col8, #T_a17a8_row7_col5 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_a17a8_row2_col3, #T_a17a8_row11_col4, #T_a17a8_row12_col4, #T_a17a8_row13_col4, #T_a17a8_row15_col6, #T_a17a8_row15_col7 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_a17a8_row2_col4, #T_a17a8_row5_col6, #T_a17a8_row8_col7, #T_a17a8_row16_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_a17a8_row2_col5, #T_a17a8_row15_col8 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_a17a8_row2_col6, #T_a17a8_row6_col4, #T_a17a8_row7_col7, #T_a17a8_row14_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_a17a8_row2_col8, #T_a17a8_row14_col5 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_a17a8_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.6%, transparent 7.6%);
# }
# #T_a17a8_row3_col3, #T_a17a8_row14_col7, #T_a17a8_row16_col6 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_a17a8_row3_col4, #T_a17a8_row3_col6, #T_a17a8_row8_col3, #T_a17a8_row11_col7 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_a17a8_row3_col5, #T_a17a8_row16_col8 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_a17a8_row3_col8, #T_a17a8_row8_col5 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_a17a8_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.3%, transparent 16.3%);
# }
# #T_a17a8_row4_col3, #T_a17a8_row4_col7, #T_a17a8_row13_col6, #T_a17a8_row14_col4 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_a17a8_row4_col4, #T_a17a8_row6_col6, #T_a17a8_row9_col3, #T_a17a8_row9_col7 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_a17a8_row4_col5, #T_a17a8_row13_col8 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_a17a8_row4_col6, #T_a17a8_row6_col3, #T_a17a8_row8_col4, #T_a17a8_row13_col7 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_a17a8_row4_col8, #T_a17a8_row6_col5 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_a17a8_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.5%, transparent 31.5%);
# }
# #T_a17a8_row5_col3, #T_a17a8_row14_col6, #T_a17a8_row16_col7 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_a17a8_row5_col4, #T_a17a8_row7_col6, #T_a17a8_row10_col3, #T_a17a8_row10_col7 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a17a8_row5_col5, #T_a17a8_row14_col8 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_a17a8_row5_col7, #T_a17a8_row7_col4, #T_a17a8_row8_col6 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_a17a8_row5_col8, #T_a17a8_row16_col5 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_a17a8_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.8%, transparent 9.8%);
# }
# #T_a17a8_row6_col7, #T_a17a8_row9_col6, #T_a17a8_row10_col4, #T_a17a8_row11_col3, #T_a17a8_row12_col3, #T_a17a8_row13_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_a17a8_row6_col8, #T_a17a8_row9_col5 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_a17a8_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.6%, transparent 18.6%);
# }
# #T_a17a8_row7_col8, #T_a17a8_row10_col5 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_a17a8_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.3%, transparent 37.3%);
# }
# #T_a17a8_row8_col8 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_a17a8_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_a17a8_row9_col4, #T_a17a8_row10_col6, #T_a17a8_row12_col7 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_a17a8_row9_col8, #T_a17a8_row11_col5, #T_a17a8_row12_col5, #T_a17a8_row13_col5 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_a17a8_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.3%, transparent 2.3%);
# }
# #T_a17a8_row10_col8 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_a17a8_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.2%, transparent 3.2%);
# }
# #T_a17a8_row11_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.1%, transparent 12.1%);
# }
# #T_a17a8_row12_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.8%, transparent 21.8%);
# }
# #T_a17a8_row13_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.2%, transparent 42.2%);
# }
# #T_a17a8_row14_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.8%, transparent 26.8%);
# }
# #T_a17a8_row15_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.8%, transparent 51.8%);
# }
# #T_a17a8_row16_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_a17a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a17a8_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_a17a8_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_a17a8_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_a17a8_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_a17a8_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_a17a8_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_a17a8_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_a17a8_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_a17a8_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_a17a8_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a17a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a17a8_row0_col0" class="data row0 col0" >DecisionTreeClassifier</td>
#       <td id="T_a17a8_row0_col1" class="data row0 col1" ></td>
#       <td id="T_a17a8_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_a17a8_row0_col3" class="data row0 col3" >0.965</td>
#       <td id="T_a17a8_row0_col4" class="data row0 col4" >0.032</td>
#       <td id="T_a17a8_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_a17a8_row0_col6" class="data row0 col6" >1.21</td>
#       <td id="T_a17a8_row0_col7" class="data row0 col7" >1.09</td>
#       <td id="T_a17a8_row0_col8" class="data row0 col8" >17</td>
#       <td id="T_a17a8_row0_col9" class="data row0 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_a17a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a17a8_row1_col0" class="data row1 col0" >KNeighborsClassifier</td>
#       <td id="T_a17a8_row1_col1" class="data row1 col1" ></td>
#       <td id="T_a17a8_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_a17a8_row1_col3" class="data row1 col3" >0.942</td>
#       <td id="T_a17a8_row1_col4" class="data row1 col4" >0.037</td>
#       <td id="T_a17a8_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_a17a8_row1_col6" class="data row1 col6" >1.18</td>
#       <td id="T_a17a8_row1_col7" class="data row1 col7" >0.94</td>
#       <td id="T_a17a8_row1_col8" class="data row1 col8" >16</td>
#       <td id=

# %% [markdown]
# # Shortlisted Best 3

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_1472f_row0_col3, #T_1472f_row0_col6 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_1472f_row0_col4, #T_1472f_row1_col7 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_1472f_row0_col5, #T_1472f_row0_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_1472f_row0_col7 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_1472f_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.1%, transparent 18.1%);
# }
# #T_1472f_row1_col3, #T_1472f_row1_col6, #T_1472f_row2_col4, #T_1472f_row2_col7, #T_1472f_row3_col4, #T_1472f_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1472f_row1_col4, #T_1472f_row4_col7 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_1472f_row1_col5, #T_1472f_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_1472f_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.3%, transparent 36.3%);
# }
# #T_1472f_row2_col3, #T_1472f_row3_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_1472f_row2_col5, #T_1472f_row3_col5, #T_1472f_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_1472f_row2_col6, #T_1472f_row3_col6, #T_1472f_row4_col3, #T_1472f_row5_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_1472f_row2_col8, #T_1472f_row3_col8, #T_1472f_row4_col5, #T_1472f_row5_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_1472f_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.0%, transparent 1.0%);
# }
# #T_1472f_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_1472f_row4_col4, #T_1472f_row5_col4 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_1472f_row4_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_1472f_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_1472f_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 45.9%, transparent 45.9%);
# }
# #T_1472f_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_1472f_row5_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_1472f_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_1472f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1472f_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_1472f_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_1472f_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_1472f_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_1472f_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_1472f_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_1472f_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_1472f_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_1472f_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_1472f_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1472f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1472f_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_1472f_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_1472f_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_1472f_row0_col3" class="data row0 col3" >0.996</td>
#       <td id="T_1472f_row0_col4" class="data row0 col4" >0.008</td>
#       <td id="T_1472f_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_1472f_row0_col6" class="data row0 col6" >0.340</td>
#       <td id="T_1472f_row0_col7" class="data row0 col7" >0.098</td>
#       <td id="T_1472f_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_1472f_row0_col9" class="data row0 col9" >15.2</td>
#     </tr>
#     <tr>
#       <th id="T_1472f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1472f_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_1472f_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_1472f_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_1472f_row1_col3" class="data row1 col3" >0.996</td>
#       <td id="T_1472f_row1_col4" class="data row1 col4" >0.005</td>
#       <td id="T_1472f_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_1472f_row1_col6" class="data row1 col6" >0.343</td>
#       <td id="T_1472f_row1_col7" class="data row1 col7" >0.102</td>
#       <td id="T_1472f_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_1472f_row1_col9" class="data row1 col9" >30.4</td>
#     </tr>
#     <tr>
#       <th id="T_1472f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1472f_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_1472f_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_1472f_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_1472f_row2_col3" class="data row2 col3" >0.994</td>
#       <td id="T_1472f_row2_col4" class="data row2 col4" >0.011</td>
#       <td id="T_1472f_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_1472f_row2_col6" class="data row2 col6" >0.148</td>
#       <td id="T_1472f_row2_col7" class="data row2 col7" >0.157</td>
#       <td id="T_1472f_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_1472f_row2_col9" class="data row2 col9" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_1472f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1472f_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_1472f_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_1472f_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_1472f_row3_col3" class="data row3 col3" >0.994</td>
#       <td id="T_1472f_row3_col4" class="data row3 col4" >0.011</td>
#       <td id="T_1472f_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_1472f_row3_col6" class="data row3 col6" >0.148</td>
#       <td id="T_1472f_row3_col7" class="data row3 col7" >0.157</td>
#       <td id="T_1472f_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_1472f_row3_col9" class="data row3 col9" >1.1</td>
#     </tr>
#     <tr>
#       <th id="T_1472f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1472f_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_1472f_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_1472f_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_1472f_row4_col3" class="data row4 col3" >0.994</td>
#       <td id="T_1472f_row4_col4" class="data row4 col4" >0.007</td>
#       <td id="T_1472f_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_1472f_row4_col6" class="data row4 col6" >0.109</td>
#       <td id="T_1472f_row4_col7" class="data row4 col7" >0.045</td>
#       <td id="T_1472f_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_1472f_row4_col9" class="data row4 col9" >38.5</td>
#     </tr>
#     <tr>
#       <th id="T_1472f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1472f_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_1472f_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_1472f_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_1472f_row5_col3" class="data row5 col3" >0.994</td>
#       <td id="T_1472f_row5_col4" class="data row5 col4" >0.007</td>
#       <td id="T_1472f_row5_col5" class="data row5 col5" >3</td>
#       <td id="T_1472f_row5_col6" class="data row5 col6" >0.107</td>
#       <td id="T_1472f_row5_col7" class="data row5 col7" >0.046</td>
#       <td id="T_1472f_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_1472f_row5_col9" class="data row5 col9" >83.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_fe_df(list_of_list_of_models):
    df_all_fe = []
    
    for i, models_to_analyse in enumerate(list_of_list_of_models):
        feature_imp_for_model = []

        for j, m in enumerate(models_to_analyse[:3]):
            model_short_name = ''.join([l for l in m.__class__.__name__ if l.isupper()])

            if hasattr(m, 'feature_names_in_'):
                feature_names = m.feature_names_in_
            elif hasattr(m, 'feature_name_'):
                feature_names = m.feature_name_
            else:
                feature_names = m.feature_names_

            feature_imp_for_model.append(
                pd.Series(index = feature_names, data = m.feature_importances_, name=f'{model_short_name}_{i}_{j}')
            )

        df_f_imp = pd.concat(feature_imp_for_model, axis=1)
        df_f_imp[f'{model_short_name}_{i}_sum'] = df_f_imp.sum(axis=1)
        df_f_imp[f'{model_short_name}_{i}_rank'] = df_f_imp[f'{model_short_name}_{i}_sum'].rank().astype(int)

        # df_f_imp.sort_values(by=[f'{model_short_name}_sum'], ascending = False)
        df_all_fe.append(df_f_imp)

        df_final_fe = pd.concat(df_all_fe, axis=1)
        
        sum_cols = [col for col in df_final_fe.columns if col.endswith('_sum')]
    df_final_fe['sum'] = df_final_fe[sum_cols].sum(axis=1)
    df_final_fe = df_final_fe.sort_values(by='sum', ascending=False)


    rank_cols = [col for col in df_final_fe.columns if col.endswith('_rank')]
    styler = df_final_fe.style
    styler.background_gradient(subset=rank_cols, cmap=plt.cm.Oranges, vmin=-5)
    return styler

# %%
df_final_fe = get_fe_df(all_trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_36bb5_row0_col4, #T_36bb5_row0_col9, #T_36bb5_row0_col14, #T_36bb5_row0_col19, #T_36bb5_row0_col24, #T_36bb5_row0_col29 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_36bb5_row1_col4, #T_36bb5_row1_col9, #T_36bb5_row3_col29, #T_36bb5_row6_col14, #T_36bb5_row6_col19, #T_36bb5_row27_col24 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_36bb5_row1_col14, #T_36bb5_row1_col19, #T_36bb5_row4_col24, #T_36bb5_row4_col29, #T_36bb5_row17_col4, #T_36bb5_row17_col9 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_36bb5_row1_col24, #T_36bb5_row1_col29, #T_36bb5_row2_col14, #T_36bb5_row2_col19, #T_36bb5_row4_col4 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_36bb5_row2_col4, #T_36bb5_row2_col9, #T_36bb5_row8_col14, #T_36bb5_row8_col19, #T_36bb5_row9_col24, #T_36bb5_row9_col29, #T_36bb5_row49_col4 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_36bb5_row2_col24, #T_36bb5_row2_col29, #T_36bb5_row3_col14, #T_36bb5_row3_col19, #T_36bb5_row4_col9, #T_36bb5_row5_col9, #T_36bb5_row6_col4 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_36bb5_row3_col4, #T_36bb5_row15_col14, #T_36bb5_row15_col19, #T_36bb5_row16_col14, #T_36bb5_row16_col19, #T_36bb5_row21_col24, #T_36bb5_row21_col29, #T_36bb5_row41_col9 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_36bb5_row3_col9, #T_36bb5_row29_col24, #T_36bb5_row29_col29 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_36bb5_row3_col24, #T_36bb5_row5_col4, #T_36bb5_row5_col14, #T_36bb5_row5_col19, #T_36bb5_row6_col9, #T_36bb5_row14_col29 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_36bb5_row4_col14, #T_36bb5_row4_col19, #T_36bb5_row8_col4, #T_36bb5_row8_col9, #T_36bb5_row17_col24, #T_36bb5_row17_col29 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_36bb5_row5_col24, #T_36bb5_row27_col9, #T_36bb5_row31_col29, #T_36bb5_row41_col4 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_36bb5_row5_col29, #T_36bb5_row13_col14, #T_36bb5_row13_col19, #T_36bb5_row26_col9, #T_36bb5_row29_col4, #T_36bb5_row31_col24 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_36bb5_row6_col24, #T_36bb5_row6_col29, #T_36bb5_row9_col9, #T_36bb5_row11_col14, #T_36bb5_row11_col19, #T_36bb5_row26_col4 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_36bb5_row7_col4, #T_36bb5_row7_col9, #T_36bb5_row30_col4, #T_36bb5_row50_col24, #T_36bb5_row50_col29, #T_36bb5_row55_col4, #T_36bb5_row63_col4 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_36bb5_row7_col14, #T_36bb5_row7_col19, #T_36bb5_row14_col24, #T_36bb5_row27_col29, #T_36bb5_row49_col9 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_36bb5_row7_col24, #T_36bb5_row21_col14, #T_36bb5_row21_col19, #T_36bb5_row23_col29, #T_36bb5_row50_col4 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_36bb5_row7_col29, #T_36bb5_row44_col24 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_36bb5_row8_col24, #T_36bb5_row8_col29, #T_36bb5_row11_col4, #T_36bb5_row11_col9, #T_36bb5_row36_col14, #T_36bb5_row36_col19 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_36bb5_row9_col4, #T_36bb5_row10_col14, #T_36bb5_row10_col19, #T_36bb5_row18_col24, #T_36bb5_row18_col29, #T_36bb5_row38_col9 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_36bb5_row9_col14, #T_36bb5_row9_col19, #T_36bb5_row12_col24, #T_36bb5_row12_col29, #T_36bb5_row14_col4, #T_36bb5_row14_col9 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_36bb5_row10_col4, #T_36bb5_row10_col9, #T_36bb5_row17_col14, #T_36bb5_row17_col19, #T_36bb5_row19_col9, #T_36bb5_row38_col29, #T_36bb5_row41_col24 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_36bb5_row10_col24, #T_36bb5_row31_col9, #T_36bb5_row37_col29, #T_36bb5_row64_col9 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_36bb5_row10_col29, #T_36bb5_row48_col4, #T_36bb5_row48_col9, #T_36bb5_row70_col24 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_36bb5_row11_col24, #T_36bb5_row20_col29, #T_36bb5_row58_col9 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_36bb5_row11_col29, #T_36bb5_row23_col9, #T_36bb5_row24_col14, #T_36bb5_row24_col19, #T_36bb5_row28_col24, #T_36bb5_row37_col4 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_36bb5_row12_col4, #T_36bb5_row12_col9, #T_36bb5_row18_col14, #T_36bb5_row18_col19, #T_36bb5_row19_col14, #T_36bb5_row19_col19, #T_36bb5_row38_col4, #T_36bb5_row38_col24, #T_36bb5_row49_col29 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_36bb5_row12_col14, #T_36bb5_row12_col19, #T_36bb5_row19_col24, #T_36bb5_row27_col4, #T_36bb5_row29_col9, #T_36bb5_row30_col29 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_36bb5_row13_col4, #T_36bb5_row13_col24, #T_36bb5_row49_col14, #T_36bb5_row49_col19, #T_36bb5_row51_col14, #T_36bb5_row51_col19, #T_36bb5_row52_col14, #T_36bb5_row52_col19, #T_36bb5_row53_col4, #T_36bb5_row53_col14, #T_36bb5_row53_col19, #T_36bb5_row54_col29, #T_36bb5_row60_col4, #T_36bb5_row64_col4 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_36bb5_row13_col9, #T_36bb5_row25_col24, #T_36bb5_row56_col9, #T_36bb5_row62_col29 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_36bb5_row13_col29, #T_36bb5_row39_col24, #T_36bb5_row41_col14, #T_36bb5_row41_col19, #T_36bb5_row42_col14, #T_36bb5_row42_col19, #T_36bb5_row43_col14, #T_36bb5_row43_col19, #T_36bb5_row67_col4 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_36bb5_row14_col14, #T_36bb5_row14_col19, #T_36bb5_row19_col4, #T_36bb5_row19_col29, #T_36bb5_row30_col24 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_36bb5_row15_col4, #T_36bb5_row23_col4, #T_36bb5_row23_col14, #T_36bb5_row23_col19, #T_36bb5_row44_col29, #T_36bb5_row49_col24, #T_36bb5_row50_col9 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_36bb5_row15_col9, #T_36bb5_row22_col14, #T_36bb5_row22_col19, #T_36bb5_row42_col9, #T_36bb5_row42_col29, #T_36bb5_row60_col24 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_36bb5_row15_col24, #T_36bb5_row33_col29, #T_36bb5_row67_col9 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_36bb5_row15_col29, #T_36bb5_row34_col9, #T_36bb5_row34_col24, #T_36bb5_row44_col9, #T_36bb5_row51_col4 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_36bb5_row16_col4, #T_36bb5_row20_col24, #T_36bb5_row45_col29, #T_36bb5_row61_col9, #T_36bb5_row66_col4, #T_36bb5_row66_col9 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_36bb5_row16_col9, #T_36bb5_row24_col29, #T_36bb5_row27_col14, #T_36bb5_row27_col19, #T_36bb5_row30_col14, #T_36bb5_row30_col19, #T_36bb5_row32_col14, #T_36bb5_row32_col19, #T_36bb5_row33_col14, #T_36bb5_row33_col19, #T_36bb5_row54_col4, #T_36bb5_row61_col4, #T_36bb5_row63_col24 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_36bb5_row16_col24, #T_36bb5_row33_col4, #T_36bb5_row33_col9, #T_36bb5_row53_col29, #T_36bb5_row68_col4, #T_36bb5_row69_col4, #T_36bb5_row70_col9 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_36bb5_row16_col29, #T_36bb5_row66_col24 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_36bb5_row18_col4, #T_36bb5_row20_col4, #T_36bb5_row55_col24, #T_36bb5_row58_col29, #T_36bb5_row60_col14, #T_36bb5_row60_col19, #T_36bb5_row62_col14, #T_36bb5_row62_col19, #T_36bb5_row70_col4 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_36bb5_row18_col9, #T_36bb5_row26_col24, #T_36bb5_row36_col9, #T_36bb5_row55_col29, #T_36bb5_row71_col9 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_36bb5_row20_col9, #T_36bb5_row22_col9, #T_36bb5_row53_col24, #T_36bb5_row56_col29, #T_36bb5_row67_col14, #T_36bb5_row67_col19 {
#   background-color: #fee5cc;
#   color: #000000;
# }
# #T_36bb5_row20_col14, #T_36bb5_row20_col19, #T_36bb5_row23_col24, #T_36bb5_row37_col9, #T_36bb5_row42_col4, #T_36bb5_row60_col29 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_36bb5_row21_col4, #T_36bb5_row45_col4, #T_36bb5_row45_col9, #T_36bb5_row46_col4, #T_36bb5_row47_col24, #T_36bb5_row47_col29, #T_36bb5_row52_col4, #T_36bb5_row56_col4 {
#   background-color: #fd8f3e;
#   color: #f1f1f1;
# }
# #T_36bb5_row21_col9, #T_36bb5_row34_col29, #T_36bb5_row38_col

# %% [markdown]
# ## Best 10 features

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X[df_final_fe.index.to_list()[:10]], y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_85d4f_row0_col3, #T_85d4f_row1_col6, #T_85d4f_row1_col7, #T_85d4f_row4_col4, #T_85d4f_row5_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_85d4f_row0_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_85d4f_row0_col5, #T_85d4f_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_85d4f_row0_col6, #T_85d4f_row0_col7, #T_85d4f_row1_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_85d4f_row0_col8, #T_85d4f_row1_col5 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_85d4f_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.4%, transparent 19.4%);
# }
# #T_85d4f_row1_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_85d4f_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.7%, transparent 37.7%);
# }
# #T_85d4f_row2_col3, #T_85d4f_row3_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_85d4f_row2_col4, #T_85d4f_row3_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_85d4f_row2_col5, #T_85d4f_row2_col8, #T_85d4f_row3_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_85d4f_row2_col6, #T_85d4f_row2_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_85d4f_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.9%, transparent 1.9%);
# }
# #T_85d4f_row3_col6, #T_85d4f_row3_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_85d4f_row3_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_85d4f_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_85d4f_row4_col3, #T_85d4f_row5_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_85d4f_row4_col5, #T_85d4f_row5_col5, #T_85d4f_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_85d4f_row4_col6, #T_85d4f_row5_col7 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_85d4f_row4_col7, #T_85d4f_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_85d4f_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_85d4f_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.4%, transparent 47.4%);
# }
# #T_85d4f_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_85d4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85d4f_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_85d4f_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_85d4f_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_85d4f_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_85d4f_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_85d4f_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_85d4f_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_85d4f_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_85d4f_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_85d4f_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85d4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85d4f_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_85d4f_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_85d4f_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_85d4f_row0_col3" class="data row0 col3" >0.999</td>
#       <td id="T_85d4f_row0_col4" class="data row0 col4" >0.003</td>
#       <td id="T_85d4f_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_85d4f_row0_col6" class="data row0 col6" >0.328</td>
#       <td id="T_85d4f_row0_col7" class="data row0 col7" >0.109</td>
#       <td id="T_85d4f_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_85d4f_row0_col9" class="data row0 col9" >11.1</td>
#     </tr>
#     <tr>
#       <th id="T_85d4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85d4f_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_85d4f_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_85d4f_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_85d4f_row1_col3" class="data row1 col3" >0.998</td>
#       <td id="T_85d4f_row1_col4" class="data row1 col4" >0.003</td>
#       <td id="T_85d4f_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_85d4f_row1_col6" class="data row1 col6" >0.334</td>
#       <td id="T_85d4f_row1_col7" class="data row1 col7" >0.112</td>
#       <td id="T_85d4f_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_85d4f_row1_col9" class="data row1 col9" >21.6</td>
#     </tr>
#     <tr>
#       <th id="T_85d4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85d4f_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_85d4f_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_85d4f_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_85d4f_row2_col3" class="data row2 col3" >0.998</td>
#       <td id="T_85d4f_row2_col4" class="data row2 col4" >0.002</td>
#       <td id="T_85d4f_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_85d4f_row2_col6" class="data row2 col6" >0.080</td>
#       <td id="T_85d4f_row2_col7" class="data row2 col7" >0.098</td>
#       <td id="T_85d4f_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_85d4f_row2_col9" class="data row2 col9" >1.1</td>
#     </tr>
#     <tr>
#       <th id="T_85d4f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85d4f_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_85d4f_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_85d4f_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_85d4f_row3_col3" class="data row3 col3" >0.998</td>
#       <td id="T_85d4f_row3_col4" class="data row3 col4" >0.002</td>
#       <td id="T_85d4f_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_85d4f_row3_col6" class="data row3 col6" >0.081</td>
#       <td id="T_85d4f_row3_col7" class="data row3 col7" >0.098</td>
#       <td id="T_85d4f_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_85d4f_row3_col9" class="data row3 col9" >1.5</td>
#     </tr>
#     <tr>
#       <th id="T_85d4f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85d4f_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_85d4f_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_85d4f_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_85d4f_row4_col3" class="data row4 col3" >0.996</td>
#       <td id="T_85d4f_row4_col4" class="data row4 col4" >0.006</td>
#       <td id="T_85d4f_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_85d4f_row4_col6" class="data row4 col6" >0.070</td>
#       <td id="T_85d4f_row4_col7" class="data row4 col7" >0.038</td>
#       <td id="T_85d4f_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_85d4f_row4_col9" class="data row4 col9" >27.2</td>
#     </tr>
#     <tr>
#       <th id="T_85d4f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85d4f_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_85d4f_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_85d4f_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_85d4f_row5_col3" class="data row5 col3" >0.996</td>
#       <td id="T_85d4f_row5_col4" class="data row5 col4" >0.006</td>
#       <td id="T_85d4f_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_85d4f_row5_col6" class="data row5 col6" >0.069</td>
#       <td id="T_85d4f_row5_col7" class="data row5 col7" >0.038</td>
#       <td id="T_85d4f_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_85d4f_row5_col9" class="data row5 col9" >57.4</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Best 20 features

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X[df_final_fe.index.to_list()[:20]], y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_12753_row0_col3, #T_12753_row0_col6, #T_12753_row1_col4, #T_12753_row2_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_12753_row0_col4, #T_12753_row1_col3, #T_12753_row1_col6, #T_12753_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_12753_row0_col5, #T_12753_row0_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_12753_row0_col7, #T_12753_row2_col3, #T_12753_row2_col4, #T_12753_row2_col6, #T_12753_row4_col3, #T_12753_row5_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_12753_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.9%, transparent 16.9%);
# }
# #T_12753_row1_col5, #T_12753_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_12753_row1_col7, #T_12753_row3_col4, #T_12753_row3_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_12753_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.9%, transparent 32.9%);
# }
# #T_12753_row2_col5, #T_12753_row2_col8, #T_12753_row4_col5, #T_12753_row5_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_12753_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_12753_row3_col3, #T_12753_row4_col4, #T_12753_row4_col7, #T_12753_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_12753_row3_col5, #T_12753_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_12753_row3_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_12753_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.0%, transparent 2.0%);
# }
# #T_12753_row4_col6, #T_12753_row5_col4, #T_12753_row5_col7 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_12753_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_12753_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.7%, transparent 43.7%);
# }
# #T_12753_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_12753">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12753_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_12753_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_12753_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_12753_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_12753_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_12753_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_12753_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_12753_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_12753_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_12753_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12753_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12753_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_12753_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_12753_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_12753_row0_col3" class="data row0 col3" >0.996</td>
#       <td id="T_12753_row0_col4" class="data row0 col4" >0.007</td>
#       <td id="T_12753_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_12753_row0_col6" class="data row0 col6" >0.311</td>
#       <td id="T_12753_row0_col7" class="data row0 col7" >0.092</td>
#       <td id="T_12753_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_12753_row0_col9" class="data row0 col9" >11.7</td>
#     </tr>
#     <tr>
#       <th id="T_12753_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12753_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_12753_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_12753_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_12753_row1_col3" class="data row1 col3" >0.997</td>
#       <td id="T_12753_row1_col4" class="data row1 col4" >0.007</td>
#       <td id="T_12753_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_12753_row1_col6" class="data row1 col6" >0.314</td>
#       <td id="T_12753_row1_col7" class="data row1 col7" >0.094</td>
#       <td id="T_12753_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_12753_row1_col9" class="data row1 col9" >22.7</td>
#     </tr>
#     <tr>
#       <th id="T_12753_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12753_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_12753_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_12753_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_12753_row2_col3" class="data row2 col3" >0.996</td>
#       <td id="T_12753_row2_col4" class="data row2 col4" >0.006</td>
#       <td id="T_12753_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_12753_row2_col6" class="data row2 col6" >0.117</td>
#       <td id="T_12753_row2_col7" class="data row2 col7" >0.139</td>
#       <td id="T_12753_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_12753_row2_col9" class="data row2 col9" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_12753_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12753_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_12753_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_12753_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_12753_row3_col3" class="data row3 col3" >0.996</td>
#       <td id="T_12753_row3_col4" class="data row3 col4" >0.006</td>
#       <td id="T_12753_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_12753_row3_col6" class="data row3 col6" >0.117</td>
#       <td id="T_12753_row3_col7" class="data row3 col7" >0.140</td>
#       <td id="T_12753_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_12753_row3_col9" class="data row3 col9" >1.4</td>
#     </tr>
#     <tr>
#       <th id="T_12753_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12753_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_12753_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_12753_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_12753_row4_col3" class="data row4 col3" >0.996</td>
#       <td id="T_12753_row4_col4" class="data row4 col4" >0.006</td>
#       <td id="T_12753_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_12753_row4_col6" class="data row4 col6" >0.079</td>
#       <td id="T_12753_row4_col7" class="data row4 col7" >0.037</td>
#       <td id="T_12753_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_12753_row4_col9" class="data row4 col9" >30.2</td>
#     </tr>
#     <tr>
#       <th id="T_12753_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12753_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_12753_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_12753_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_12753_row5_col3" class="data row5 col3" >0.996</td>
#       <td id="T_12753_row5_col4" class="data row5 col4" >0.006</td>
#       <td id="T_12753_row5_col5" class="data row5 col5" >3</td>
#       <td id="T_12753_row5_col6" class="data row5 col6" >0.078</td>
#       <td id="T_12753_row5_col7" class="data row5 col7" >0.038</td>
#       <td id="T_12753_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_12753_row5_col9" class="data row5 col9" >69.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Best 30 features

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X[df_final_fe.index.to_list()[:30]], y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_7dc38_row0_col3, #T_7dc38_row1_col4, #T_7dc38_row1_col6, #T_7dc38_row2_col7, #T_7dc38_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col4 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col5, #T_7dc38_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col6, #T_7dc38_row1_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col7 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col8, #T_7dc38_row1_col5 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_7dc38_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.9%, transparent 20.9%);
# }
# #T_7dc38_row1_col7 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_7dc38_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.4%, transparent 34.4%);
# }
# #T_7dc38_row2_col3, #T_7dc38_row2_col6, #T_7dc38_row3_col3, #T_7dc38_row3_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_7dc38_row2_col4, #T_7dc38_row3_col4, #T_7dc38_row4_col3, #T_7dc38_row5_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_7dc38_row2_col5, #T_7dc38_row2_col8, #T_7dc38_row3_col5, #T_7dc38_row3_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_7dc38_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_7dc38_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.5%, transparent 1.5%);
# }
# #T_7dc38_row4_col4, #T_7dc38_row5_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_7dc38_row4_col5, #T_7dc38_row5_col5, #T_7dc38_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_7dc38_row4_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_7dc38_row4_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_7dc38_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_7dc38_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.6%, transparent 47.6%);
# }
# #T_7dc38_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_7dc38_row5_col7 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7dc38_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_7dc38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dc38_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_7dc38_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_7dc38_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_7dc38_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_7dc38_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_7dc38_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_7dc38_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_7dc38_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_7dc38_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_7dc38_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dc38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7dc38_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_7dc38_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_7dc38_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_7dc38_row0_col3" class="data row0 col3" >0.996</td>
#       <td id="T_7dc38_row0_col4" class="data row0 col4" >0.007</td>
#       <td id="T_7dc38_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_7dc38_row0_col6" class="data row0 col6" >0.314</td>
#       <td id="T_7dc38_row0_col7" class="data row0 col7" >0.092</td>
#       <td id="T_7dc38_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_7dc38_row0_col9" class="data row0 col9" >15.4</td>
#     </tr>
#     <tr>
#       <th id="T_7dc38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7dc38_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_7dc38_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_7dc38_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_7dc38_row1_col3" class="data row1 col3" >0.996</td>
#       <td id="T_7dc38_row1_col4" class="data row1 col4" >0.007</td>
#       <td id="T_7dc38_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_7dc38_row1_col6" class="data row1 col6" >0.315</td>
#       <td id="T_7dc38_row1_col7" class="data row1 col7" >0.094</td>
#       <td id="T_7dc38_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_7dc38_row1_col9" class="data row1 col9" >25.4</td>
#     </tr>
#     <tr>
#       <th id="T_7dc38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7dc38_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_7dc38_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_7dc38_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_7dc38_row2_col3" class="data row2 col3" >0.996</td>
#       <td id="T_7dc38_row2_col4" class="data row2 col4" >0.006</td>
#       <td id="T_7dc38_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_7dc38_row2_col6" class="data row2 col6" >0.112</td>
#       <td id="T_7dc38_row2_col7" class="data row2 col7" >0.134</td>
#       <td id="T_7dc38_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_7dc38_row2_col9" class="data row2 col9" >0.7</td>
#     </tr>
#     <tr>
#       <th id="T_7dc38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7dc38_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_7dc38_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_7dc38_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_7dc38_row3_col3" class="data row3 col3" >0.996</td>
#       <td id="T_7dc38_row3_col4" class="data row3 col4" >0.006</td>
#       <td id="T_7dc38_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_7dc38_row3_col6" class="data row3 col6" >0.112</td>
#       <td id="T_7dc38_row3_col7" class="data row3 col7" >0.134</td>
#       <td id="T_7dc38_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_7dc38_row3_col9" class="data row3 col9" >1.1</td>
#     </tr>
#     <tr>
#       <th id="T_7dc38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7dc38_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_7dc38_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_7dc38_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_7dc38_row4_col3" class="data row4 col3" >0.995</td>
#       <td id="T_7dc38_row4_col4" class="data row4 col4" >0.007</td>
#       <td id="T_7dc38_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_7dc38_row4_col6" class="data row4 col6" >0.088</td>
#       <td id="T_7dc38_row4_col7" class="data row4 col7" >0.041</td>
#       <td id="T_7dc38_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_7dc38_row4_col9" class="data row4 col9" >35.2</td>
#     </tr>
#     <tr>
#       <th id="T_7dc38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7dc38_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_7dc38_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_7dc38_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_7dc38_row5_col3" class="data row5 col3" >0.995</td>
#       <td id="T_7dc38_row5_col4" class="data row5 col4" >0.007</td>
#       <td id="T_7dc38_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_7dc38_row5_col6" class="data row5 col6" >0.087</td>
#       <td id="T_7dc38_row5_col7" class="data row5 col7" >0.041</td>
#       <td id="T_7dc38_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_7dc38_row5_col9" class="data row5 col9" >74.0</td>
#     </tr>
#   </tbody>
# </table>
