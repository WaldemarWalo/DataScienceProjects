# %% [markdown]
# # Setup and Imports

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

from sklearn.preprocessing import StandardScaler, PowerTransformer

# %%
(X, y) = t.from_pkl(f'{processed_data_path}/b1_b2_concat_ax0.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 54)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__p01', 'x__p10', 'x__p20', 'x__p30', 'x__p99', 'x__p90',
#        'x__p80', 'x__p70', 'x__iqr', 'x__kurtosis', 'x__skew', 'y__amin',
#        'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std', 'y__var',
#        'y__p01', 'y__p10', 'y__p20', 'y__p30', 'y__p99', 'y__p90', 'y__p80',
#        'y__p70', 'y__iqr', 'y__kurtosis', 'y__skew', 'z__amin', 'z__amax',
#        'z__sum', 'z__median', 'z__mean', 'z__std', 'z__var', 'z__p01',
#        'z__p10', 'z__p20', 'z__p30', 'z__p99', 'z__p90', 'z__p80', 'z__p70',
#        'z__iqr', 'z__kurtosis', 'z__skew'],
#       dtype='object')
# (200,)
# 0    100
# 1    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

from sklearn.metrics import roc_auc_score, log_loss

from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# # First Run

# %%
n_est_list = [100, 400, 800]
models_and_params = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5)
metrics = [ roc_auc_score, log_loss ]

ret = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_5f859_row0_col3, #T_5f859_row16_col4, #T_5f859_row16_col6, #T_5f859_row16_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5f859_row0_col4, #T_5f859_row3_col6, #T_5f859_row11_col7 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_5f859_row0_col5, #T_5f859_row16_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_5f859_row0_col6, #T_5f859_row2_col7, #T_5f859_row9_col4, #T_5f859_row16_col3 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_5f859_row0_col7, #T_5f859_row2_col4, #T_5f859_row8_col3, #T_5f859_row13_col6 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_5f859_row0_col8, #T_5f859_row16_col5 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_5f859_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_5f859_row1_col3, #T_5f859_row15_col4, #T_5f859_row15_col6, #T_5f859_row15_col7 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_5f859_row1_col4, #T_5f859_row4_col6, #T_5f859_row8_col7, #T_5f859_row12_col3, #T_5f859_row13_col3, #T_5f859_row14_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_5f859_row1_col5, #T_5f859_row15_col8 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_5f859_row1_col6, #T_5f859_row3_col4, #T_5f859_row7_col7, #T_5f859_row15_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_5f859_row1_col7, #T_5f859_row7_col4, #T_5f859_row9_col3, #T_5f859_row14_col6 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_5f859_row1_col8, #T_5f859_row15_col5 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_5f859_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.6%, transparent 49.6%);
# }
# #T_5f859_row2_col3, #T_5f859_row2_col6, #T_5f859_row11_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_5f859_row2_col5, #T_5f859_row2_col8 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_5f859_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.5%, transparent 36.5%);
# }
# #T_5f859_row3_col3, #T_5f859_row7_col6, #T_5f859_row12_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_5f859_row3_col5, #T_5f859_row7_col8 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_5f859_row3_col7, #T_5f859_row4_col4, #T_5f859_row9_col6, #T_5f859_row10_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_5f859_row3_col8 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_5f859_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.5%, transparent 12.5%);
# }
# #T_5f859_row4_col3, #T_5f859_row4_col7, #T_5f859_row11_col6 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_5f859_row4_col5, #T_5f859_row11_col8 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_5f859_row4_col8, #T_5f859_row12_col5, #T_5f859_row13_col5, #T_5f859_row14_col5 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_5f859_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_5f859_row5_col3, #T_5f859_row5_col6, #T_5f859_row6_col3, #T_5f859_row6_col6 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_5f859_row5_col4, #T_5f859_row6_col4 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_5f859_row5_col5, #T_5f859_row5_col8, #T_5f859_row6_col5, #T_5f859_row6_col8 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_5f859_row5_col7, #T_5f859_row6_col7 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_5f859_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_5f859_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.7%, transparent 1.7%);
# }
# #T_5f859_row7_col3, #T_5f859_row12_col6, #T_5f859_row12_col7 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_5f859_row7_col5, #T_5f859_row12_col8 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_5f859_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.2%, transparent 18.2%);
# }
# #T_5f859_row8_col4, #T_5f859_row8_col6, #T_5f859_row9_col7 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_5f859_row8_col5, #T_5f859_row13_col8 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_5f859_row8_col8 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_5f859_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.2%, transparent 31.2%);
# }
# #T_5f859_row9_col5, #T_5f859_row14_col8 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_5f859_row9_col8, #T_5f859_row10_col5 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_5f859_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.0%, transparent 4.0%);
# }
# #T_5f859_row10_col4, #T_5f859_row10_col6, #T_5f859_row10_col7, #T_5f859_row11_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_5f859_row10_col8, #T_5f859_row11_col5 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_5f859_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.6%, transparent 15.6%);
# }
# #T_5f859_row11_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.7%, transparent 4.7%);
# }
# #T_5f859_row12_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.0%, transparent 6.0%);
# }
# #T_5f859_row13_col4, #T_5f859_row14_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_5f859_row13_col7 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_5f859_row13_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.1%, transparent 21.1%);
# }
# #T_5f859_row14_col7 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_5f859_row14_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.1%, transparent 42.1%);
# }
# #T_5f859_row15_col9, #T_5f859_row16_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# </style>
# <table id="T_5f859">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f859_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_5f859_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_5f859_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_5f859_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_5f859_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_5f859_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_5f859_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_5f859_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_5f859_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_5f859_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f859_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_5f859_row0_col0" class="data row0 col0" >CatBoostClassifier</td>
#       <td id="T_5f859_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_5f859_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_5f859_row0_col3" class="data row0 col3" >0.987</td>
#       <td id="T_5f859_row0_col4" class="data row0 col4" >0.016</td>
#       <td id="T_5f859_row0_col5" class="data row0 col5" >17</td>
#       <td id="T_5f859_row0_col6" class="data row0 col6" >0.165</td>
#       <td id="T_5f859_row0_col7" class="data row0 col7" >0.076</td>
#       <td id="T_5f859_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_5f859_row0_col9" class="data row0 col9" >89.3</td>
#     </tr>
#     <tr>
#       <th id="T_5f859_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_5f859_row1_col0" class="data row1 col0" >CatBoostClassifier</td>
#       <td id="T_5f859_row1_col1" class="data row1 col1" >'n_estimators': 400</td>
#       <td id="T_5f859_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_5f859_row1_col3" class="data row1 col3" >0.986</td>
#       <td id="T_5f859_row1_col4" class="data row1 col4" >0.016</td>
#       <td id="T_5f859_row1_col5" class="data row1 col5" >16</td>
#       <td id="T_5f859_row1

# %% [markdown]
# # Shortlisted Best 3

# %%
trained_models = []
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_17ff6_row0_col3, #T_17ff6_row0_col6, #T_17ff6_row1_col4, #T_17ff6_row4_col7, #T_17ff6_row5_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_17ff6_row0_col4, #T_17ff6_row1_col3, #T_17ff6_row1_col6 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_17ff6_row0_col5, #T_17ff6_row0_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_17ff6_row0_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_17ff6_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.9%, transparent 35.9%);
# }
# #T_17ff6_row1_col5, #T_17ff6_row1_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_17ff6_row1_col7 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_17ff6_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.2%, transparent 18.2%);
# }
# #T_17ff6_row2_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_17ff6_row2_col4, #T_17ff6_row3_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_17ff6_row2_col5 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_17ff6_row2_col6, #T_17ff6_row3_col4 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_17ff6_row2_col7 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_17ff6_row2_col8, #T_17ff6_row4_col5, #T_17ff6_row5_col5 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_17ff6_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_17ff6_row3_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_17ff6_row3_col5, #T_17ff6_row4_col8, #T_17ff6_row5_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_17ff6_row3_col7 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_17ff6_row3_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_17ff6_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.0%, transparent 48.0%);
# }
# #T_17ff6_row4_col3, #T_17ff6_row5_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_17ff6_row4_col4, #T_17ff6_row4_col6, #T_17ff6_row5_col4, #T_17ff6_row5_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_17ff6_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_17ff6_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# </style>
# <table id="T_17ff6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17ff6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_17ff6_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_17ff6_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_17ff6_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_17ff6_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_17ff6_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_17ff6_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_17ff6_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_17ff6_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_17ff6_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17ff6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_17ff6_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_17ff6_row0_col1" class="data row0 col1" >'n_estimators': 1600</td>
#       <td id="T_17ff6_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_17ff6_row0_col3" class="data row0 col3" >0.986</td>
#       <td id="T_17ff6_row0_col4" class="data row0 col4" >0.017</td>
#       <td id="T_17ff6_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_17ff6_row0_col6" class="data row0 col6" >0.445</td>
#       <td id="T_17ff6_row0_col7" class="data row0 col7" >0.026</td>
#       <td id="T_17ff6_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_17ff6_row0_col9" class="data row0 col9" >130.1</td>
#     </tr>
#     <tr>
#       <th id="T_17ff6_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_17ff6_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_17ff6_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_17ff6_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_17ff6_row1_col3" class="data row1 col3" >0.986</td>
#       <td id="T_17ff6_row1_col4" class="data row1 col4" >0.018</td>
#       <td id="T_17ff6_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_17ff6_row1_col6" class="data row1 col6" >0.442</td>
#       <td id="T_17ff6_row1_col7" class="data row1 col7" >0.026</td>
#       <td id="T_17ff6_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_17ff6_row1_col9" class="data row1 col9" >66.2</td>
#     </tr>
#     <tr>
#       <th id="T_17ff6_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_17ff6_row2_col0" class="data row2 col0" >CatBoostClassifier</td>
#       <td id="T_17ff6_row2_col1" class="data row2 col1" >'n_estimators': 1600</td>
#       <td id="T_17ff6_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_17ff6_row2_col3" class="data row2 col3" >0.986</td>
#       <td id="T_17ff6_row2_col4" class="data row2 col4" >0.015</td>
#       <td id="T_17ff6_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_17ff6_row2_col6" class="data row2 col6" >0.163</td>
#       <td id="T_17ff6_row2_col7" class="data row2 col7" >0.076</td>
#       <td id="T_17ff6_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_17ff6_row2_col9" class="data row2 col9" >362.8</td>
#     </tr>
#     <tr>
#       <th id="T_17ff6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_17ff6_row3_col0" class="data row3 col0" >CatBoostClassifier</td>
#       <td id="T_17ff6_row3_col1" class="data row3 col1" >'n_estimators': 800</td>
#       <td id="T_17ff6_row3_col2" class="data row3 col2" >50</td>
#       <td id="T_17ff6_row3_col3" class="data row3 col3" >0.986</td>
#       <td id="T_17ff6_row3_col4" class="data row3 col4" >0.015</td>
#       <td id="T_17ff6_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_17ff6_row3_col6" class="data row3 col6" >0.164</td>
#       <td id="T_17ff6_row3_col7" class="data row3 col7" >0.074</td>
#       <td id="T_17ff6_row3_col8" class="data row3 col8" >2</td>
#       <td id="T_17ff6_row3_col9" class="data row3 col9" >174.3</td>
#     </tr>
#     <tr>
#       <th id="T_17ff6_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_17ff6_row4_col0" class="data row4 col0" >LGBMClassifier</td>
#       <td id="T_17ff6_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_17ff6_row4_col2" class="data row4 col2" >50</td>
#       <td id="T_17ff6_row4_col3" class="data row4 col3" >0.985</td>
#       <td id="T_17ff6_row4_col4" class="data row4 col4" >0.017</td>
#       <td id="T_17ff6_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_17ff6_row4_col6" class="data row4 col6" >0.278</td>
#       <td id="T_17ff6_row4_col7" class="data row4 col7" >0.230</td>
#       <td id="T_17ff6_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_17ff6_row4_col9" class="data row4 col9" >3.2</td>
#     </tr>
#     <tr>
#       <th id="T_17ff6_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_17ff6_row5_col0" class="data row5 col0" >LGBMClassifier</td>
#       <td id="T_17ff6_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_17ff6_row5_col2" class="data row5 col2" >50</td>
#       <td id="T_17ff6_row5_col3" class="data row5 col3" >0.985</td>
#       <td id="T_17ff6_row5_col4" class="data row5 col4" >0.017</td>
#       <td id="T_17ff6_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_17ff6_row5_col6" class="data row5 col6" >0.278</td>
#       <td id="T_17ff6_row5_col7" class="data row5 col7" >0.230</td>
#       <td id="T_17ff6_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_17ff6_row5_col9" class="data row5 col9" >4.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_3de6a_row0_col0, #T_3de6a_row1_col1, #T_3de6a_row6_col2 {
#   background-color: #8b2c04;
#   color: #f1f1f1;
# }
# #T_3de6a_row0_col1, #T_3de6a_row0_col3, #T_3de6a_row1_col2, #T_3de6a_row10_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_3de6a_row0_col2, #T_3de6a_row2_col0, #T_3de6a_row7_col1 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_3de6a_row1_col0, #T_3de6a_row4_col1, #T_3de6a_row9_col2 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_3de6a_row1_col3 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_3de6a_row2_col1, #T_3de6a_row3_col0, #T_3de6a_row3_col2 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_3de6a_row2_col2, #T_3de6a_row12_col1, #T_3de6a_row17_col0 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_3de6a_row2_col3 {
#   background-color: #993103;
#   color: #f1f1f1;
# }
# #T_3de6a_row3_col1, #T_3de6a_row4_col2, #T_3de6a_row5_col0 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_3de6a_row3_col3, #T_3de6a_row4_col3 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_3de6a_row4_col0, #T_3de6a_row5_col2, #T_3de6a_row8_col1 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_3de6a_row5_col1, #T_3de6a_row8_col0, #T_3de6a_row9_col3, #T_3de6a_row10_col3, #T_3de6a_row15_col2 {
#   background-color: #ce4401;
#   color: #f1f1f1;
# }
# #T_3de6a_row5_col3 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_3de6a_row6_col0, #T_3de6a_row9_col1, #T_3de6a_row24_col2 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_3de6a_row6_col1, #T_3de6a_row12_col2, #T_3de6a_row18_col0 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_3de6a_row6_col3 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_3de6a_row7_col0, #T_3de6a_row17_col3, #T_3de6a_row19_col2, #T_3de6a_row22_col1 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_3de6a_row7_col2, #T_3de6a_row10_col1, #T_3de6a_row11_col0 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_3de6a_row7_col3 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_3de6a_row8_col2, #T_3de6a_row15_col1, #T_3de6a_row31_col0 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_3de6a_row8_col3 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_3de6a_row9_col0, #T_3de6a_row14_col1, #T_3de6a_row14_col2 {
#   background-color: #eb610f;
#   color: #f1f1f1;
# }
# #T_3de6a_row10_col2, #T_3de6a_row27_col3, #T_3de6a_row29_col1, #T_3de6a_row30_col0 {
#   background-color: #fd9b50;
#   color: #000000;
# }
# #T_3de6a_row11_col1, #T_3de6a_row21_col2, #T_3de6a_row26_col0 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_3de6a_row11_col2, #T_3de6a_row12_col0, #T_3de6a_row20_col1 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_3de6a_row11_col3 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_3de6a_row12_col3 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_3de6a_row13_col0, #T_3de6a_row23_col1, #T_3de6a_row23_col2 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_3de6a_row13_col1, #T_3de6a_row14_col0, #T_3de6a_row25_col2 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_3de6a_row13_col2, #T_3de6a_row16_col0, #T_3de6a_row16_col1 {
#   background-color: #b53b02;
#   color: #f1f1f1;
# }
# #T_3de6a_row13_col3 {
#   background-color: #e75b0b;
#   color: #f1f1f1;
# }
# #T_3de6a_row14_col3 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_3de6a_row15_col0, #T_3de6a_row21_col1, #T_3de6a_row21_col3, #T_3de6a_row22_col3, #T_3de6a_row33_col2 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_3de6a_row15_col3 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_3de6a_row16_col2, #T_3de6a_row32_col0, #T_3de6a_row37_col1 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_3de6a_row16_col3 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_3de6a_row17_col1, #T_3de6a_row18_col2, #T_3de6a_row22_col0, #T_3de6a_row24_col3, #T_3de6a_row25_col3, #T_3de6a_row26_col3 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_3de6a_row17_col2, #T_3de6a_row18_col1, #T_3de6a_row27_col0 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# #T_3de6a_row18_col3, #T_3de6a_row19_col3 {
#   background-color: #f36f1a;
#   color: #f1f1f1;
# }
# #T_3de6a_row19_col0, #T_3de6a_row22_col2, #T_3de6a_row30_col1 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_3de6a_row19_col1, #T_3de6a_row20_col0, #T_3de6a_row32_col2 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_3de6a_row20_col2, #T_3de6a_row25_col0, #T_3de6a_row25_col1 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_3de6a_row20_col3 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_3de6a_row21_col0, #T_3de6a_row26_col1, #T_3de6a_row26_col2 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_3de6a_row23_col0, #T_3de6a_row27_col1, #T_3de6a_row28_col2 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_3de6a_row23_col3 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_3de6a_row24_col0, #T_3de6a_row35_col1, #T_3de6a_row42_col2 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_3de6a_row24_col1, #T_3de6a_row29_col0, #T_3de6a_row35_col2 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_3de6a_row27_col2, #T_3de6a_row33_col0, #T_3de6a_row36_col1 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_3de6a_row28_col0, #T_3de6a_row29_col2, #T_3de6a_row34_col1 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_3de6a_row28_col1, #T_3de6a_row37_col2, #T_3de6a_row39_col0 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_3de6a_row28_col3 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_3de6a_row29_col3 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_3de6a_row30_col2, #T_3de6a_row37_col0, #T_3de6a_row38_col3, #T_3de6a_row43_col1 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_3de6a_row30_col3 {
#   background-color: #fdad69;
#   color: #000000;
# }
# #T_3de6a_row31_col1, #T_3de6a_row34_col2, #T_3de6a_row40_col0 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_3de6a_row31_col2, #T_3de6a_row33_col1, #T_3de6a_row34_col0 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_3de6a_row31_col3, #T_3de6a_row32_col3 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_3de6a_row32_col1, #T_3de6a_row36_col0, #T_3de6a_row36_col2 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_3de6a_row33_col3 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_3de6a_row34_col3 {
#   background-color: #fdcb9b;
#   color: #000000;
# }
# #T_3de6a_row35_col0, #T_3de6a_row39_col2, #T_3de6a_row42_col1 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_3de6a_row35_col3 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_3de6a_row36_col3, #T_3de6a_row37_col3 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_3de6a_row38_col0, #T_3de6a_row38_col1, #T_3de6a_row41_col2 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_3de6a_row38_col2, #T_3de6a_row39_col1, #T_3de6a_row43_col0 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_3de6a_row39_col3, #T_3de6a_row40_col1, #T_3de6a_row42_col0, #T_3de6a_row43_col2 {
#   background-color: #fedcb9;
#   color: #000000;
# }
# #T_3de6a_row40_col2, #T_3de6a_row41_col0, #T_3de6a_row41_col1 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_3de6a_row40_col3 {
#   background-color: #fedfc0;
#   color: #000000;
# }
# #T_3de6a_row41_col3 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_3de6a_row42_col3 {
#   background-color: #fee2c6;
#   color: #000000;
# }
# #T_3de6a_row43_col3 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# </style>
# <table id="T_3de6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3de6a_level0_col0" class="col_heading level0 col0" >ABC_0_rank</th>
#       <th id="T_3de6a_level0_col1" class="col_heading level0 col1" >LGBMC_1_rank</th>
#       <th id="T_3de6a_level0_col2" class="col_heading level0 col2" >CBC_2_rank</th>
#       <th id="T_3de6a_level0_col3" class="col_heading level0 col3" >sum_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3de6a_level0_row0" class="row_heading level0 row0" >x__skew</th>
#       <td id="T_3de6a_row0_col0" class="data row0 col0" >42</td>
#       <td id="T_3de6a_row0_col1" class="data row0 col1" >44</td>
#       <td id="T_3de6a_row0_col2" class="

# %% [markdown]
# ## Remove worst 10 features

# %%
features_to_drop = df_final_fe.index.to_list()[-10:]
features_to_drop
# Out:
# ['x__p01',
#  'z__std',
#  'x__p90',
#  'x__iqr',
#  'x__amin',
#  'z__p30',
#  'x__p99',
#  'z__p80',
#  'y__p99',
#  'x__std']

# %%
trained_models = []
n_est_list = [800]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X.drop(columns=features_to_drop), y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_02e6e_row0_col3, #T_02e6e_row1_col7, #T_02e6e_row2_col4, #T_02e6e_row2_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_02e6e_row0_col4, #T_02e6e_row0_col6, #T_02e6e_row2_col3, #T_02e6e_row2_col7 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_02e6e_row0_col5, #T_02e6e_row2_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_02e6e_row0_col7, #T_02e6e_row1_col3, #T_02e6e_row1_col4, #T_02e6e_row1_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_02e6e_row0_col8, #T_02e6e_row2_col5 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_02e6e_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_02e6e_row1_col5, #T_02e6e_row1_col8 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_02e6e_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.4%, transparent 2.4%);
# }
# #T_02e6e_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.6%, transparent 35.6%);
# }
# </style>
# <table id="T_02e6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02e6e_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_02e6e_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_02e6e_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_02e6e_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_02e6e_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_02e6e_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_02e6e_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_02e6e_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_02e6e_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_02e6e_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02e6e_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_02e6e_row0_col0" class="data row0 col0" >CatBoostClassifier</td>
#       <td id="T_02e6e_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_02e6e_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_02e6e_row0_col3" class="data row0 col3" >0.988</td>
#       <td id="T_02e6e_row0_col4" class="data row0 col4" >0.013</td>
#       <td id="T_02e6e_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_02e6e_row0_col6" class="data row0 col6" >0.156</td>
#       <td id="T_02e6e_row0_col7" class="data row0 col7" >0.073</td>
#       <td id="T_02e6e_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_02e6e_row0_col9" class="data row0 col9" >187.6</td>
#     </tr>
#     <tr>
#       <th id="T_02e6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02e6e_row1_col0" class="data row1 col0" >LGBMClassifier</td>
#       <td id="T_02e6e_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_02e6e_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_02e6e_row1_col3" class="data row1 col3" >0.986</td>
#       <td id="T_02e6e_row1_col4" class="data row1 col4" >0.016</td>
#       <td id="T_02e6e_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_02e6e_row1_col6" class="data row1 col6" >0.271</td>
#       <td id="T_02e6e_row1_col7" class="data row1 col7" >0.217</td>
#       <td id="T_02e6e_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_02e6e_row1_col9" class="data row1 col9" >4.5</td>
#     </tr>
#     <tr>
#       <th id="T_02e6e_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_02e6e_row2_col0" class="data row2 col0" >AdaBoostClassifier</td>
#       <td id="T_02e6e_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_02e6e_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_02e6e_row2_col3" class="data row2 col3" >0.985</td>
#       <td id="T_02e6e_row2_col4" class="data row2 col4" >0.019</td>
#       <td id="T_02e6e_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_02e6e_row2_col6" class="data row2 col6" >0.436</td>
#       <td id="T_02e6e_row2_col7" class="data row2 col7" >0.026</td>
#       <td id="T_02e6e_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_02e6e_row2_col9" class="data row2 col9" >66.7</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_aee8f_row0_col0, #T_aee8f_row0_col1, #T_aee8f_row7_col2 {
#   background-color: #8b2c04;
#   color: #f1f1f1;
# }
# #T_aee8f_row0_col2, #T_aee8f_row0_col3, #T_aee8f_row1_col1, #T_aee8f_row1_col3, #T_aee8f_row10_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_aee8f_row1_col0, #T_aee8f_row8_col1, #T_aee8f_row9_col2 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_aee8f_row1_col2, #T_aee8f_row2_col0, #T_aee8f_row6_col1 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_aee8f_row2_col1, #T_aee8f_row3_col2, #T_aee8f_row16_col0 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_aee8f_row2_col2, #T_aee8f_row12_col1, #T_aee8f_row19_col0 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_aee8f_row2_col3 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_aee8f_row3_col0, #T_aee8f_row4_col1, #T_aee8f_row5_col2 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_aee8f_row3_col1, #T_aee8f_row4_col0, #T_aee8f_row14_col2 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_aee8f_row3_col3 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_aee8f_row4_col2, #T_aee8f_row5_col0, #T_aee8f_row16_col1 {
#   background-color: #b53b02;
#   color: #f1f1f1;
# }
# #T_aee8f_row4_col3 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_aee8f_row5_col1, #T_aee8f_row9_col3, #T_aee8f_row10_col3, #T_aee8f_row12_col2, #T_aee8f_row18_col0 {
#   background-color: #ce4401;
#   color: #f1f1f1;
# }
# #T_aee8f_row5_col3 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_aee8f_row6_col0, #T_aee8f_row20_col1, #T_aee8f_row30_col2 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_aee8f_row6_col2, #T_aee8f_row10_col1, #T_aee8f_row11_col0 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_aee8f_row6_col3, #T_aee8f_row7_col3 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_aee8f_row7_col0, #T_aee8f_row11_col1, #T_aee8f_row26_col2 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_aee8f_row7_col1, #T_aee8f_row8_col0, #T_aee8f_row13_col2 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_aee8f_row8_col2, #T_aee8f_row13_col1, #T_aee8f_row15_col0 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_aee8f_row8_col3 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_aee8f_row9_col0, #T_aee8f_row15_col2, #T_aee8f_row17_col1 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_aee8f_row9_col1, #T_aee8f_row25_col2, #T_aee8f_row31_col0 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_aee8f_row10_col2, #T_aee8f_row24_col1, #T_aee8f_row29_col0 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_aee8f_row11_col2, #T_aee8f_row14_col1, #T_aee8f_row20_col0 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_aee8f_row11_col3 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_aee8f_row12_col0, #T_aee8f_row15_col1, #T_aee8f_row15_col3, #T_aee8f_row16_col3, #T_aee8f_row17_col2 {
#   background-color: #eb610f;
#   color: #f1f1f1;
# }
# #T_aee8f_row12_col3 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_aee8f_row13_col0, #T_aee8f_row18_col2, #T_aee8f_row28_col1 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_aee8f_row13_col3 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_aee8f_row14_col0, #T_aee8f_row33_col1, #T_aee8f_row34_col2 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_aee8f_row14_col3 {
#   background-color: #e75b0b;
#   color: #f1f1f1;
# }
# #T_aee8f_row16_col2, #T_aee8f_row34_col1, #T_aee8f_row42_col0 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_aee8f_row17_col0, #T_aee8f_row19_col1, #T_aee8f_row29_col2 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# #T_aee8f_row17_col3, #T_aee8f_row18_col3, #T_aee8f_row19_col3 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_aee8f_row18_col1, #T_aee8f_row21_col0, #T_aee8f_row32_col2 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_aee8f_row19_col2, #T_aee8f_row22_col0, #T_aee8f_row26_col1 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_aee8f_row20_col2, #T_aee8f_row25_col0, #T_aee8f_row31_col1 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_aee8f_row20_col3 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_aee8f_row21_col1, #T_aee8f_row23_col2, #T_aee8f_row28_col0 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_aee8f_row21_col2, #T_aee8f_row23_col0, #T_aee8f_row23_col1, #T_aee8f_row23_col3 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_aee8f_row21_col3 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_aee8f_row22_col1, #T_aee8f_row24_col2, #T_aee8f_row27_col0 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_aee8f_row22_col2, #T_aee8f_row24_col0, #T_aee8f_row40_col1 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_aee8f_row22_col3 {
#   background-color: #fd8e3d;
#   color: #f1f1f1;
# }
# #T_aee8f_row24_col3 {
#   background-color: #fd9243;
#   color: #000000;
# }
# #T_aee8f_row25_col1, #T_aee8f_row37_col0, #T_aee8f_row38_col2 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_aee8f_row25_col3, #T_aee8f_row26_col3 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_aee8f_row26_col0, #T_aee8f_row27_col2, #T_aee8f_row29_col1 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_aee8f_row27_col1, #T_aee8f_row35_col0, #T_aee8f_row41_col2 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_aee8f_row27_col3, #T_aee8f_row28_col3 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_aee8f_row28_col2, #T_aee8f_row30_col0, #T_aee8f_row30_col1 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_aee8f_row29_col3 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_aee8f_row30_col3 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_aee8f_row31_col2, #T_aee8f_row40_col0, #T_aee8f_row42_col1 {
#   background-color: #fedcb9;
#   color: #000000;
# }
# #T_aee8f_row31_col3 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_aee8f_row32_col0, #T_aee8f_row34_col3, #T_aee8f_row38_col1, #T_aee8f_row39_col2 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_aee8f_row32_col1, #T_aee8f_row33_col2, #T_aee8f_row36_col0 {
#   background-color: #fd9b50;
#   color: #000000;
# }
# #T_aee8f_row32_col3 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_aee8f_row33_col0, #T_aee8f_row37_col1, #T_aee8f_row40_col2 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_aee8f_row33_col3 {
#   background-color: #fdb87c;
#   color: #000000;
# }
# #T_aee8f_row34_col0, #T_aee8f_row35_col1, #T_aee8f_row37_col2 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_aee8f_row35_col2, #T_aee8f_row35_col3, #T_aee8f_row36_col1, #T_aee8f_row36_col3, #T_aee8f_row39_col0 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_aee8f_row36_col2, #T_aee8f_row39_col1, #T_aee8f_row43_col0 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_aee8f_row37_col3, #T_aee8f_row38_col3 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_aee8f_row38_col0, #T_aee8f_row41_col1, #T_aee8f_row42_col2 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_aee8f_row39_col3 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_aee8f_row40_col3, #T_aee8f_row41_col3 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_aee8f_row41_col0, #T_aee8f_row43_col1, #T_aee8f_row43_col2 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_aee8f_row42_col3 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# #T_aee8f_row43_col3 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# </style>
# <table id="T_aee8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee8f_level0_col0" class="col_heading level0 col0" >ABC_0_rank</th>
#       <th id="T_aee8f_level0_col1" class="col_heading level0 col1" >LGBMC_1_rank</th>
#       <th id="T_aee8f_level0_col2" class="col_heading level0 col2" >CBC_2_rank</th>
#       <th id="T_aee8f_level0_col3" class="col_heading level0 col3" >sum_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aee8f_level0_row0" class="row_heading level0 row0" >x__median</th>
#       <td id="T_aee8f_row0_col0" class="data row0 col0" >42</td>
#       <td id="T_aee8f_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_aee8f_row0_col2" class="data row0 col2" >44</td>
#       <td id="T_aee8f_r

# %% [markdown]
# # Second 10 Worst Features

# %%
features_to_drop_2 = df_final_fe.index.to_list()[-10:]
features_to_drop_2
features_to_drop.extend(features_to_drop_2)
# Out:
# ['z__p90',
#  'z__p10',
#  'y__amax',
#  'z__p01',
#  'y__std',
#  'x__p10',
#  'x__var',
#  'y__var',
#  'z__iqr',
#  'z__p20']

# %%
trained_models = []
n_est_list = [800]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X.drop(columns=features_to_drop), y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_ff6ec_row0_col3, #T_ff6ec_row1_col4, #T_ff6ec_row1_col6, #T_ff6ec_row2_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ff6ec_row0_col4, #T_ff6ec_row0_col6, #T_ff6ec_row1_col7, #T_ff6ec_row2_col3 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_ff6ec_row0_col5, #T_ff6ec_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_ff6ec_row0_col7, #T_ff6ec_row1_col3, #T_ff6ec_row2_col4, #T_ff6ec_row2_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_ff6ec_row0_col8, #T_ff6ec_row2_col5 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_ff6ec_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_ff6ec_row1_col5, #T_ff6ec_row2_col8 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_ff6ec_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.7%, transparent 39.7%);
# }
# #T_ff6ec_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.3%, transparent 2.3%);
# }
# </style>
# <table id="T_ff6ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff6ec_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_ff6ec_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_ff6ec_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_ff6ec_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_ff6ec_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_ff6ec_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_ff6ec_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_ff6ec_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_ff6ec_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_ff6ec_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff6ec_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ff6ec_row0_col0" class="data row0 col0" >CatBoostClassifier</td>
#       <td id="T_ff6ec_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_ff6ec_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_ff6ec_row0_col3" class="data row0 col3" >0.989</td>
#       <td id="T_ff6ec_row0_col4" class="data row0 col4" >0.013</td>
#       <td id="T_ff6ec_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_ff6ec_row0_col6" class="data row0 col6" >0.151</td>
#       <td id="T_ff6ec_row0_col7" class="data row0 col7" >0.071</td>
#       <td id="T_ff6ec_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_ff6ec_row0_col9" class="data row0 col9" >165.1</td>
#     </tr>
#     <tr>
#       <th id="T_ff6ec_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_ff6ec_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_ff6ec_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_ff6ec_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_ff6ec_row1_col3" class="data row1 col3" >0.988</td>
#       <td id="T_ff6ec_row1_col4" class="data row1 col4" >0.017</td>
#       <td id="T_ff6ec_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_ff6ec_row1_col6" class="data row1 col6" >0.430</td>
#       <td id="T_ff6ec_row1_col7" class="data row1 col7" >0.025</td>
#       <td id="T_ff6ec_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_ff6ec_row1_col9" class="data row1 col9" >65.5</td>
#     </tr>
#     <tr>
#       <th id="T_ff6ec_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_ff6ec_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_ff6ec_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_ff6ec_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_ff6ec_row2_col3" class="data row2 col3" >0.987</td>
#       <td id="T_ff6ec_row2_col4" class="data row2 col4" >0.015</td>
#       <td id="T_ff6ec_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ff6ec_row2_col6" class="data row2 col6" >0.263</td>
#       <td id="T_ff6ec_row2_col7" class="data row2 col7" >0.215</td>
#       <td id="T_ff6ec_row2_col8" class="data row2 col8" >2</td>
#       <td id="T_ff6ec_row2_col9" class="data row2 col9" >3.8</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_8a3db_row0_col0, #T_8a3db_row2_col1, #T_8a3db_row7_col2 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_8a3db_row0_col1, #T_8a3db_row0_col3, #T_8a3db_row1_col2, #T_8a3db_row10_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_8a3db_row0_col2, #T_8a3db_row3_col0, #T_8a3db_row5_col1 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_8a3db_row1_col0, #T_8a3db_row2_col2, #T_8a3db_row8_col1 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_8a3db_row1_col1, #T_8a3db_row9_col0, #T_8a3db_row12_col2 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_8a3db_row1_col3 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_8a3db_row2_col0, #T_8a3db_row3_col1, #T_8a3db_row4_col2 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_8a3db_row2_col3 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_8a3db_row3_col2, #T_8a3db_row6_col0, #T_8a3db_row7_col1 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_8a3db_row3_col3 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_8a3db_row4_col0, #T_8a3db_row6_col2, #T_8a3db_row10_col1 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_8a3db_row4_col1, #T_8a3db_row5_col2, #T_8a3db_row18_col0 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_8a3db_row4_col3 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_8a3db_row5_col0, #T_8a3db_row21_col1, #T_8a3db_row24_col2 {
#   background-color: #fd9141;
#   color: #000000;
# }
# #T_8a3db_row5_col3 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_8a3db_row6_col1, #T_8a3db_row8_col2, #T_8a3db_row30_col0 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_8a3db_row6_col3, #T_8a3db_row7_col3 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_8a3db_row7_col0, #T_8a3db_row12_col1, #T_8a3db_row28_col2 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_8a3db_row8_col0, #T_8a3db_row13_col1, #T_8a3db_row29_col2 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_8a3db_row8_col3, #T_8a3db_row9_col3 {
#   background-color: #dc4c03;
#   color: #f1f1f1;
# }
# #T_8a3db_row9_col1, #T_8a3db_row11_col2, #T_8a3db_row17_col0 {
#   background-color: #df5106;
#   color: #f1f1f1;
# }
# #T_8a3db_row9_col2, #T_8a3db_row11_col0, #T_8a3db_row14_col1 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_8a3db_row10_col2, #T_8a3db_row16_col0, #T_8a3db_row22_col1, #T_8a3db_row27_col3 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_8a3db_row10_col3 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_8a3db_row11_col1, #T_8a3db_row14_col2, #T_8a3db_row22_col0 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_8a3db_row11_col3 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_8a3db_row12_col0, #T_8a3db_row19_col2, #T_8a3db_row20_col1 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_8a3db_row12_col3, #T_8a3db_row16_col1, #T_8a3db_row21_col0, #T_8a3db_row27_col2 {
#   background-color: #ee6410;
#   color: #f1f1f1;
# }
# #T_8a3db_row13_col0, #T_8a3db_row20_col2, #T_8a3db_row23_col1 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_8a3db_row13_col2, #T_8a3db_row19_col0, #T_8a3db_row19_col1 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_8a3db_row13_col3 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_8a3db_row14_col0, #T_8a3db_row17_col1, #T_8a3db_row33_col2 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_8a3db_row14_col3 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_8a3db_row15_col0, #T_8a3db_row15_col1, #T_8a3db_row16_col2 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_8a3db_row15_col2, #T_8a3db_row27_col0, #T_8a3db_row29_col1 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_8a3db_row15_col3 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_8a3db_row16_col3 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_8a3db_row17_col2, #T_8a3db_row18_col1, #T_8a3db_row25_col0 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_8a3db_row17_col3, #T_8a3db_row18_col3 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_8a3db_row18_col2, #T_8a3db_row24_col0, #T_8a3db_row31_col1 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_8a3db_row19_col3 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_8a3db_row20_col0, #T_8a3db_row23_col2, #T_8a3db_row27_col1 {
#   background-color: #fdcfa0;
#   color: #000000;
# }
# #T_8a3db_row20_col3 {
#   background-color: #fd9a4e;
#   color: #000000;
# }
# #T_8a3db_row21_col2, #T_8a3db_row28_col0, #T_8a3db_row32_col1 {
#   background-color: #fdc794;
#   color: #000000;
# }
# #T_8a3db_row21_col3 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_8a3db_row22_col2, #T_8a3db_row29_col0, #T_8a3db_row32_col3, #T_8a3db_row33_col1 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_8a3db_row22_col3, #T_8a3db_row23_col3 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_8a3db_row23_col0, #T_8a3db_row25_col1, #T_8a3db_row25_col2 {
#   background-color: #fdb373;
#   color: #000000;
# }
# #T_8a3db_row24_col1, #T_8a3db_row26_col2, #T_8a3db_row31_col0 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_8a3db_row24_col3 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_8a3db_row25_col3, #T_8a3db_row26_col3 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_8a3db_row26_col0, #T_8a3db_row26_col1, #T_8a3db_row32_col2 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_8a3db_row28_col1, #T_8a3db_row31_col2, #T_8a3db_row32_col0 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_8a3db_row28_col3 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_8a3db_row29_col3 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_8a3db_row30_col1, #T_8a3db_row30_col2, #T_8a3db_row33_col0 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_8a3db_row30_col3 {
#   background-color: #fdcb9b;
#   color: #000000;
# }
# #T_8a3db_row31_col3 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_8a3db_row33_col3 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# </style>
# <table id="T_8a3db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a3db_level0_col0" class="col_heading level0 col0" >ABC_0_rank</th>
#       <th id="T_8a3db_level0_col1" class="col_heading level0 col1" >LGBMC_1_rank</th>
#       <th id="T_8a3db_level0_col2" class="col_heading level0 col2" >CBC_2_rank</th>
#       <th id="T_8a3db_level0_col3" class="col_heading level0 col3" >sum_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a3db_level0_row0" class="row_heading level0 row0" >x__skew</th>
#       <td id="T_8a3db_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_8a3db_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_8a3db_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_8a3db_row0_col3" class="data row0 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_8a3db_level0_row1" class="row_heading level0 row1" >x__median</th>
#       <td id="T_8a3db_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_8a3db_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_8a3db_row1_col2" class="data row1 col2" >34</td>
#       <td id="T_8a3db_row1_col3" class="data row1 col3" >95</td>
#     </tr>
#     <tr>
#       <th id="T_8a3db_level0_row2" class="row_heading level0 row2" >z__p99</th>
#       <td id="T_8a3db_row2_col0" class="data row2 col0" >29</td>
#       <td id="T_8a3db_row2_col1" class="data row2 col1" >32</td>
#       <td id="T_8a3db_row2_col2" class="data row2 col2" >31</td>
#       <td id="T_8a3db_row2_col3" class="data row2 col3" >92</td>
#     </tr>
#     <tr>
#       <th id="T_8a3db_level0_row3" class="row_heading level0 row3" >z__skew</th>
#       <td id="T_8a3db_row3_col0" class="data row3 col0" >33</td>
#       <td id="T_8a3db_row3_col1" class="data row3 col1" >29</td>
#       <td id="T_8a3db_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_8a3db_row3_col3" class="data row3 col3" >86</td>
#     </tr>
#     <tr>
#       <th id="T_8a3db_level0_row4" class="row_heading level0 row4" >x__sum</th>
#       <td id="T_8a3db_row4_col0" class="data row4 col0" >28</td>
#       <td id="T_8a3db_row4_col1" class="data row4 col1" >27</td>
#       <td id="T_8a3db_row4_col2" class="data row4 col2" >29</td>
#       <td id="T_8a3db_row
