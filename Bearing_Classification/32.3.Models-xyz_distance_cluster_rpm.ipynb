# %% [markdown]
# # Setup and Imports

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

from sklearn.preprocessing import StandardScaler, PowerTransformer

# %%
(X, y) = t.from_pkl(f'{processed_data_path}/xyz_distance_cluster_rpm.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 72)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__p01', 'x__p10', 'x__p20', 'x__p30', 'x__p99', 'x__p90',
#        'x__p80', 'x__p70', 'x__iqr', 'x__kurtosis', 'x__skew', 'y__amin',
#        'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std', 'y__var',
#        'y__p01', 'y__p10', 'y__p20', 'y__p30', 'y__p99', 'y__p90', 'y__p80',
#        'y__p70', 'y__iqr', 'y__kurtosis', 'y__skew', 'z__amin', 'z__amax',
#        'z__sum', 'z__median', 'z__mean', 'z__std', 'z__var', 'z__p01',
#        'z__p10', 'z__p20', 'z__p30', 'z__p99', 'z__p90', 'z__p80', 'z__p70',
#        'z__iqr', 'z__kurtosis', 'z__skew', 'xyz__amin', 'xyz__amax',
#        'xyz__sum', 'xyz__median', 'xyz__mean', 'xyz__std', 'xyz__var',
#        'xyz__p01', 'xyz__p10', 'xyz__p20', 'xyz__p30', 'xyz__p99', 'xyz__p90',
#        'xyz__p80', 'xyz__p70', 'xyz__iqr', 'xyz__kurtosis', 'xyz__skew'],
#       dtype='object')
# (200,)
# 0    100
# 1    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

from sklearn.metrics import roc_auc_score, log_loss

from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# # First Run

# %%
n_est_list = [100, 400, 800]
models_and_params = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5)
metrics = [ roc_auc_score, log_loss ]

ret = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_146cd_row0_col3, #T_146cd_row16_col4, #T_146cd_row16_col6, #T_146cd_row16_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_146cd_row0_col4, #T_146cd_row8_col6, #T_146cd_row9_col7, #T_146cd_row12_col3, #T_146cd_row13_col3, #T_146cd_row14_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_146cd_row0_col5, #T_146cd_row16_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_146cd_row0_col6, #T_146cd_row2_col7, #T_146cd_row14_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_146cd_row0_col7, #T_146cd_row6_col4, #T_146cd_row7_col6, #T_146cd_row16_col3 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_146cd_row0_col8 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_146cd_row0_col9, #T_146cd_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.3%, transparent 4.3%);
# }
# #T_146cd_row1_col3, #T_146cd_row15_col4, #T_146cd_row15_col6, #T_146cd_row15_col7 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_146cd_row1_col4, #T_146cd_row6_col7, #T_146cd_row9_col3, #T_146cd_row9_col6 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_146cd_row1_col5, #T_146cd_row15_col8 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_146cd_row1_col6, #T_146cd_row3_col7, #T_146cd_row10_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_146cd_row1_col7, #T_146cd_row6_col6, #T_146cd_row7_col4, #T_146cd_row15_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_146cd_row1_col8, #T_146cd_row2_col5, #T_146cd_row3_col5 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_146cd_row1_col9, #T_146cd_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.2%, transparent 2.2%);
# }
# #T_146cd_row2_col3, #T_146cd_row3_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_146cd_row2_col4, #T_146cd_row3_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_146cd_row2_col6, #T_146cd_row6_col3, #T_146cd_row11_col4, #T_146cd_row13_col7 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_146cd_row2_col8, #T_146cd_row6_col5 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_146cd_row3_col6, #T_146cd_row5_col3, #T_146cd_row12_col7 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_146cd_row3_col8, #T_146cd_row5_col5 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_146cd_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_146cd_row4_col3, #T_146cd_row4_col6, #T_146cd_row5_col7 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_146cd_row4_col4, #T_146cd_row8_col7, #T_146cd_row10_col3, #T_146cd_row11_col6 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_146cd_row4_col5, #T_146cd_row4_col8 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_146cd_row4_col7, #T_146cd_row5_col6, #T_146cd_row8_col4 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_146cd_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_146cd_row5_col4, #T_146cd_row7_col7, #T_146cd_row8_col3, #T_146cd_row10_col6 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_146cd_row5_col8 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_146cd_row6_col8, #T_146cd_row15_col5 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_146cd_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.0%, transparent 6.0%);
# }
# #T_146cd_row7_col3, #T_146cd_row9_col4, #T_146cd_row11_col7, #T_146cd_row14_col6 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_146cd_row7_col5, #T_146cd_row14_col8 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_146cd_row7_col8, #T_146cd_row16_col5 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_146cd_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.2%, transparent 8.2%);
# }
# #T_146cd_row8_col5, #T_146cd_row10_col8 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_146cd_row8_col8, #T_146cd_row12_col5, #T_146cd_row13_col5, #T_146cd_row14_col5 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_146cd_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.8%, transparent 1.8%);
# }
# #T_146cd_row9_col5, #T_146cd_row9_col8 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_146cd_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_146cd_row10_col5, #T_146cd_row11_col8 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_146cd_row10_col7, #T_146cd_row12_col6 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_146cd_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_146cd_row11_col3, #T_146cd_row13_col6, #T_146cd_row14_col7 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_146cd_row11_col5, #T_146cd_row13_col8 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_146cd_row11_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.3%, transparent 6.3%);
# }
# #T_146cd_row12_col4, #T_146cd_row13_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_146cd_row12_col8 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_146cd_row12_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_146cd_row13_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.6%, transparent 99.6%);
# }
# #T_146cd_row14_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_146cd_row15_col9, #T_146cd_row16_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_146cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_146cd_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_146cd_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_146cd_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_146cd_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_146cd_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_146cd_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_146cd_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_146cd_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_146cd_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_146cd_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_146cd_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_146cd_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_146cd_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_146cd_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_146cd_row0_col3" class="data row0 col3" >0.991</td>
#       <td id="T_146cd_row0_col4" class="data row0 col4" >0.016</td>
#       <td id="T_146cd_row0_col5" class="data row0 col5" >17</td>
#       <td id="T_146cd_row0_col6" class="data row0 col6" >0.472</td>
#       <td id="T_146cd_row0_col7" class="data row0 col7" >0.016</td>
#       <td id="T_146cd_row0_col8" class="data row0 col8" >15</td>
#       <td id="T_146cd_row0_col9" class="data row0 col9" >61.6</td>
#     </tr>
#     <tr>
#       <th id="T_146cd_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_146cd_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_146cd_row1_col1" class="data row1 col1" >'n_estimators': 400</td>
#       <td id="T_146cd_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_146cd_row1_col3" class="data row1 col3" >0.990</td>
#       <td id="T_146cd_row1_col4" class="data row1 col4" >0.017</td>
#       <td id="T_146cd_row1_col5" class="data row1 col5" >16</td>
#       <td id="T_146cd_row1_col6" class="data row1 col6" >0.466</td>
#       <td id="T_146cd_row1_col7" class="data row1 col7" >0.017</td>
#       <td id="T_146cd_row1_col8" class="data row1 col8" >14</td>
#       <td id="T_

# %% [markdown]
# # Shortlisted Best 3

# %%
trained_models = []
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_f523d_row0_col3, #T_f523d_row0_col6, #T_f523d_row2_col4, #T_f523d_row2_col7, #T_f523d_row3_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f523d_row0_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_f523d_row0_col5, #T_f523d_row0_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f523d_row0_col7, #T_f523d_row4_col6, #T_f523d_row5_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_f523d_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_f523d_row1_col3, #T_f523d_row1_col6, #T_f523d_row3_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_f523d_row1_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_f523d_row1_col5, #T_f523d_row1_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_f523d_row1_col7, #T_f523d_row4_col3, #T_f523d_row5_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_f523d_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.0%, transparent 17.0%);
# }
# #T_f523d_row2_col3, #T_f523d_row3_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_f523d_row2_col5, #T_f523d_row2_col8, #T_f523d_row3_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_f523d_row2_col6, #T_f523d_row5_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_f523d_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_f523d_row3_col6, #T_f523d_row4_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_f523d_row3_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_f523d_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_f523d_row4_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_f523d_row4_col5, #T_f523d_row5_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_f523d_row4_col8, #T_f523d_row5_col5 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_f523d_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f523d_row5_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_f523d_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.0%, transparent 48.0%);
# }
# </style>
# <table id="T_f523d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f523d_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f523d_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_f523d_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_f523d_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_f523d_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_f523d_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_f523d_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_f523d_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_f523d_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_f523d_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f523d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f523d_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_f523d_row0_col1" class="data row0 col1" >'n_estimators': 1600</td>
#       <td id="T_f523d_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_f523d_row0_col3" class="data row0 col3" >0.993</td>
#       <td id="T_f523d_row0_col4" class="data row0 col4" >0.013</td>
#       <td id="T_f523d_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_f523d_row0_col6" class="data row0 col6" >0.475</td>
#       <td id="T_f523d_row0_col7" class="data row0 col7" >0.020</td>
#       <td id="T_f523d_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_f523d_row0_col9" class="data row0 col9" >156.3</td>
#     </tr>
#     <tr>
#       <th id="T_f523d_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_f523d_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_f523d_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_f523d_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_f523d_row1_col3" class="data row1 col3" >0.992</td>
#       <td id="T_f523d_row1_col4" class="data row1 col4" >0.012</td>
#       <td id="T_f523d_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_f523d_row1_col6" class="data row1 col6" >0.472</td>
#       <td id="T_f523d_row1_col7" class="data row1 col7" >0.021</td>
#       <td id="T_f523d_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_f523d_row1_col9" class="data row1 col9" >80.4</td>
#     </tr>
#     <tr>
#       <th id="T_f523d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f523d_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_f523d_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_f523d_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_f523d_row2_col3" class="data row2 col3" >0.988</td>
#       <td id="T_f523d_row2_col4" class="data row2 col4" >0.014</td>
#       <td id="T_f523d_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_f523d_row2_col6" class="data row2 col6" >0.245</td>
#       <td id="T_f523d_row2_col7" class="data row2 col7" >0.210</td>
#       <td id="T_f523d_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_f523d_row2_col9" class="data row2 col9" >4.1</td>
#     </tr>
#     <tr>
#       <th id="T_f523d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f523d_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_f523d_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_f523d_row3_col2" class="data row3 col2" >50</td>
#       <td id="T_f523d_row3_col3" class="data row3 col3" >0.988</td>
#       <td id="T_f523d_row3_col4" class="data row3 col4" >0.014</td>
#       <td id="T_f523d_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_f523d_row3_col6" class="data row3 col6" >0.245</td>
#       <td id="T_f523d_row3_col7" class="data row3 col7" >0.210</td>
#       <td id="T_f523d_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_f523d_row3_col9" class="data row3 col9" >6.1</td>
#     </tr>
#     <tr>
#       <th id="T_f523d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f523d_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_f523d_row4_col1" class="data row4 col1" >'n_estimators': 1600</td>
#       <td id="T_f523d_row4_col2" class="data row4 col2" >50</td>
#       <td id="T_f523d_row4_col3" class="data row4 col3" >0.986</td>
#       <td id="T_f523d_row4_col4" class="data row4 col4" >0.012</td>
#       <td id="T_f523d_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_f523d_row4_col6" class="data row4 col6" >0.171</td>
#       <td id="T_f523d_row4_col7" class="data row4 col7" >0.065</td>
#       <td id="T_f523d_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_f523d_row4_col9" class="data row4 col9" >473.1</td>
#     </tr>
#     <tr>
#       <th id="T_f523d_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_f523d_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_f523d_row5_col1" class="data row5 col1" >'n_estimators': 800</td>
#       <td id="T_f523d_row5_col2" class="data row5 col2" >50</td>
#       <td id="T_f523d_row5_col3" class="data row5 col3" >0.985</td>
#       <td id="T_f523d_row5_col4" class="data row5 col4" >0.013</td>
#       <td id="T_f523d_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_f523d_row5_col6" class="data row5 col6" >0.174</td>
#       <td id="T_f523d_row5_col7" class="data row5 col7" >0.064</td>
#       <td id="T_f523d_row5_col8" class="data row5 col8" >2</td>
#       <td id="T_f523d_row5_col9" class="data row5 col9" >227.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_1e1b8_row0_col0, #T_1e1b8_row0_col1, #T_1e1b8_row0_col4, #T_1e1b8_row0_col5, #T_1e1b8_row3_col2, #T_1e1b8_row3_col3 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_1e1b8_row0_col2, #T_1e1b8_row0_col3, #T_1e1b8_row0_col6, #T_1e1b8_row1_col4, #T_1e1b8_row1_col5, #T_1e1b8_row2_col0, #T_1e1b8_row2_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_1e1b8_row1_col0, #T_1e1b8_row1_col1, #T_1e1b8_row2_col2, #T_1e1b8_row2_col3, #T_1e1b8_row4_col4, #T_1e1b8_row4_col5 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row1_col2, #T_1e1b8_row1_col3, #T_1e1b8_row2_col4, #T_1e1b8_row2_col5, #T_1e1b8_row3_col0, #T_1e1b8_row3_col1 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row1_col6, #T_1e1b8_row2_col6 {
#   background-color: #842904;
#   color: #f1f1f1;
# }
# #T_1e1b8_row3_col4, #T_1e1b8_row6_col6, #T_1e1b8_row7_col2, #T_1e1b8_row7_col3, #T_1e1b8_row7_col5, #T_1e1b8_row21_col0, #T_1e1b8_row21_col1 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_1e1b8_row3_col5, #T_1e1b8_row7_col4, #T_1e1b8_row9_col0, #T_1e1b8_row9_col1, #T_1e1b8_row10_col2, #T_1e1b8_row10_col3 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_1e1b8_row3_col6 {
#   background-color: #8b2c04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row4_col0, #T_1e1b8_row4_col1, #T_1e1b8_row5_col2, #T_1e1b8_row5_col3, #T_1e1b8_row8_col5, #T_1e1b8_row16_col4 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_1e1b8_row4_col2, #T_1e1b8_row4_col3, #T_1e1b8_row5_col4, #T_1e1b8_row5_col5, #T_1e1b8_row6_col0, #T_1e1b8_row6_col1 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row4_col6 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row5_col0, #T_1e1b8_row8_col2, #T_1e1b8_row11_col4, #T_1e1b8_row11_col5, #T_1e1b8_row28_col1, #T_1e1b8_row32_col3 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_1e1b8_row5_col1, #T_1e1b8_row8_col3, #T_1e1b8_row10_col4, #T_1e1b8_row10_col5, #T_1e1b8_row17_col2, #T_1e1b8_row28_col0 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_1e1b8_row5_col6 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_1e1b8_row6_col2, #T_1e1b8_row6_col3, #T_1e1b8_row8_col4, #T_1e1b8_row13_col0, #T_1e1b8_row13_col1, #T_1e1b8_row16_col5 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_1e1b8_row6_col4, #T_1e1b8_row6_col5, #T_1e1b8_row14_col2, #T_1e1b8_row18_col0, #T_1e1b8_row18_col1, #T_1e1b8_row37_col3 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_1e1b8_row7_col0, #T_1e1b8_row7_col1, #T_1e1b8_row13_col2, #T_1e1b8_row13_col3, #T_1e1b8_row15_col4, #T_1e1b8_row15_col5 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_1e1b8_row7_col6 {
#   background-color: #a03403;
#   color: #f1f1f1;
# }
# #T_1e1b8_row8_col0, #T_1e1b8_row8_col1, #T_1e1b8_row9_col2, #T_1e1b8_row9_col3, #T_1e1b8_row12_col4, #T_1e1b8_row12_col5 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_1e1b8_row8_col6 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_1e1b8_row9_col4, #T_1e1b8_row9_col5, #T_1e1b8_row12_col2, #T_1e1b8_row15_col3, #T_1e1b8_row19_col0, #T_1e1b8_row19_col1 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_1e1b8_row9_col6, #T_1e1b8_row10_col6 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_1e1b8_row10_col0, #T_1e1b8_row10_col1, #T_1e1b8_row11_col2, #T_1e1b8_row11_col6, #T_1e1b8_row14_col4, #T_1e1b8_row14_col5, #T_1e1b8_row17_col3 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_1e1b8_row11_col0, #T_1e1b8_row11_col1, #T_1e1b8_row11_col3, #T_1e1b8_row15_col2, #T_1e1b8_row23_col4, #T_1e1b8_row23_col5 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_1e1b8_row12_col0, #T_1e1b8_row12_col1, #T_1e1b8_row18_col3, #T_1e1b8_row18_col5, #T_1e1b8_row19_col4, #T_1e1b8_row19_col6, #T_1e1b8_row20_col2 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_1e1b8_row12_col3, #T_1e1b8_row17_col0, #T_1e1b8_row17_col1, #T_1e1b8_row18_col6, #T_1e1b8_row29_col2, #T_1e1b8_row44_col4, #T_1e1b8_row44_col5 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_1e1b8_row12_col6 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_1e1b8_row13_col4, #T_1e1b8_row13_col5, #T_1e1b8_row26_col2, #T_1e1b8_row26_col3, #T_1e1b8_row38_col0, #T_1e1b8_row50_col1 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_1e1b8_row13_col6 {
#   background-color: #c94202;
#   color: #f1f1f1;
# }
# #T_1e1b8_row14_col0, #T_1e1b8_row16_col3, #T_1e1b8_row22_col2, #T_1e1b8_row25_col1, #T_1e1b8_row31_col4, #T_1e1b8_row31_col5 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_1e1b8_row14_col1, #T_1e1b8_row19_col3, #T_1e1b8_row20_col4, #T_1e1b8_row20_col5, #T_1e1b8_row20_col6, #T_1e1b8_row25_col0, #T_1e1b8_row27_col2 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_1e1b8_row14_col3, #T_1e1b8_row18_col2, #T_1e1b8_row19_col5, #T_1e1b8_row27_col0, #T_1e1b8_row27_col1, #T_1e1b8_row30_col4 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_1e1b8_row14_col6, #T_1e1b8_row15_col6, #T_1e1b8_row16_col6, #T_1e1b8_row17_col6 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_1e1b8_row15_col0, #T_1e1b8_row23_col2, #T_1e1b8_row24_col4, #T_1e1b8_row24_col5, #T_1e1b8_row25_col3, #T_1e1b8_row26_col1 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_1e1b8_row15_col1, #T_1e1b8_row23_col6, #T_1e1b8_row24_col3, #T_1e1b8_row25_col2, #T_1e1b8_row26_col0, #T_1e1b8_row34_col4, #T_1e1b8_row34_col5 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_1e1b8_row16_col0, #T_1e1b8_row16_col1, #T_1e1b8_row24_col2, #T_1e1b8_row26_col4, #T_1e1b8_row26_col5, #T_1e1b8_row27_col3 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_1e1b8_row16_col2, #T_1e1b8_row18_col4, #T_1e1b8_row29_col0, #T_1e1b8_row29_col1, #T_1e1b8_row29_col3, #T_1e1b8_row30_col5 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_1e1b8_row17_col4, #T_1e1b8_row17_col5, #T_1e1b8_row19_col2, #T_1e1b8_row20_col3, #T_1e1b8_row22_col0, #T_1e1b8_row22_col1 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_1e1b8_row20_col0, #T_1e1b8_row20_col1, #T_1e1b8_row22_col3, #T_1e1b8_row32_col2, #T_1e1b8_row52_col4, #T_1e1b8_row52_col5 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_1e1b8_row21_col2, #T_1e1b8_row21_col3, #T_1e1b8_row21_col4, #T_1e1b8_row21_col5, #T_1e1b8_row38_col1, #T_1e1b8_row50_col0 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_1e1b8_row21_col6 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_1e1b8_row22_col4, #T_1e1b8_row28_col2, #T_1e1b8_row28_col3, #T_1e1b8_row36_col0, #T_1e1b8_row36_col1, #T_1e1b8_row41_col5 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_1e1b8_row22_col5, #T_1e1b8_row24_col0, #T_1e1b8_row26_col6, #T_1e1b8_row33_col2, #T_1e1b8_row33_col3, #T_1e1b8_row41_col4, #T_1e1b8_row45_col1 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_1e1b8_row22_col6 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_1e1b8_row23_col0, #T_1e1b8_row25_col5, #T_1e1b8_row32_col1, #T_1e1b8_row36_col2, #T_1e1b8_row36_col3, #T_1e1b8_row59_col4 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_1e1b8_row23_col1, #T_1e1b8_row40_col4, #T_1e1b8_row40_col5, #T_1e1b8_row46_col2, #T_1e1b8_row46_col3, #T_1e1b8_row47_col0 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_1e1b8_row23_col3, #T_1e1b8_row24_col1, #T_1e1b8_row24_col6, #T_1e1b8_row37_col2, #T_1e1b8_row39_col4, #T_1e1b8_row39_col5, #T_1e1b8_row45_col0 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_1e1b8_row25_col4, #T_1e1b8_row32_col0, #T_1e1b8_row33_col1, #T_1e1b8_row38_col2, #T_1e1b8_row38_col3, #T_1e1b8_row59_col5 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_1e1b8_row25_col6 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_1e1b8_row27_col4, #T_1e1b8_row28_col5, #T_1e1b8_row41_col6, #T_1e1b8_row42_col1, #T_1e1b8_row42_col6, #T_1e1b8_row50_col2, #T_1e1b8_row50_col3, #T_1e1b8_row51_col0 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_1e1b8_row27_col5, #T_1e1b8_row35_col1, #T_1e1b8_row42_col0, #T_1e1b8_row44_col6, #T_1e1b8_row45_col2, #T_1e1b8_row45_col3, #T_1e1b8_row45_col6, #T_1e1b8_row57_col4 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_1e1b8_row27_col6 {
#   background-color: #f3701b;
#   colo

# %% [markdown]
# ## Remove worst 10 features

# %%
features_to_drop = df_final_fe.index.to_list()[-10:]
features_to_drop
# Out:
# ['y__var',
#  'xyz__std',
#  'x__var',
#  'xyz__median',
#  'xyz__mean',
#  'xyz__p90',
#  'x__p01',
#  'xyz__p70',
#  'xyz__p80',
#  'xyz__var']

# %%
trained_models = []
n_est_list = [800]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X.drop(columns=features_to_drop), y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_496dd_row0_col3, #T_496dd_row0_col6, #T_496dd_row1_col4, #T_496dd_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_496dd_row0_col4, #T_496dd_row0_col7, #T_496dd_row2_col3, #T_496dd_row2_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_496dd_row0_col5, #T_496dd_row0_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_496dd_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_496dd_row1_col3, #T_496dd_row1_col6, #T_496dd_row2_col4, #T_496dd_row2_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_496dd_row1_col5, #T_496dd_row1_col8 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_496dd_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.7%, transparent 1.7%);
# }
# #T_496dd_row2_col5, #T_496dd_row2_col8 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_496dd_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_496dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_496dd_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_496dd_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_496dd_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_496dd_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_496dd_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_496dd_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_496dd_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_496dd_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_496dd_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_496dd_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_496dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_496dd_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_496dd_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_496dd_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_496dd_row0_col3" class="data row0 col3" >0.993</td>
#       <td id="T_496dd_row0_col4" class="data row0 col4" >0.011</td>
#       <td id="T_496dd_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_496dd_row0_col6" class="data row0 col6" >0.472</td>
#       <td id="T_496dd_row0_col7" class="data row0 col7" >0.020</td>
#       <td id="T_496dd_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_496dd_row0_col9" class="data row0 col9" >77.1</td>
#     </tr>
#     <tr>
#       <th id="T_496dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_496dd_row1_col0" class="data row1 col0" >LGBMClassifier</td>
#       <td id="T_496dd_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_496dd_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_496dd_row1_col3" class="data row1 col3" >0.987</td>
#       <td id="T_496dd_row1_col4" class="data row1 col4" >0.015</td>
#       <td id="T_496dd_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_496dd_row1_col6" class="data row1 col6" >0.246</td>
#       <td id="T_496dd_row1_col7" class="data row1 col7" >0.219</td>
#       <td id="T_496dd_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_496dd_row1_col9" class="data row1 col9" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_496dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_496dd_row2_col0" class="data row2 col0" >CatBoostClassifier</td>
#       <td id="T_496dd_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_496dd_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_496dd_row2_col3" class="data row2 col3" >0.986</td>
#       <td id="T_496dd_row2_col4" class="data row2 col4" >0.012</td>
#       <td id="T_496dd_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_496dd_row2_col6" class="data row2 col6" >0.169</td>
#       <td id="T_496dd_row2_col7" class="data row2 col7" >0.063</td>
#       <td id="T_496dd_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_496dd_row2_col9" class="data row2 col9" >233.3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_514ba_row0_col0, #T_514ba_row0_col2, #T_514ba_row3_col1 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_514ba_row0_col1, #T_514ba_row0_col3, #T_514ba_row1_col0, #T_514ba_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_514ba_row1_col1, #T_514ba_row2_col0, #T_514ba_row4_col2 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_514ba_row1_col2, #T_514ba_row3_col0, #T_514ba_row4_col1 {
#   background-color: #882a04;
#   color: #f1f1f1;
# }
# #T_514ba_row1_col3 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_514ba_row2_col1, #T_514ba_row5_col2, #T_514ba_row6_col0 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
# }
# #T_514ba_row2_col3 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_514ba_row3_col2, #T_514ba_row7_col1, #T_514ba_row21_col0 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_514ba_row3_col3, #T_514ba_row4_col3 {
#   background-color: #8e2d04;
#   color: #f1f1f1;
# }
# #T_514ba_row4_col0, #T_514ba_row5_col1, #T_514ba_row8_col2 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_514ba_row5_col0, #T_514ba_row11_col1, #T_514ba_row23_col2 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_514ba_row5_col3 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_514ba_row6_col1, #T_514ba_row10_col0, #T_514ba_row14_col2 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_514ba_row6_col2, #T_514ba_row17_col0, #T_514ba_row18_col1 {
#   background-color: #ce4401;
#   color: #f1f1f1;
# }
# #T_514ba_row6_col3, #T_514ba_row7_col3 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_514ba_row7_col0, #T_514ba_row10_col1, #T_514ba_row12_col2 {
#   background-color: #a93703;
#   color: #f1f1f1;
# }
# #T_514ba_row7_col2, #T_514ba_row9_col1, #T_514ba_row16_col0 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_514ba_row8_col0, #T_514ba_row15_col2, #T_514ba_row16_col1 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_514ba_row8_col1, #T_514ba_row9_col2, #T_514ba_row29_col0 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_514ba_row8_col3 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_514ba_row9_col0, #T_514ba_row11_col2, #T_514ba_row13_col1 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_514ba_row9_col3 {
#   background-color: #ae3903;
#   color: #f1f1f1;
# }
# #T_514ba_row10_col2, #T_514ba_row12_col1, #T_514ba_row19_col0 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_514ba_row10_col3 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_514ba_row11_col0, #T_514ba_row15_col1, #T_514ba_row18_col2 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_514ba_row11_col3 {
#   background-color: #c03f02;
#   color: #f1f1f1;
# }
# #T_514ba_row12_col0, #T_514ba_row17_col2, #T_514ba_row20_col1 {
#   background-color: #df5106;
#   color: #f1f1f1;
# }
# #T_514ba_row12_col3 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_514ba_row13_col0, #T_514ba_row27_col1, #T_514ba_row45_col2 {
#   background-color: #dc4c03;
#   color: #f1f1f1;
# }
# #T_514ba_row13_col2, #T_514ba_row14_col1, #T_514ba_row27_col0 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_514ba_row13_col3 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_514ba_row14_col0, #T_514ba_row20_col2, #T_514ba_row28_col1 {
#   background-color: #ee6410;
#   color: #f1f1f1;
# }
# #T_514ba_row14_col3, #T_514ba_row15_col3 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_514ba_row15_col0, #T_514ba_row22_col2, #T_514ba_row23_col1 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_514ba_row16_col2, #T_514ba_row31_col1, #T_514ba_row38_col0 {
#   background-color: #fd8f3e;
#   color: #f1f1f1;
# }
# #T_514ba_row16_col3, #T_514ba_row17_col3 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_514ba_row17_col1, #T_514ba_row28_col0, #T_514ba_row30_col2 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_514ba_row18_col0, #T_514ba_row19_col2, #T_514ba_row24_col1 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_514ba_row18_col3 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_514ba_row19_col1, #T_514ba_row24_col0, #T_514ba_row31_col2 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_514ba_row19_col3 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_514ba_row20_col0, #T_514ba_row25_col1, #T_514ba_row50_col2 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_514ba_row20_col3 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_514ba_row21_col1, #T_514ba_row25_col2, #T_514ba_row37_col0 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_514ba_row21_col2, #T_514ba_row36_col0, #T_514ba_row36_col1 {
#   background-color: #fb8735;
#   color: #f1f1f1;
# }
# #T_514ba_row21_col3 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_514ba_row22_col0, #T_514ba_row22_col1, #T_514ba_row33_col2 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_514ba_row22_col3 {
#   background-color: #ee6511;
#   color: #f1f1f1;
# }
# #T_514ba_row23_col0, #T_514ba_row42_col1, #T_514ba_row52_col2 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_514ba_row23_col3 {
#   background-color: #f26b15;
#   color: #f1f1f1;
# }
# #T_514ba_row24_col2, #T_514ba_row39_col0, #T_514ba_row49_col1 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_514ba_row24_col3 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_514ba_row25_col0, #T_514ba_row32_col1, #T_514ba_row41_col2 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_514ba_row25_col3 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_514ba_row26_col0, #T_514ba_row26_col2, #T_514ba_row29_col1 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_514ba_row26_col1, #T_514ba_row35_col2, #T_514ba_row44_col0 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_514ba_row26_col3 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_514ba_row27_col2, #T_514ba_row47_col0, #T_514ba_row51_col1 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_514ba_row27_col3 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_514ba_row28_col2, #T_514ba_row35_col0, #T_514ba_row54_col1 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_514ba_row28_col3 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_514ba_row29_col2, #T_514ba_row56_col1, #T_514ba_row61_col0 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_514ba_row29_col3 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_514ba_row30_col0, #T_514ba_row35_col1, #T_514ba_row47_col2 {
#   background-color: #fd9b50;
#   color: #000000;
# }
# #T_514ba_row30_col1, #T_514ba_row48_col0, #T_514ba_row51_col2 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_514ba_row30_col3 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_514ba_row31_col0, #T_514ba_row44_col1, #T_514ba_row54_col2 {
#   background-color: #fdba7f;
#   color: #000000;
# }
# #T_514ba_row31_col3 {
#   background-color: #fd9243;
#   color: #000000;
# }
# #T_514ba_row32_col0, #T_514ba_row33_col1, #T_514ba_row53_col2 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_514ba_row32_col2, #T_514ba_row39_col1, #T_514ba_row42_col0 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_514ba_row32_col3 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_514ba_row33_col0, #T_514ba_row34_col2, #T_514ba_row45_col1 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_514ba_row33_col3 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_514ba_row34_col0, #T_514ba_row34_col1, #T_514ba_row55_col2 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_514ba_row34_col3, #T_514ba_row35_col3 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_514ba_row36_col2, #T_514ba_row45_col0, #T_514ba_row53_col1, #T_514ba_row55_col0 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_514ba_row36_col3 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_514ba_row37_col1, #T_514ba_row56_col2, #T_514ba_row60_col0 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_514ba_row37_col2, #T_514ba_row41_col0, #T_514ba_row60_col1 {
#   background-color: #fedfc0;
#   color: #000000;
# }
# #T_514ba_row37_col3 {
#   background-color: #fdb271;
#   color: #000000;
# }
# #T_514ba_row38_col1, #T_514ba_row52_col0, #T_514ba_row61_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_514ba_row38_col2, #T_514ba_row47_col1, #T_514ba_row59_col

# %% [markdown]
# # Second 10 Worst Features

# %%
features_to_drop_2 = df_final_fe.index.to_list()[-10:]
features_to_drop_2
features_to_drop.extend(features_to_drop_2)
# Out:
# ['z__p20',
#  'y__p20',
#  'x__p20',
#  'x__p80',
#  'xyz__p10',
#  'y__amax',
#  'xyz__amax',
#  'z__p30',
#  'x__p99',
#  'x__p90']

# %%
trained_models = []
n_est_list = [800]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X.drop(columns=features_to_drop), y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_af1f9_row0_col3, #T_af1f9_row0_col6, #T_af1f9_row1_col4, #T_af1f9_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_af1f9_row0_col4, #T_af1f9_row0_col7, #T_af1f9_row2_col3, #T_af1f9_row2_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_af1f9_row0_col5, #T_af1f9_row0_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_af1f9_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.9%, transparent 27.9%);
# }
# #T_af1f9_row1_col3, #T_af1f9_row1_col6, #T_af1f9_row2_col4, #T_af1f9_row2_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_af1f9_row1_col5, #T_af1f9_row1_col8 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_af1f9_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_af1f9_row2_col5, #T_af1f9_row2_col8 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_af1f9_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_af1f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af1f9_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_af1f9_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_af1f9_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_af1f9_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_af1f9_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_af1f9_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_af1f9_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_af1f9_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_af1f9_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_af1f9_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af1f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af1f9_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_af1f9_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_af1f9_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_af1f9_row0_col3" class="data row0 col3" >0.994</td>
#       <td id="T_af1f9_row0_col4" class="data row0 col4" >0.011</td>
#       <td id="T_af1f9_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_af1f9_row0_col6" class="data row0 col6" >0.470</td>
#       <td id="T_af1f9_row0_col7" class="data row0 col7" >0.023</td>
#       <td id="T_af1f9_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_af1f9_row0_col9" class="data row0 col9" >72.4</td>
#     </tr>
#     <tr>
#       <th id="T_af1f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af1f9_row1_col0" class="data row1 col0" >LGBMClassifier</td>
#       <td id="T_af1f9_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_af1f9_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_af1f9_row1_col3" class="data row1 col3" >0.988</td>
#       <td id="T_af1f9_row1_col4" class="data row1 col4" >0.015</td>
#       <td id="T_af1f9_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_af1f9_row1_col6" class="data row1 col6" >0.242</td>
#       <td id="T_af1f9_row1_col7" class="data row1 col7" >0.217</td>
#       <td id="T_af1f9_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_af1f9_row1_col9" class="data row1 col9" >4.2</td>
#     </tr>
#     <tr>
#       <th id="T_af1f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af1f9_row2_col0" class="data row2 col0" >CatBoostClassifier</td>
#       <td id="T_af1f9_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_af1f9_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_af1f9_row2_col3" class="data row2 col3" >0.987</td>
#       <td id="T_af1f9_row2_col4" class="data row2 col4" >0.012</td>
#       <td id="T_af1f9_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_af1f9_row2_col6" class="data row2 col6" >0.163</td>
#       <td id="T_af1f9_row2_col7" class="data row2 col7" >0.061</td>
#       <td id="T_af1f9_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_af1f9_row2_col9" class="data row2 col9" >259.7</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_3dce7_row0_col0, #T_3dce7_row0_col2, #T_3dce7_row3_col1 {
#   background-color: #842904;
#   color: #f1f1f1;
# }
# #T_3dce7_row0_col1, #T_3dce7_row0_col3, #T_3dce7_row1_col0, #T_3dce7_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_3dce7_row1_col1, #T_3dce7_row2_col0, #T_3dce7_row4_col2, #T_3dce7_row4_col3 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_3dce7_row1_col2, #T_3dce7_row2_col1, #T_3dce7_row3_col0 {
#   background-color: #892b04;
#   color: #f1f1f1;
# }
# #T_3dce7_row1_col3, #T_3dce7_row2_col3 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_3dce7_row3_col2, #T_3dce7_row6_col1, #T_3dce7_row6_col3, #T_3dce7_row7_col3, #T_3dce7_row20_col0 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_3dce7_row3_col3 {
#   background-color: #902e04;
#   color: #f1f1f1;
# }
# #T_3dce7_row4_col0, #T_3dce7_row7_col1, #T_3dce7_row8_col2 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_3dce7_row4_col1, #T_3dce7_row5_col2, #T_3dce7_row7_col0 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_3dce7_row5_col0, #T_3dce7_row14_col1, #T_3dce7_row17_col2 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_3dce7_row5_col1, #T_3dce7_row10_col0, #T_3dce7_row15_col2 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_3dce7_row5_col3 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_3dce7_row6_col0, #T_3dce7_row8_col1, #T_3dce7_row12_col2 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_3dce7_row6_col2, #T_3dce7_row9_col1, #T_3dce7_row18_col0 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_3dce7_row7_col2, #T_3dce7_row12_col3, #T_3dce7_row16_col0, #T_3dce7_row17_col1 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_3dce7_row8_col0, #T_3dce7_row10_col1, #T_3dce7_row14_col2 {
#   background-color: #b93d02;
#   color: #f1f1f1;
# }
# #T_3dce7_row8_col3 {
#   background-color: #ae3903;
#   color: #f1f1f1;
# }
# #T_3dce7_row9_col0, #T_3dce7_row11_col2, #T_3dce7_row18_col1 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_3dce7_row9_col2, #T_3dce7_row13_col1, #T_3dce7_row29_col0 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_3dce7_row9_col3 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_3dce7_row10_col2, #T_3dce7_row12_col1, #T_3dce7_row26_col0 {
#   background-color: #de5005;
#   color: #f1f1f1;
# }
# #T_3dce7_row10_col3 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_3dce7_row11_col0, #T_3dce7_row11_col1, #T_3dce7_row23_col2 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_3dce7_row11_col3 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_3dce7_row12_col0, #T_3dce7_row22_col1, #T_3dce7_row30_col2 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_3dce7_row13_col0, #T_3dce7_row16_col2, #T_3dce7_row17_col3, #T_3dce7_row18_col3, #T_3dce7_row24_col1 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_3dce7_row13_col2, #T_3dce7_row16_col1, #T_3dce7_row19_col0 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_3dce7_row13_col3 {
#   background-color: #df5106;
#   color: #f1f1f1;
# }
# #T_3dce7_row14_col0, #T_3dce7_row25_col1, #T_3dce7_row44_col2 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_3dce7_row14_col3 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_3dce7_row15_col0, #T_3dce7_row19_col2, #T_3dce7_row21_col3, #T_3dce7_row26_col1 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_3dce7_row15_col1, #T_3dce7_row21_col0, #T_3dce7_row40_col2 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_3dce7_row15_col3, #T_3dce7_row16_col3 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_3dce7_row17_col0, #T_3dce7_row19_col1, #T_3dce7_row22_col2 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_3dce7_row18_col2, #T_3dce7_row45_col0, #T_3dce7_row50_col1 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_3dce7_row19_col3 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_3dce7_row20_col1, #T_3dce7_row27_col0, #T_3dce7_row46_col2 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_3dce7_row20_col2, #T_3dce7_row27_col1, #T_3dce7_row49_col0 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_3dce7_row20_col3 {
#   background-color: #f36f1a;
#   color: #f1f1f1;
# }
# #T_3dce7_row21_col1, #T_3dce7_row25_col0, #T_3dce7_row34_col2 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_3dce7_row21_col2, #T_3dce7_row23_col1, #T_3dce7_row33_col0 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_3dce7_row22_col0, #T_3dce7_row25_col3, #T_3dce7_row27_col2, #T_3dce7_row32_col1 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_3dce7_row22_col3 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_3dce7_row23_col0, #T_3dce7_row39_col1, #T_3dce7_row48_col2 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_3dce7_row23_col3, #T_3dce7_row24_col3 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_3dce7_row24_col0, #T_3dce7_row24_col2, #T_3dce7_row29_col1 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_3dce7_row25_col2, #T_3dce7_row32_col0, #T_3dce7_row38_col1 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_3dce7_row26_col2, #T_3dce7_row41_col1, #T_3dce7_row51_col0 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_3dce7_row26_col3, #T_3dce7_row27_col3 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_3dce7_row28_col0, #T_3dce7_row28_col1, #T_3dce7_row31_col2 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_3dce7_row28_col2, #T_3dce7_row44_col0, #T_3dce7_row46_col1, #T_3dce7_row51_col3 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_3dce7_row28_col3 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_3dce7_row29_col2, #T_3dce7_row34_col0, #T_3dce7_row51_col1 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_3dce7_row29_col3 {
#   background-color: #fd984b;
#   color: #000000;
# }
# #T_3dce7_row30_col0, #T_3dce7_row39_col2, #T_3dce7_row42_col1 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_3dce7_row30_col1, #T_3dce7_row34_col3, #T_3dce7_row36_col0, #T_3dce7_row51_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_3dce7_row30_col3 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_3dce7_row31_col0, #T_3dce7_row35_col1, #T_3dce7_row42_col2 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_3dce7_row31_col1, #T_3dce7_row41_col2, #T_3dce7_row42_col0, #T_3dce7_row44_col3, #T_3dce7_row45_col3, #T_3dce7_row46_col3 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_3dce7_row31_col3 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_3dce7_row32_col2, #T_3dce7_row36_col1, #T_3dce7_row39_col0 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_3dce7_row32_col3 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_3dce7_row33_col1, #T_3dce7_row37_col0, #T_3dce7_row38_col2 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_3dce7_row33_col2, #T_3dce7_row46_col0, #T_3dce7_row48_col1 {
#   background-color: #fee4ca;
#   color: #000000;
# }
# #T_3dce7_row33_col3 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_3dce7_row34_col1, #T_3dce7_row47_col2, #T_3dce7_row48_col0 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_3dce7_row35_col0, #T_3dce7_row40_col3, #T_3dce7_row47_col1, #T_3dce7_row50_col2 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_3dce7_row35_col2, #T_3dce7_row37_col1, #T_3dce7_row41_col0 {
#   background-color: #fd9d53;
#   color: #000000;
# }
# #T_3dce7_row35_col3 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_3dce7_row36_col2, #T_3dce7_row43_col0, #T_3dce7_row43_col1 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_3dce7_row36_col3, #T_3dce7_row37_col3 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_3dce7_row37_col2, #T_3dce7_row38_col0, #T_3dce7_row40_col1 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_3dce7_row38_col3 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_3dce7_row39_col3 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_3dce7_row40_col0, #T_3dce7_row49_col1, #T_3dce7_row49_col2 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_3dce7_row41_col3, #T_3dce7_row42_col3 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_3dce7_row43_col2, #T_3dce7_row44_col1, #T_3dce7_row50_col0 {
#   background-co

# %% [markdown]
# # Third 10 worst features

# %%
features_to_drop_3 = df_final_fe.index.to_list()[-10:]
features_to_drop_3
features_to_drop.extend(features_to_drop_3)
# Out:
# ['x__std',
#  'y__median',
#  'z__var',
#  'xyz__sum',
#  'y__iqr',
#  'xyz__p20',
#  'xyz__p30',
#  'y__p99',
#  'xyz__p01',
#  'z__p10']

# %%
trained_models = []
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X.drop(columns=features_to_drop), y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['ROC_AUC_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_a8931_row0_col3, #T_a8931_row0_col6, #T_a8931_row3_col4, #T_a8931_row4_col4, #T_a8931_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a8931_row0_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_a8931_row0_col5, #T_a8931_row0_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a8931_row0_col7, #T_a8931_row2_col6, #T_a8931_row5_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a8931_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.1%, transparent 25.1%);
# }
# #T_a8931_row1_col3, #T_a8931_row1_col6, #T_a8931_row3_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_a8931_row1_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a8931_row1_col5, #T_a8931_row1_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_a8931_row1_col7, #T_a8931_row5_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_a8931_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.7%, transparent 8.7%);
# }
# #T_a8931_row2_col3, #T_a8931_row2_col7, #T_a8931_row3_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_a8931_row2_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_a8931_row2_col5, #T_a8931_row3_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_a8931_row2_col8, #T_a8931_row5_col5 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_a8931_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_a8931_row3_col3, #T_a8931_row4_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_a8931_row3_col5, #T_a8931_row4_col5, #T_a8931_row5_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_a8931_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_a8931_row4_col6, #T_a8931_row5_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_a8931_row4_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_a8931_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.1%, transparent 1.1%);
# }
# #T_a8931_row5_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_a8931_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.9%, transparent 36.9%);
# }
# </style>
# <table id="T_a8931">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8931_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_a8931_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_a8931_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_a8931_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_a8931_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_a8931_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_a8931_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_a8931_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_a8931_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_a8931_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8931_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a8931_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_a8931_row0_col1" class="data row0 col1" >'n_estimators': 1600</td>
#       <td id="T_a8931_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_a8931_row0_col3" class="data row0 col3" >0.994</td>
#       <td id="T_a8931_row0_col4" class="data row0 col4" >0.009</td>
#       <td id="T_a8931_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_a8931_row0_col6" class="data row0 col6" >0.467</td>
#       <td id="T_a8931_row0_col7" class="data row0 col7" >0.019</td>
#       <td id="T_a8931_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_a8931_row0_col9" class="data row0 col9" >196.5</td>
#     </tr>
#     <tr>
#       <th id="T_a8931_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_a8931_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_a8931_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_a8931_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_a8931_row1_col3" class="data row1 col3" >0.994</td>
#       <td id="T_a8931_row1_col4" class="data row1 col4" >0.010</td>
#       <td id="T_a8931_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_a8931_row1_col6" class="data row1 col6" >0.465</td>
#       <td id="T_a8931_row1_col7" class="data row1 col7" >0.019</td>
#       <td id="T_a8931_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_a8931_row1_col9" class="data row1 col9" >68.1</td>
#     </tr>
#     <tr>
#       <th id="T_a8931_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_a8931_row2_col0" class="data row2 col0" >CatBoostClassifier</td>
#       <td id="T_a8931_row2_col1" class="data row2 col1" >'n_estimators': 1600</td>
#       <td id="T_a8931_row2_col2" class="data row2 col2" >50</td>
#       <td id="T_a8931_row2_col3" class="data row2 col3" >0.989</td>
#       <td id="T_a8931_row2_col4" class="data row2 col4" >0.011</td>
#       <td id="T_a8931_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_a8931_row2_col6" class="data row2 col6" >0.152</td>
#       <td id="T_a8931_row2_col7" class="data row2 col7" >0.058</td>
#       <td id="T_a8931_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_a8931_row2_col9" class="data row2 col9" >782.5</td>
#     </tr>
#     <tr>
#       <th id="T_a8931_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_a8931_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_a8931_row3_col1" class="data row3 col1" >'n_estimators': 800</td>
#       <td id="T_a8931_row3_col2" class="data row3 col2" >50</td>
#       <td id="T_a8931_row3_col3" class="data row3 col3" >0.989</td>
#       <td id="T_a8931_row3_col4" class="data row3 col4" >0.014</td>
#       <td id="T_a8931_row3_col5" class="data row3 col5" >2</td>
#       <td id="T_a8931_row3_col6" class="data row3 col6" >0.236</td>
#       <td id="T_a8931_row3_col7" class="data row3 col7" >0.209</td>
#       <td id="T_a8931_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_a8931_row3_col9" class="data row3 col9" >10.1</td>
#     </tr>
#     <tr>
#       <th id="T_a8931_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_a8931_row4_col0" class="data row4 col0" >LGBMClassifier</td>
#       <td id="T_a8931_row4_col1" class="data row4 col1" >'n_estimators': 1600</td>
#       <td id="T_a8931_row4_col2" class="data row4 col2" >50</td>
#       <td id="T_a8931_row4_col3" class="data row4 col3" >0.989</td>
#       <td id="T_a8931_row4_col4" class="data row4 col4" >0.014</td>
#       <td id="T_a8931_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_a8931_row4_col6" class="data row4 col6" >0.236</td>
#       <td id="T_a8931_row4_col7" class="data row4 col7" >0.209</td>
#       <td id="T_a8931_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_a8931_row4_col9" class="data row4 col9" >8.3</td>
#     </tr>
#     <tr>
#       <th id="T_a8931_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_a8931_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_a8931_row5_col1" class="data row5 col1" >'n_estimators': 800</td>
#       <td id="T_a8931_row5_col2" class="data row5 col2" >50</td>
#       <td id="T_a8931_row5_col3" class="data row5 col3" >0.989</td>
#       <td id="T_a8931_row5_col4" class="data row5 col4" >0.011</td>
#       <td id="T_a8931_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_a8931_row5_col6" class="data row5 col6" >0.154</td>
#       <td id="T_a8931_row5_col7" class="data row5 col7" >0.058</td>
#       <td id="T_a8931_row5_col8" class="data row5 col8" >2</td>
#       <td id="T_a8931_row5_col9" class="data row5 col9" >288.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe = m.get_fe_df(trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_a72dc_row0_col0, #T_a72dc_row0_col1, #T_a72dc_row0_col4, #T_a72dc_row0_col5, #T_a72dc_row3_col2, #T_a72dc_row3_col3 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_a72dc_row0_col2, #T_a72dc_row0_col3, #T_a72dc_row0_col6, #T_a72dc_row1_col0, #T_a72dc_row1_col1, #T_a72dc_row2_col4, #T_a72dc_row2_col5 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a72dc_row1_col2, #T_a72dc_row1_col3, #T_a72dc_row4_col4, #T_a72dc_row4_col5, #T_a72dc_row14_col0, #T_a72dc_row14_col1 {
#   background-color: #993103;
#   color: #f1f1f1;
# }
# #T_a72dc_row1_col4, #T_a72dc_row1_col5, #T_a72dc_row2_col2, #T_a72dc_row2_col3, #T_a72dc_row2_col6, #T_a72dc_row3_col0, #T_a72dc_row3_col1 {
#   background-color: #8b2c04;
#   color: #f1f1f1;
# }
# #T_a72dc_row1_col6 {
#   background-color: #892b04;
#   color: #f1f1f1;
# }
# #T_a72dc_row2_col0, #T_a72dc_row2_col1, #T_a72dc_row5_col3, #T_a72dc_row6_col2, #T_a72dc_row18_col4, #T_a72dc_row18_col5 {
#   background-color: #a03403;
#   color: #f1f1f1;
# }
# #T_a72dc_row3_col4, #T_a72dc_row4_col0, #T_a72dc_row4_col1, #T_a72dc_row5_col2, #T_a72dc_row5_col6, #T_a72dc_row7_col3, #T_a72dc_row8_col5 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_a72dc_row3_col5, #T_a72dc_row8_col4, #T_a72dc_row9_col2, #T_a72dc_row9_col3, #T_a72dc_row19_col0, #T_a72dc_row19_col1 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_a72dc_row3_col6 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_a72dc_row4_col2, #T_a72dc_row4_col3, #T_a72dc_row6_col4, #T_a72dc_row6_col5, #T_a72dc_row7_col0, #T_a72dc_row7_col1 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_a72dc_row4_col6 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_a72dc_row5_col0, #T_a72dc_row5_col1, #T_a72dc_row12_col4, #T_a72dc_row12_col5, #T_a72dc_row14_col2, #T_a72dc_row21_col3 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_a72dc_row5_col4, #T_a72dc_row5_col5, #T_a72dc_row6_col3, #T_a72dc_row7_col2, #T_a72dc_row10_col0, #T_a72dc_row10_col1 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_a72dc_row6_col0, #T_a72dc_row8_col2, #T_a72dc_row9_col4, #T_a72dc_row15_col3, #T_a72dc_row23_col5, #T_a72dc_row27_col1 {
#   background-color: #de4e05;
#   color: #f1f1f1;
# }
# #T_a72dc_row6_col1, #T_a72dc_row8_col3, #T_a72dc_row9_col0, #T_a72dc_row11_col2, #T_a72dc_row17_col4, #T_a72dc_row17_col5 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_a72dc_row6_col6 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_a72dc_row7_col4, #T_a72dc_row7_col5, #T_a72dc_row11_col0, #T_a72dc_row11_col1, #T_a72dc_row11_col3, #T_a72dc_row21_col2 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_a72dc_row7_col6 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_a72dc_row8_col0, #T_a72dc_row8_col1, #T_a72dc_row10_col2, #T_a72dc_row13_col4, #T_a72dc_row13_col5, #T_a72dc_row14_col3 {
#   background-color: #c94202;
#   color: #f1f1f1;
# }
# #T_a72dc_row8_col6 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_a72dc_row9_col1, #T_a72dc_row9_col5, #T_a72dc_row13_col3, #T_a72dc_row15_col2, #T_a72dc_row16_col0, #T_a72dc_row23_col4 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_a72dc_row9_col6 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_a72dc_row10_col3, #T_a72dc_row11_col4, #T_a72dc_row11_col5, #T_a72dc_row13_col2, #T_a72dc_row16_col1, #T_a72dc_row27_col0 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_a72dc_row10_col4, #T_a72dc_row15_col0, #T_a72dc_row15_col1, #T_a72dc_row15_col6, #T_a72dc_row16_col2, #T_a72dc_row16_col3, #T_a72dc_row16_col6, #T_a72dc_row30_col5 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_a72dc_row10_col5, #T_a72dc_row12_col2, #T_a72dc_row12_col3, #T_a72dc_row22_col0, #T_a72dc_row22_col1, #T_a72dc_row30_col4 {
#   background-color: #ee6511;
#   color: #f1f1f1;
# }
# #T_a72dc_row10_col6 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_a72dc_row11_col6 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_a72dc_row12_col0, #T_a72dc_row12_col1, #T_a72dc_row16_col4, #T_a72dc_row16_col5, #T_a72dc_row18_col2, #T_a72dc_row18_col3 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_a72dc_row12_col6 {
#   background-color: #ee6410;
#   color: #f1f1f1;
# }
# #T_a72dc_row13_col0, #T_a72dc_row19_col4, #T_a72dc_row19_col5, #T_a72dc_row21_col1, #T_a72dc_row26_col2, #T_a72dc_row26_col3 {
#   background-color: #fd9b50;
#   color: #000000;
# }
# #T_a72dc_row13_col1, #T_a72dc_row19_col2, #T_a72dc_row19_col3, #T_a72dc_row21_col0, #T_a72dc_row38_col4, #T_a72dc_row38_col5 {
#   background-color: #fda159;
#   color: #000000;
# }
# #T_a72dc_row13_col6 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_a72dc_row14_col4, #T_a72dc_row35_col1, #T_a72dc_row39_col2, #T_a72dc_row39_col3, #T_a72dc_row39_col5, #T_a72dc_row40_col0 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_a72dc_row14_col5, #T_a72dc_row31_col0, #T_a72dc_row33_col1, #T_a72dc_row39_col4, #T_a72dc_row41_col2, #T_a72dc_row41_col3 {
#   background-color: #fdcfa0;
#   color: #000000;
# }
# #T_a72dc_row14_col6 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_a72dc_row15_col4, #T_a72dc_row15_col5, #T_a72dc_row20_col2, #T_a72dc_row20_col3, #T_a72dc_row25_col0, #T_a72dc_row25_col1 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_a72dc_row17_col0, #T_a72dc_row21_col4, #T_a72dc_row21_col5, #T_a72dc_row31_col2, #T_a72dc_row31_col3, #T_a72dc_row32_col1 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_a72dc_row17_col1, #T_a72dc_row20_col4, #T_a72dc_row22_col6, #T_a72dc_row24_col2, #T_a72dc_row24_col3, #T_a72dc_row32_col0, #T_a72dc_row35_col5 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_a72dc_row17_col2, #T_a72dc_row17_col3, #T_a72dc_row24_col0, #T_a72dc_row24_col1, #T_a72dc_row34_col4, #T_a72dc_row34_col5 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_a72dc_row17_col6 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# #T_a72dc_row18_col0, #T_a72dc_row18_col1, #T_a72dc_row28_col4, #T_a72dc_row29_col2, #T_a72dc_row29_col3, #T_a72dc_row36_col5 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_a72dc_row18_col6 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_a72dc_row19_col6, #T_a72dc_row20_col5, #T_a72dc_row22_col2, #T_a72dc_row22_col3, #T_a72dc_row26_col0, #T_a72dc_row26_col1, #T_a72dc_row35_col4 {
#   background-color: #fa8331;
#   color: #f1f1f1;
# }
# #T_a72dc_row20_col0, #T_a72dc_row20_col1, #T_a72dc_row25_col2, #T_a72dc_row25_col3, #T_a72dc_row33_col4, #T_a72dc_row33_col5 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_a72dc_row20_col6 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_a72dc_row21_col6 {
#   background-color: #fb8735;
#   color: #f1f1f1;
# }
# #T_a72dc_row22_col4, #T_a72dc_row22_col5, #T_a72dc_row23_col2, #T_a72dc_row23_col3, #T_a72dc_row28_col0, #T_a72dc_row28_col1 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_a72dc_row23_col0, #T_a72dc_row23_col1, #T_a72dc_row26_col4, #T_a72dc_row30_col2, #T_a72dc_row30_col3, #T_a72dc_row40_col5 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_a72dc_row23_col6 {
#   background-color: #fd984b;
#   color: #000000;
# }
# #T_a72dc_row24_col4, #T_a72dc_row24_col5, #T_a72dc_row35_col0, #T_a72dc_row36_col6, #T_a72dc_row38_col2, #T_a72dc_row38_col3, #T_a72dc_row40_col1 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_a72dc_row24_col6 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_a72dc_row25_col4, #T_a72dc_row25_col5, #T_a72dc_row30_col0, #T_a72dc_row37_col2, #T_a72dc_row37_col3, #T_a72dc_row38_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_a72dc_row25_col6 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_a72dc_row26_col5, #T_a72dc_row36_col2, #T_a72dc_row36_col3, #T_a72dc_row40_col4, #T_a72dc_row41_col0, #T_a72dc_row41_col1 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_a72dc_row26_col6, #T_a72dc_row27_col6 {
#   background-color: #fdad69;
#   color: #000000;
# }
# #T_a72dc_row27_col2, #T_a72dc_row27_col3, #T_a72dc_row28_col5, #T_a72dc_row29_col0, #T_a72dc_row29_col1, #T_a72dc_row36_col4 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_a72dc_row27_col4, #T_a72dc_row30_col1, #T_a72dc_row32_col5, #T_a72dc_row35_col2, #T_a72dc_row35_co
