# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (1.6.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.8.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.1.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.0.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.5.2)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.10.0)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.4.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost) (1.8.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.0.1)

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport transformations

# %aimport transformations
# %aimport f
# Out:
# transformations loaded, version: 0.1
# framework loaded, version: 0.1

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113

import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.preprocessing import StandardScaler, PowerTransformer

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture

RS = 35577 # global random state seed
data_path = './data-raw/'

# %%
(X, y) = f.from_pkl(f'data-processed/all_b1_b2.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 36)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__q1', 'x__q3', 'x__iqr', 'x__kurtosis', 'x__skew',
#        'y__amin', 'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std',
#        'y__var', 'y__q1', 'y__q3', 'y__iqr', 'y__kurtosis', 'y__skew',
#        'z__amin', 'z__amax', 'z__sum', 'z__median', 'z__mean', 'z__std',
#        'z__var', 'z__q1', 'z__q3', 'z__iqr', 'z__kurtosis', 'z__skew'],
#       dtype='object')
# (200,)
# 1    100
# 0    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %%
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
import itertools

def grid_exec(func, *args):
    return [func(*element) for element in itertools.product(*args)]

def grid_exec_callback(func, callback, *args):
    return [ callback(func(*element)) for element in itertools.product(*args)]

# %%
all_trained_models = []

def cross_val(model_factory, X, y, cv_repeat_n = 1, model_repeat_n = 1, folds_n = 7):
    np.random.seed(RS)
    get_random = lambda  : np.random.randint(1, 10000)
    cv_scores = []
    
    for i_cv in range(cv_repeat_n):
        fold_scores = []
        cv_scores.append(fold_scores)
        
        for i_fold, (idx_train, idx_test) in enumerate(StratifiedKFold(n_splits=folds_n, shuffle=True, random_state=get_random()).split(X, y, y)):
            
            X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
            X_test, y_test = X.iloc[idx_test], y.iloc[idx_test]
            
            model_scores = []
            fold_scores.append(model_scores)

            for i_model in range(model_repeat_n):
                rand = get_random()
                constructor, params_dic = model_factory(rand)
                
                model = constructor(**params_dic)
                # model = model_factory(get_random())
                model.fit(X_train, y_train)
                
                all_trained_models.append(model)

                y_pred = model.predict_proba(X_test)[:, 1]
                score = roc_auc_score(y_test, y_pred)
                model_scores.append(score)
                
            model_name = model.__class__.__name__
            model_params = params_dic.copy()
                
    return model_name, model_params, cv_repeat_n, folds_n, model_repeat_n, np.array(cv_scores), model

# %%
def get_stats_df(cv_results):
    
    ret_list = []
    
    for result in cv_results:
        
        model_params = result[1]
        model_params.pop('random_state', None)
        stats_ = result[5]
        
        ret_list.append(
            {
                'model' : result[0],
                # '#' : None,
                '##' : None,
                'params' : str(model_params).strip('{').strip('}'),
                'cv_repeat_n' : result[2],
                'folds_n' : result[3],    
                'model_repeat_n' : result[4],

                'min': stats_.min(),
                'mean': stats_.mean(),
                'max': stats_.max(),
                'std': stats_.std(),

                'folds_mean_min': stats_.mean(axis=2).reshape(1,-1).min(),
                # 'folds_mean_mean': stats_.mean(axis=2).reshape(1,-1).mean(),
                'folds_mean_max': stats_.mean(axis=2).reshape(1,-1).max(),
                'folds_mean_std': stats_.mean(axis=2).reshape(1,-1).std(),
            })
    df = pd.DataFrame(ret_list)
    
    # df['#'] = df.groupby('model', group_keys=False).apply(
    #             lambda df: (df['mean'].rank(ascending = False) \
    #                       + df['min'].rank(ascending = False) \
    #                       + df['folds_mean_std'].rank(ascending = True)
    #                        ).rank()).astype(int)
    
    df['##'] = (df['mean'].rank(ascending = False) \
                      + df['min'].rank(ascending = False) \
                      + df['folds_mean_std'].rank(ascending = True)
                       ).rank().astype(int)
    
    return df

def display_stats(df_stats):
    display(df_stats.style.format('{:,.3f}', df_stats.columns[6:])\
        # .background_gradient(cmap='Oranges', subset='#', axis=0)\
        .background_gradient(cmap='Reds', subset='##', axis=0)\
        .background_gradient(cmap='Blues', subset=df_stats.columns[6:10], axis=0)\
        .background_gradient(cmap='Greens', subset=df_stats.columns[10:], axis=0))

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# ## First Run

# %%
KNeighborsClassifier

# %%
all_models = [
    lambda random_state: (DecisionTreeClassifier, {}),
    lambda random_state: (KNeighborsClassifier,   {}),

    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 600}),
    
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 500}),
    
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 500}),
    
    lambda random_state: (XGBClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (XGBClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (XGBClassifier, {'random_state':random_state, 'n_estimators': 500}),
    
    lambda random_state: (CatBoostClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (CatBoostClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (CatBoostClassifier, {'random_state':random_state, 'n_estimators': 500}),
]

grid_func = lambda factory, cv_repeat_n, model_repeat_n, folds_n: cross_val(factory, X, y, cv_repeat_n, model_repeat_n, folds_n)

all_trained_models.clear()
all_results = []
def on_1_completed(results):
    all_results.append(results)
    clear_output(wait=True)
    get_stats_df(all_results)
    display_stats(get_stats_df(all_results))
    
cv_repeat_list = [3]
model_repeat_list = [20]
folds_list = [5]

_ = grid_exec_callback(grid_func, on_1_completed, all_models, cv_repeat_list, model_repeat_list, folds_list)
# Out:
# <style type="text/css">
# #T_f65c3_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f65c3_row0_col6, #T_f65c3_row0_col7, #T_f65c3_row0_col8, #T_f65c3_row7_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f65c3_row0_col9, #T_f65c3_row2_col8, #T_f65c3_row3_col8, #T_f65c3_row4_col8, #T_f65c3_row5_col8, #T_f65c3_row6_col8, #T_f65c3_row7_col6, #T_f65c3_row7_col7, #T_f65c3_row7_col8, #T_f65c3_row8_col8, #T_f65c3_row9_col8, #T_f65c3_row10_col8, #T_f65c3_row11_col8, #T_f65c3_row12_col8, #T_f65c3_row13_col8, #T_f65c3_row14_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f65c3_row0_col10, #T_f65c3_row0_col11, #T_f65c3_row7_col12 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_f65c3_row0_col12, #T_f65c3_row2_col11, #T_f65c3_row3_col11, #T_f65c3_row4_col11, #T_f65c3_row5_col11, #T_f65c3_row6_col11, #T_f65c3_row7_col10, #T_f65c3_row7_col11, #T_f65c3_row8_col11, #T_f65c3_row9_col11, #T_f65c3_row10_col11, #T_f65c3_row11_col11, #T_f65c3_row12_col11, #T_f65c3_row13_col11, #T_f65c3_row14_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col1 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col6 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col7 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col8 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col9 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col10 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col11 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_f65c3_row1_col12 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_f65c3_row2_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_f65c3_row2_col6, #T_f65c3_row12_col6, #T_f65c3_row13_col6 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_f65c3_row2_col7, #T_f65c3_row4_col6 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_f65c3_row2_col9 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_f65c3_row2_col10 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_f65c3_row2_col12 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_f65c3_row3_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_f65c3_row3_col6 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_f65c3_row3_col7, #T_f65c3_row6_col6 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_f65c3_row3_col9 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f65c3_row3_col10 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_f65c3_row3_col12 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_f65c3_row4_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_f65c3_row4_col7 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_f65c3_row4_col9 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f65c3_row4_col10, #T_f65c3_row9_col10 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_f65c3_row4_col12 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_f65c3_row5_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_f65c3_row5_col6 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_f65c3_row5_col7, #T_f65c3_row8_col7 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_f65c3_row5_col9 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_f65c3_row5_col10 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_f65c3_row5_col12 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_f65c3_row6_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_f65c3_row6_col7, #T_f65c3_row9_col7, #T_f65c3_row10_col7 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_f65c3_row6_col9 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f65c3_row6_col10, #T_f65c3_row14_col10 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_f65c3_row6_col12 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_f65c3_row7_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f65c3_row8_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_f65c3_row8_col6, #T_f65c3_row12_col7, #T_f65c3_row13_col7 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_f65c3_row8_col9 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_f65c3_row8_col10 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_f65c3_row8_col12 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_f65c3_row9_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_f65c3_row9_col6 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_f65c3_row9_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f65c3_row9_col12 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_f65c3_row10_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_f65c3_row10_col6 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_f65c3_row10_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_f65c3_row10_col10 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_f65c3_row10_col12 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_f65c3_row11_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_f65c3_row11_col6 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_f65c3_row11_col7 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_f65c3_row11_col9 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_f65c3_row11_col10 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_f65c3_row11_col12 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_f65c3_row12_col1, #T_f65c3_row13_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_f65c3_row12_col9, #T_f65c3_row13_col9 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_f65c3_row12_col10, #T_f65c3_row13_col10 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_f65c3_row12_col12, #T_f65c3_row13_col12 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_f65c3_row14_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_f65c3_row14_col6 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_f65c3_row14_col7 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_f65c3_row14_col9 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_f65c3_row14_col12 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# </style>
# <table id="T_f65c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f65c3_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f65c3_level0_col1" class="col_heading level0 col1" >##</th>
#       <th id="T_f65c3_level0_col2" class="col_heading level0 col2" >params</th>
#       <th id="T_f65c3_level0_col3" class="col_heading level0 col3" >cv_repeat_n</th>
#       <th id="T_f65c3_level0_col4" class="col_heading level0 col4" >folds_n</th>
#       <th id="T_f65c3_level0_col5" class="col_heading level0 col5" >model_repeat_n</th>
#       <th id="T_f65c3_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_f65c3_level0_col7" class="col_heading level0 col7" >mean</th>
#       <th id="T_f65c3_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_f65c3_level0_col9" class="col_heading level0 col9" >std</th>
#       <th id="T_f65c3_level0_col10" class="col_heading level0 col10" >folds_mean_min</th>
#       <th id="T_f65c3_level0_col11" class="col_heading level0 col11" >folds_mean_max</th>
#       <th id="T_f65c3_level0_col12" class="col_heading level0 col12" >folds_mean_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f65c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f65c3_row0_col0" class="data row0 col0" >DecisionTreeClassifier</td>
#       <td id="T_f65c3_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_f65c3_row0_col2" class="data row0 col2" ></td>
#       <td id="T_f65c3_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_f65c3_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_f65c3_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_f65c3_row0_col6" class="data row0 col6" >0.725</td>
#       <td id="T_f65c3_row0_col7" class="data row0 col7" >0.855</td>
#       <td id="T_f65c3_row0_col8" class="data row0 col8" >0.975</td>
#       <td id="T_f65c3_row0_col9" class="data row0 col9"
# Learning rate set to 0.020609
# 0:	learn: 0.6750262	total: 2.64ms	remaining: 525ms
# 1:	learn: 0.6546799	total: 4.37ms	remaining: 432ms
# 2:	learn: 0.6332955	total: 8.12ms	remaining: 534ms
# 3:	learn: 0.6108807	total: 9.91ms	remaining: 486ms
# 4:	learn: 0.5927722	total: 11.4ms	remaining: 446ms
# 5:	learn: 0.5730431	total: 13.5ms	remaining: 437ms
# 6:	learn: 0.5601833	total: 15ms	remaining: 414ms
# 7:	learn: 0.5445139	total: 17.3ms	remaining: 416ms
# 8:	learn: 0.5262256	total: 19.2ms	remaining: 408ms
# 9:	learn: 0.5093603	total: 21.2ms	remaining: 403ms
# 10:	learn: 0.4963978	total: 22.7ms	remaining: 391ms
# 11:	learn: 0.4813488	total: 25.2ms	remaining: 396ms
# 12:	learn: 0.4657825	total: 27.4ms	remaining: 394ms
# 13:	learn: 0.4514323	total: 30.1ms	remaining: 399ms
# 14:	learn: 0.4369101	total: 32ms	remaining: 395ms
# 15:	learn: 0.4223847	total: 33.6ms	remaining: 386ms
# 16:	learn: 0.4137528	total: 35.2ms	remaining: 379ms
# 17:	learn: 0.3998520	total: 36.7ms	remaining: 371ms
# 18:	learn: 0.3889842	total: 38.2ms	remaining: 364ms
# 19:	learn: 0.3790095	total: 40ms	remaining: 360ms
# 20:	learn: 0.3700515	total: 41.8ms	remaining: 356ms
# 21:	learn: 0.3591831	total: 43.5ms	remaining: 352ms
# 22:	learn: 0.3492649	total: 45.9ms	remaining: 353ms
# 23:	learn: 0.3405963	total: 48.7ms	remaining: 357ms
# 24:	learn: 0.3312084	total: 50.4ms	remaining: 353ms
# 199:	learn: 0.0297075	total: 484ms	remaining: 0us
# Learning rate set to 0.020609

# %% [markdown]
# ## Shortlist models

# %% [markdown]
# ## Shortlist based on [model_repeat_n]

# %%
all_models = [
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 400}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 800}),
    
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 400}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 800}),
    
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 100}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 300}),
]

grid_func = lambda factory, cv_repeat_n, model_repeat_n, folds_n: cross_val(factory, X, y, cv_repeat_n, model_repeat_n, folds_n)

all_trained_models.clear()
all_results = []
def on_1_completed(results):
    all_results.append(results)
    clear_output(wait=True)
    get_stats_df(all_results)
    display_stats(get_stats_df(all_results))
    
cv_repeat_list = [2]
model_repeat_list = [1, 5, 15, 30]
folds_list = [5]

_ = grid_exec_callback(grid_func, on_1_completed, all_models, cv_repeat_list, model_repeat_list, folds_list)
# Out:
# <style type="text/css">
# #T_422ce_row0_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_422ce_row0_col6, #T_422ce_row4_col6, #T_422ce_row24_col6, #T_422ce_row25_col6, #T_422ce_row33_col6 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_422ce_row0_col7, #T_422ce_row20_col9 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_422ce_row0_col8, #T_422ce_row1_col8, #T_422ce_row2_col8, #T_422ce_row3_col7, #T_422ce_row3_col8, #T_422ce_row4_col8, #T_422ce_row5_col8, #T_422ce_row6_col8, #T_422ce_row7_col8, #T_422ce_row8_col8, #T_422ce_row9_col8, #T_422ce_row10_col8, #T_422ce_row11_col8, #T_422ce_row12_col8, #T_422ce_row13_col8, #T_422ce_row14_col8, #T_422ce_row15_col8, #T_422ce_row16_col8, #T_422ce_row17_col8, #T_422ce_row18_col8, #T_422ce_row19_col8, #T_422ce_row20_col8, #T_422ce_row21_col8, #T_422ce_row21_col9, #T_422ce_row22_col8, #T_422ce_row23_col8, #T_422ce_row24_col8, #T_422ce_row25_col8, #T_422ce_row26_col8, #T_422ce_row27_col6, #T_422ce_row27_col8, #T_422ce_row28_col8, #T_422ce_row29_col8, #T_422ce_row30_col8, #T_422ce_row31_col8, #T_422ce_row32_col8, #T_422ce_row33_col8, #T_422ce_row34_col8, #T_422ce_row35_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_422ce_row0_col9 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_422ce_row0_col10, #T_422ce_row4_col10, #T_422ce_row24_col10, #T_422ce_row25_col10, #T_422ce_row33_col10 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_422ce_row0_col11, #T_422ce_row1_col11, #T_422ce_row2_col11, #T_422ce_row4_col11, #T_422ce_row5_col11, #T_422ce_row6_col11, #T_422ce_row7_col11, #T_422ce_row8_col11, #T_422ce_row9_col11, #T_422ce_row10_col11, #T_422ce_row11_col11, #T_422ce_row12_col11, #T_422ce_row13_col11, #T_422ce_row14_col11, #T_422ce_row15_col11, #T_422ce_row16_col11, #T_422ce_row17_col11, #T_422ce_row18_col11, #T_422ce_row19_col11, #T_422ce_row20_col11, #T_422ce_row21_col10, #T_422ce_row21_col11, #T_422ce_row22_col11, #T_422ce_row23_col11, #T_422ce_row24_col11, #T_422ce_row25_col11, #T_422ce_row26_col11, #T_422ce_row27_col11, #T_422ce_row27_col12, #T_422ce_row28_col11, #T_422ce_row29_col11, #T_422ce_row30_col11, #T_422ce_row31_col11, #T_422ce_row32_col11, #T_422ce_row33_col11, #T_422ce_row34_col11, #T_422ce_row35_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_422ce_row0_col12 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_422ce_row1_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_422ce_row1_col6, #T_422ce_row14_col6, #T_422ce_row34_col6 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_422ce_row1_col7, #T_422ce_row5_col7 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_422ce_row1_col9 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_422ce_row1_col10, #T_422ce_row8_col10 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_422ce_row1_col12, #T_422ce_row2_col10 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_422ce_row2_col1 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_422ce_row2_col6, #T_422ce_row31_col6, #T_422ce_row35_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_422ce_row2_col7 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_422ce_row2_col9 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_422ce_row2_col12 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_422ce_row3_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_422ce_row3_col6 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_422ce_row3_col9, #T_422ce_row9_col6, #T_422ce_row18_col6, #T_422ce_row19_col6, #T_422ce_row20_col6, #T_422ce_row22_col6, #T_422ce_row30_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_422ce_row3_col10, #T_422ce_row11_col10, #T_422ce_row30_col12 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_422ce_row3_col11, #T_422ce_row21_col12, #T_422ce_row27_col10 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_422ce_row3_col12 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_422ce_row4_col1, #T_422ce_row16_col1 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_422ce_row4_col7 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_422ce_row4_col9 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_422ce_row4_col12 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_422ce_row5_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_422ce_row5_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_422ce_row5_col9 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_422ce_row5_col10, #T_422ce_row9_col10 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_422ce_row5_col12 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_422ce_row6_col1 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_422ce_row6_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_422ce_row6_col7 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_422ce_row6_col9, #T_422ce_row24_col7 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_422ce_row6_col10 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_422ce_row6_col12 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_422ce_row7_col1 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_422ce_row7_col6 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_422ce_row7_col7, #T_422ce_row11_col7 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_422ce_row7_col9 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_422ce_row7_col10, #T_422ce_row12_col10, #T_422ce_row23_col10 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_422ce_row7_col12 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_422ce_row8_col1 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_422ce_row8_col6, #T_422ce_row33_col7 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_422ce_row8_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_422ce_row8_col9, #T_422ce_row22_col9 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_422ce_row8_col12, #T_422ce_row22_col12 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_422ce_row9_col1 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_422ce_row9_col7 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_422ce_row9_col9 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_422ce_row9_col12 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_422ce_row10_col1 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_422ce_row10_col6 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_422ce_row10_col7 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_422ce_row10_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_422ce_row10_col10 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_422ce_row10_col12 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_422ce_row11_col1 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_422ce_row11_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_422ce_row11_col9 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_422ce_row11_col12 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_422ce_row12_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_422ce_row12_col6, #T_422ce_row23_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_422ce_row12_col7 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_422ce_row12_col9 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_422ce_row12_col12 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_422ce_row13_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_422ce_row13_col6, #T_422ce_row26_col6, #T_422ce_row28_col6, #T_422ce_row32_col6 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_422ce_row13_col7 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_422ce_row13_col9 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_422ce_row13_col10, #T_422ce_row26_col10, #T_422ce_row28_col10, #T_422ce_row32_col10 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_422ce_row13_col12 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_422ce_row14_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_422ce_row14_col7 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_42

# %% [markdown]
# ## Shortlist based on [model_repeat_n] v2

# %%
all_models = [
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 400}),
    
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 400}),
    
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 200}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 300}),
]

grid_func = lambda factory, cv_repeat_n, model_repeat_n, folds_n: cross_val(factory, X, y, cv_repeat_n, model_repeat_n, folds_n)

all_trained_models.clear()
all_results = []
def on_1_completed(results):
    all_results.append(results)
    clear_output(wait=True)
    get_stats_df(all_results)
    display_stats(get_stats_df(all_results))
    
cv_repeat_list = [3]
model_repeat_list = [30, 60, 90]
folds_list = [5]

_ = grid_exec_callback(grid_func, on_1_completed, all_models, cv_repeat_list, model_repeat_list, folds_list)
# Out:
# <style type="text/css">
# #T_2e3d5_row0_col1 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_2e3d5_row0_col6, #T_2e3d5_row17_col7 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_2e3d5_row0_col7, #T_2e3d5_row0_col8, #T_2e3d5_row1_col8, #T_2e3d5_row2_col8, #T_2e3d5_row3_col7, #T_2e3d5_row3_col8, #T_2e3d5_row4_col8, #T_2e3d5_row5_col8, #T_2e3d5_row6_col8, #T_2e3d5_row7_col8, #T_2e3d5_row8_col8, #T_2e3d5_row9_col8, #T_2e3d5_row9_col9, #T_2e3d5_row10_col8, #T_2e3d5_row11_col8, #T_2e3d5_row12_col6, #T_2e3d5_row12_col8, #T_2e3d5_row13_col8, #T_2e3d5_row14_col8, #T_2e3d5_row15_col6, #T_2e3d5_row15_col8, #T_2e3d5_row16_col8, #T_2e3d5_row17_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2e3d5_row0_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_2e3d5_row0_col10 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_2e3d5_row0_col11, #T_2e3d5_row9_col12, #T_2e3d5_row12_col10, #T_2e3d5_row15_col10 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2e3d5_row0_col12, #T_2e3d5_row2_col12 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_2e3d5_row1_col1 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_2e3d5_row1_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_2e3d5_row1_col7 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_2e3d5_row1_col9 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_2e3d5_row1_col10 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_2e3d5_row1_col11, #T_2e3d5_row3_col11, #T_2e3d5_row4_col11, #T_2e3d5_row5_col11, #T_2e3d5_row6_col11, #T_2e3d5_row7_col11, #T_2e3d5_row8_col11, #T_2e3d5_row9_col11, #T_2e3d5_row10_col11, #T_2e3d5_row11_col11, #T_2e3d5_row12_col11, #T_2e3d5_row13_col10, #T_2e3d5_row13_col11, #T_2e3d5_row14_col11, #T_2e3d5_row14_col12, #T_2e3d5_row15_col11, #T_2e3d5_row16_col10, #T_2e3d5_row16_col11, #T_2e3d5_row17_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2e3d5_row1_col12 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_2e3d5_row2_col1 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_2e3d5_row2_col6, #T_2e3d5_row2_col7, #T_2e3d5_row3_col6, #T_2e3d5_row10_col6, #T_2e3d5_row17_col6 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_2e3d5_row2_col9 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_2e3d5_row2_col10 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2e3d5_row2_col11, #T_2e3d5_row9_col10 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_2e3d5_row3_col1 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_2e3d5_row3_col9 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_2e3d5_row3_col10 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_2e3d5_row3_col12 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_2e3d5_row4_col1 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_2e3d5_row4_col6, #T_2e3d5_row6_col6 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_2e3d5_row4_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_2e3d5_row4_col9 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_2e3d5_row4_col10 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_2e3d5_row4_col12 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_2e3d5_row5_col1 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_2e3d5_row5_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_2e3d5_row5_col7, #T_2e3d5_row16_col9 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_2e3d5_row5_col9 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_2e3d5_row5_col10 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_2e3d5_row5_col12 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_2e3d5_row6_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_2e3d5_row6_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_2e3d5_row6_col9 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_2e3d5_row6_col10 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2e3d5_row6_col12 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_2e3d5_row7_col1 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_2e3d5_row7_col6, #T_2e3d5_row11_col6, #T_2e3d5_row14_col6 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_2e3d5_row7_col7 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_2e3d5_row7_col9 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_2e3d5_row7_col10, #T_2e3d5_row14_col10 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_2e3d5_row7_col12 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_2e3d5_row8_col1 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_2e3d5_row8_col6 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_2e3d5_row8_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_2e3d5_row8_col9 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_2e3d5_row8_col10 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_2e3d5_row8_col12 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_2e3d5_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2e3d5_row9_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_2e3d5_row9_col7, #T_2e3d5_row13_col6, #T_2e3d5_row14_col9, #T_2e3d5_row16_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2e3d5_row10_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_2e3d5_row10_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_2e3d5_row10_col9 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_2e3d5_row10_col10 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_2e3d5_row10_col12 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_2e3d5_row11_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_2e3d5_row11_col7, #T_2e3d5_row16_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_2e3d5_row11_col9 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_2e3d5_row11_col10 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_2e3d5_row11_col12 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_2e3d5_row12_col1 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_2e3d5_row12_col7 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_2e3d5_row12_col9 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_2e3d5_row12_col12 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_2e3d5_row13_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_2e3d5_row13_col7 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_2e3d5_row13_col9 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_2e3d5_row13_col12 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_2e3d5_row14_col1 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_2e3d5_row14_col7 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_2e3d5_row15_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2e3d5_row15_col7 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_2e3d5_row15_col9 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_2e3d5_row15_col12 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_2e3d5_row16_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_2e3d5_row16_col12 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_2e3d5_row17_col1 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_2e3d5_row17_col9 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_2e3d5_row17_col10 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_2e3d5_row17_col12 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e3d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e3d5_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_2e3d5_level0_col1" class="col_heading level0 col1" >##</th>
#       <th id="T_2e3d5_level0_col2" class="col_heading level0 col2" >params</th>
#       <th id="T_2e3d5_level0_col3" class="col_heading level0 col3" >cv_repeat_n</th>
#       <th id="T_2e3d5_level0_col4" class="col_heading level0 col4" >folds_n</th>
#       <th id="T_2e3d5_level0_col5" class="col_heading level0 col5" >model_repeat_n</th>
#       <th id="T_2e3d5_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_2e3d5_level0_col7" class="col_heading level0 col7" >m

# %% [markdown]
# ## Shortlist based on [cv_repeat_n]

# %% [markdown]
# ## Shortlist based on [folds_n]

# %% [markdown]
# ## Shortlist

# %%
all_models = [
    # lambda random_state: (DecisionTreeClassifier, {}),
    # lambda random_state: (KNeighborsClassifier,   {}),

    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 20}),
    # lambda random_state: (RandomForestClassifier, {'random_state':random_state, 'n_estimators': 600}),
    
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 20}),
    # lambda random_state: (AdaBoostClassifier, {'random_state':random_state, 'n_estimators': 600}),
    
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 50}),
    lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 20}),
    # lambda random_state: (LGBMClassifier, {'random_state':random_state, 'n_estimators': 600}),
]
    # lambda random_state: (XGBClassifier,          {'random_state':random_state}),

grid_func = lambda factory, cv_repeat_n, model_repeat_n, folds_n: cross_val(factory, X, y, cv_repeat_n, model_repeat_n, folds_n)

all_trained_models.clear()
all_results = []
def on_1_completed(results):
    all_results.append(results)
    clear_output(wait=True)
    get_stats_df(all_results)
    display_stats(get_stats_df(all_results))

# %%
cv_repeat_list = [1]
model_repeat_list = [1]
folds_list = [3]

_ = grid_exec_callback(grid_func, on_1_completed, all_models, cv_repeat_list, model_repeat_list, folds_list)

# %%
all_trained_models

# %%
m = all_trained_models[0]
pd.Series(data = m.feature_importances_, index = m.feature_names_in_).sort_values(ascending=False)

m = all_trained_models[6]
pd.Series(data = m.feature_importances_, index = m.feature_names_in_).sort_values(ascending=False)

m = all_trained_models[12]
pd.Series(data = m.feature_importances_, index = m.feature_name_).sort_values(ascending=False)

# %%
all_fe = []

for m in all_trained_models:
    if 'feature_names_in_' in m.__dict__.keys():
        all_fe.append(
            pd.Series(data = m.feature_importances_, index = m.feature_names_in_).rank().astype(int)
        )
    else:
        all_fe.append(
            pd.Series(data = m.feature_importances_, index = m.feature_name_).rank().astype(int)
        )

fe = pd.concat(all_fe, axis=1).sort_values(by=[0, 1, 2], ascending=False).head(15)
fe

# %%
all_fe = []

for i, m in enumerate(all_trained_models):
    if 'feature_names_in_' in m.__dict__.keys():
        all_fe.append(
            pd.Series(data = m.feature_importances_, index = m.feature_names_in_, name=f'{m.__class__.__name__[0]}_{i}')#.rank().astype(int)
        )
    else:
        all_fe.append(
            pd.Series(data = m.feature_importances_, index = m.feature_name_, name=f'{m.__class__.__name__[0]}_{i}')
        )

fe = pd.concat(all_fe, axis=1)
fe['sum_1'] = fe.iloc[:, :6].sum(axis=1)
fe['sum_2'] = fe.iloc[:, 6:12].sum(axis=1)
fe['sum_3'] = fe.iloc[:, 12:].sum(axis=1)
fe.sort_values(by=['sum_1', 'sum_2', 'sum_3'], ascending=False)\
    .round(2)\
    .style\
    .format('{:,.2f}', subset=fe.columns[:12])\
    .format('{:,.2f}', subset=fe.columns[-3:])\
    .highlight_max(color='green')\
    .highlight_min(color='blue')\
    .highlight_max(color='red', subset=['sum_1', 'sum_2', 'sum_3'])
