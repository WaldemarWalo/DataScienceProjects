# %% [markdown]
# # Setup and Imports

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

# %%
df_data = t.from_pkl(f'{processed_data_path}/df_clean.pkl')

df_data.shape
df_data.head(3)
# Out:
# (97323, 8)
#    make model  year  price transmission  mileage fuelType  engineSize
# 0  Audi    A1  2017  12500       Manual    15735   Petrol         1.4
# 1  Audi    A6  2016  16500    Automatic    36203   Diesel         2.0
# 2  Audi    A1  2016  11000       Manual    29946   Petrol         1.4

# %%
df_data.insert(0, 'car', df_data['make'] + '__' + df_data['model'])
df_data = df_data.drop(columns=['make', 'model'])

# %%
df_data.groupby(['car']).size().sort_values(ascending=False).head(10)
# Out:
# car
# Ford__Fiesta       6508
# Vw__Golf           4769
# Ford__Focus        4555
# Merc__C Class      3689
# Vauxhall__Corsa    3285
# Vw__Polo           3230
# Vauxhall__Astra    2655
# Merc__A Class      2474
# Bmw__3 Series      2413
# Ford__Kuga         2208
# dtype: int64

# %%
df_fiesta = df_data.loc[ (df_data['car'] == 'Ford__Fiesta') ].drop(columns=['car']).copy()
df_fiesta.head(3)
# Out:
#        year  price transmission  mileage fuelType  engineSize
# 21449  2017  12000    Automatic    15944   Petrol         1.0
# 21452  2019  17500       Manual    10460   Petrol         1.5
# 21453  2019  16500    Automatic     1482   Petrol         1.0

# %%
mileage_5k = ((df_fiesta['mileage'] / 5000).round(0) * 5000).astype(int)
df_fiesta_grp = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_5k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
df_fiesta_grp.columns = [c[1] for c in df_fiesta_grp.columns]

'mean group size: ', df_fiesta_grp['len'].mean()
'price mad in 5k groups: ', df_fiesta_grp['mad'].mean()
'price std in 5k groups: ', df_fiesta_grp['std'].mean()
# Out:
# ('mean group size: ', 10.446227929373997)
# ('price mad in 5k groups: ', 323.66491789552254)
# ('price std in 5k groups: ', 701.2696209252479)

# %%
mileage_10k = ((df_fiesta['mileage'] / 10000).round(0) * 10000).astype(int)
df_fiesta_grp = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_10k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
df_fiesta_grp.columns = [c[1] for c in df_fiesta_grp.columns]

'mean group size: ', df_fiesta_grp['len'].mean()
'price mad in 10k groups: ', df_fiesta_grp['mad'].mean()
'price std in 10k groups: ', df_fiesta_grp['std'].mean()
# Out:
# ('mean group size: ', 15.349056603773585)
# ('price mad in 10k groups: ', 343.64691608968064)
# ('price std in 10k groups: ', 729.4423273421423)

# %% [markdown]
# # Encode

# %%
m.ordinalEncode(df_fiesta, ['transmission', 'fuelType'])
df_fiesta
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0
# 21454  2015  10500             1    35432         1         1.6
# 21456  2017   9000             1    13054         1         1.2
# ...     ...    ...           ...      ...       ...         ...
# 39394  2019  15999             1     2813         1         1.0
# 39395  2015   8999             1    24546         1         1.0
# 39401  2017   9899             0    16303         1         1.0
# 39404  2018  12500             0     7047         1         1.0
# 39409  2016   7999             1    31348         1         1.2
#
# [6508 rows x 6 columns]

# %% [markdown]
# ## minmax

# %% [markdown]
# # X y

# %%
df_train = df_fiesta
df_train.head(3)

from sklearn.preprocessing import minmax_scale, scale
df_train = pd.DataFrame(data = scale(minmax_scale(df_fiesta)), columns = df_fiesta.columns)

df_train.head(3)
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0
#        year     price  transmission   mileage  fuelType  engineSize
# 0  0.102000  0.625971     -3.791209 -0.354737  0.252824   -0.527712
# 1  1.110838  2.529589     -0.056243 -0.692438  0.252824    2.165051
# 2  1.110838  2.183476     -3.791209 -1.245298  0.252824   -0.527712

# %%
X, y  = df_train.drop(columns='price'), df_train['price']

y.shape
X.shape
X.columns
X.head(2)
# Out:
# (6508,)
# (6508, 5)
# Index(['year', 'transmission', 'mileage', 'fuelType', 'engineSize'], dtype='object')
#        year  transmission   mileage  fuelType  engineSize
# 0  0.102000     -3.791209 -0.354737  0.252824   -0.527712
# 1  1.110838     -0.056243 -0.692438  0.252824    2.165051

# %% [markdown]
# # Train model

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# ## Linear Models

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import minmax_scale, normalize, scale, PolynomialFeatures

# %%
models_and_params = [
        (LinearRegression, {}),
        (Lasso, {'random_state': RS}),
        (Ridge, {'random_state': RS}),
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_9949c_row0_col3, #T_9949c_row0_col4, #T_9949c_row0_col6, #T_9949c_row0_col7, #T_9949c_row0_col9, #T_9949c_row0_col10 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9949c_row0_col5, #T_9949c_row0_col8, #T_9949c_row0_col11 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_9949c_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.3%, transparent 81.3%);
# }
# #T_9949c_row1_col3, #T_9949c_row1_col4, #T_9949c_row1_col6, #T_9949c_row1_col7, #T_9949c_row1_col10, #T_9949c_row2_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9949c_row1_col5, #T_9949c_row1_col8, #T_9949c_row1_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_9949c_row1_col9, #T_9949c_row2_col3, #T_9949c_row2_col4, #T_9949c_row2_col6, #T_9949c_row2_col7, #T_9949c_row2_col10 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_9949c_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.3%, transparent 78.3%);
# }
# #T_9949c_row2_col5, #T_9949c_row2_col8, #T_9949c_row2_col11 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_9949c_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_9949c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9949c_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_9949c_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_9949c_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_9949c_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_9949c_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_9949c_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_9949c_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_9949c_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_9949c_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_9949c_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_9949c_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_9949c_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_9949c_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9949c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9949c_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_9949c_row0_col1" class="data row0 col1" ></td>
#       <td id="T_9949c_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_9949c_row0_col3" class="data row0 col3" >0.440</td>
#       <td id="T_9949c_row0_col4" class="data row0 col4" >0.042</td>
#       <td id="T_9949c_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_9949c_row0_col6" class="data row0 col6" >0.588</td>
#       <td id="T_9949c_row0_col7" class="data row0 col7" >0.070</td>
#       <td id="T_9949c_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_9949c_row0_col9" class="data row0 col9" >0.627</td>
#       <td id="T_9949c_row0_col10" class="data row0 col10" >0.037</td>
#       <td id="T_9949c_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_9949c_row0_col12" class="data row0 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_9949c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9949c_row1_col0" class="data row1 col0" >Lasso</td>
#       <td id="T_9949c_row1_col1" class="data row1 col1" ></td>
#       <td id="T_9949c_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_9949c_row1_col3" class="data row1 col3" >0.775</td>
#       <td id="T_9949c_row1_col4" class="data row1 col4" >0.103</td>
#       <td id="T_9949c_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_9949c_row1_col6" class="data row1 col6" >1.010</td>
#       <td id="T_9949c_row1_col7" class="data row1 col7" >0.130</td>
#       <td id="T_9949c_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_9949c_row1_col9" class="data row1 col9" >-0.096</td>
#       <td id="T_9949c_row1_col10" class="data row1 col10" >0.097</td>
#       <td id="T_9949c_row1_col11" class="data row1 col11" >3</td>
#       <td id="T_9949c_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_9949c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9949c_row2_col0" class="data row2 col0" >Ridge</td>
#       <td id="T_9949c_row2_col1" class="data row2 col1" ></td>
#       <td id="T_9949c_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_9949c_row2_col3" class="data row2 col3" >0.440</td>
#       <td id="T_9949c_row2_col4" class="data row2 col4" >0.042</td>
#       <td id="T_9949c_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_9949c_row2_col6" class="data row2 col6" >0.588</td>
#       <td id="T_9949c_row2_col7" class="data row2 col7" >0.070</td>
#       <td id="T_9949c_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_9949c_row2_col9" class="data row2 col9" >0.628</td>
#       <td id="T_9949c_row2_col10" class="data row2 col10" >0.037</td>
#       <td id="T_9949c_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_9949c_row2_col12" class="data row2 col12" >0.1</td>
#     </tr>
#   </tbody>
# </table>

# %%
def booger_aids(X, y):
    models_and_params = [
        (LinearRegression, {}),
        # (Lasso, {'random_state': RS}),
        # (Ridge, {'random_state': RS}),
    ]
    cv = KFold(5)
    metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

    r = t.grid_exec(
        lambda model: m.cv_regression(model, cv, X, y, metrics), 
        models_and_params,
    )
    return r

# %% [markdown]
# ### Poly

# %%
all_r = []
for i in range(7):
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)
# Out:
# <style type="text/css">
# #T_28094_row0_col3, #T_28094_row3_col4, #T_28094_row3_col6, #T_28094_row3_col7, #T_28094_row3_col9, #T_28094_row3_col10 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_28094_row0_col4, #T_28094_row0_col6, #T_28094_row2_col7, #T_28094_row2_col10, #T_28094_row3_col3, #T_28094_row5_col9 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_28094_row0_col5, #T_28094_row3_col8, #T_28094_row3_col11 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_28094_row0_col7, #T_28094_row0_col10, #T_28094_row1_col3, #T_28094_row2_col4, #T_28094_row2_col6, #T_28094_row4_col9 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_28094_row0_col8, #T_28094_row3_col5, #T_28094_row5_col11 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_28094_row0_col9, #T_28094_row5_col3, #T_28094_row5_col4, #T_28094_row5_col6, #T_28094_row5_col7, #T_28094_row5_col10 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_28094_row0_col11, #T_28094_row5_col5, #T_28094_row5_col8 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_28094_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_28094_row1_col4, #T_28094_row1_col6, #T_28094_row1_col7, #T_28094_row1_col10, #T_28094_row2_col3, #T_28094_row6_col9 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_28094_row1_col5, #T_28094_row2_col8, #T_28094_row4_col11 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_28094_row1_col8, #T_28094_row2_col5, #T_28094_row6_col11 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_28094_row1_col9, #T_28094_row6_col3, #T_28094_row6_col4, #T_28094_row6_col6, #T_28094_row6_col7, #T_28094_row6_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_28094_row1_col11, #T_28094_row6_col5, #T_28094_row6_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_28094_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.0%, transparent 3.0%);
# }
# #T_28094_row2_col9, #T_28094_row4_col3, #T_28094_row4_col4, #T_28094_row4_col6, #T_28094_row4_col7, #T_28094_row4_col10 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_28094_row2_col11, #T_28094_row4_col5, #T_28094_row4_col8 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_28094_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.6%, transparent 5.6%);
# }
# #T_28094_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.0%, transparent 10.0%);
# }
# #T_28094_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.1%, transparent 22.1%);
# }
# #T_28094_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.4%, transparent 43.4%);
# }
# #T_28094_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_28094">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28094_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_28094_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_28094_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_28094_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_28094_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_28094_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_28094_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_28094_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_28094_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_28094_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_28094_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_28094_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_28094_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28094_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28094_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_28094_row0_col1" class="data row0 col1" ></td>
#       <td id="T_28094_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_28094_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_28094_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_28094_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_28094_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_28094_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_28094_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_28094_row0_col9" class="data row0 col9" >-0</td>
#       <td id="T_28094_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_28094_row0_col11" class="data row0 col11" >5</td>
#       <td id="T_28094_row0_col12" class="data row0 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_28094_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28094_row1_col0" class="data row1 col0" >LinearRegression</td>
#       <td id="T_28094_row1_col1" class="data row1 col1" ></td>
#       <td id="T_28094_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_28094_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_28094_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_28094_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_28094_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_28094_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_28094_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_28094_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_28094_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_28094_row1_col11" class="data row1 col11" >7</td>
#       <td id="T_28094_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_28094_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28094_row2_col0" class="data row2 col0" >LinearRegression</td>
#       <td id="T_28094_row2_col1" class="data row2 col1" ></td>
#       <td id="T_28094_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_28094_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_28094_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_28094_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_28094_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_28094_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_28094_row2_col8" class="data row2 col8" >2</td>
#       <td id="T_28094_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_28094_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_28094_row2_col11" class="data row2 col11" >6</td>
#       <td id="T_28094_row2_col12" class="data row2 col12" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_28094_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28094_row3_col0" class="data row3 col0" >LinearRegression</td>
#       <td id="T_28094_row3_col1" class="data row3 col1" ></td>
#       <td id="T_28094_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_28094_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_28094_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_28094_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_28094_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_28094_row3_col7" class="data row3 col7" >6</td>
#       <td id="T_28094_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_28094_row3_col9" class="data row3 col9" >-45</td>
#       <td id="T_28094_row3_col10" class="data row3 col10" >91</td>
#       <td id="T_28094_row3_col11" class="data row3 col11" >4</td>
#       <td id="T_28094_row3_col12" class="data row3 col12" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_28094_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28094_row4_col0" class="data row4 col0" >LinearRegression</td>
#       <td id="T_28094_row4_col1" class="data row4 col1" ></td>
#       <td id="T_28094_row4_col2" class="da

# %%
('price mad in 5k groups: ', 323.66491789552254)
('price std in 5k groups: ', 701.2696209252479)

('price mad in 10k groups: ', 343.64691608968064)
('price std in 10k groups: ', 729.4423273421423)
