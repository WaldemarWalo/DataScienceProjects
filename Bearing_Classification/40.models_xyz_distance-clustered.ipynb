# %% [markdown]
# # Setup and Imports

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

from sklearn.preprocessing import StandardScaler, PowerTransformer

# %%
(X, y) = t.from_pkl(f'{processed_data_path}/all_b1_b2_xyz_distance_cluster1.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 72)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__p01', 'x__p10', 'x__p20', 'x__p30', 'x__p99', 'x__p90',
#        'x__p80', 'x__p70', 'x__iqr', 'x__kurtosis', 'x__skew', 'y__amin',
#        'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std', 'y__var',
#        'y__p01', 'y__p10', 'y__p20', 'y__p30', 'y__p99', 'y__p90', 'y__p80',
#        'y__p70', 'y__iqr', 'y__kurtosis', 'y__skew', 'z__amin', 'z__amax',
#        'z__sum', 'z__median', 'z__mean', 'z__std', 'z__var', 'z__p01',
#        'z__p10', 'z__p20', 'z__p30', 'z__p99', 'z__p90', 'z__p80', 'z__p70',
#        'z__iqr', 'z__kurtosis', 'z__skew', 'xyz__amin', 'xyz__amax',
#        'xyz__sum', 'xyz__median', 'xyz__mean', 'xyz__std', 'xyz__var',
#        'xyz__p01', 'xyz__p10', 'xyz__p20', 'xyz__p30', 'xyz__p99', 'xyz__p90',
#        'xyz__p80', 'xyz__p70', 'xyz__iqr', 'xyz__kurtosis', 'xyz__skew'],
#       dtype='object')
# (200,)
# 0    100
# 1    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

from sklearn.metrics import roc_auc_score, log_loss

from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# # First Run

# %%
n_est_list = [100, 200]
models_and_params = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5)
metrics = [ roc_auc_score, log_loss ]

_ = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)
# Out:
# <style type="text/css">
# #T_13eb7_row0_col3, #T_13eb7_row5_col7, #T_13eb7_row6_col6, #T_13eb7_row11_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_13eb7_row0_col4, #T_13eb7_row0_col6, #T_13eb7_row0_col7, #T_13eb7_row5_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_13eb7_row0_col5, #T_13eb7_row6_col8 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_13eb7_row0_col8, #T_13eb7_row5_col5 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_13eb7_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_13eb7_row1_col3, #T_13eb7_row4_col7, #T_13eb7_row10_col4, #T_13eb7_row11_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_13eb7_row1_col4, #T_13eb7_row1_col6, #T_13eb7_row1_col7, #T_13eb7_row7_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_13eb7_row1_col5, #T_13eb7_row11_col8 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_13eb7_row1_col8, #T_13eb7_row7_col5 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# #T_13eb7_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_13eb7_row2_col3, #T_13eb7_row9_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_13eb7_row2_col4, #T_13eb7_row4_col3, #T_13eb7_row5_col6, #T_13eb7_row7_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_13eb7_row2_col5, #T_13eb7_row9_col5, #T_13eb7_row10_col8 {
#   background-color: #fdb373;
#   color: #000000;
# }
# #T_13eb7_row2_col6, #T_13eb7_row8_col4, #T_13eb7_row9_col7, #T_13eb7_row10_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_13eb7_row2_col7, #T_13eb7_row7_col4, #T_13eb7_row9_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_13eb7_row2_col8, #T_13eb7_row10_col5 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_13eb7_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.5%, transparent 14.5%);
# }
# #T_13eb7_row3_col3, #T_13eb7_row3_col4, #T_13eb7_row7_col6, #T_13eb7_row11_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_13eb7_row3_col5, #T_13eb7_row7_col8 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_13eb7_row3_col6, #T_13eb7_row6_col4, #T_13eb7_row8_col7, #T_13eb7_row11_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_13eb7_row3_col7, #T_13eb7_row5_col4, #T_13eb7_row10_col6 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_13eb7_row3_col8, #T_13eb7_row11_col5 {
#   background-color: #ee6410;
#   color: #f1f1f1;
# }
# #T_13eb7_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.4%, transparent 28.4%);
# }
# #T_13eb7_row4_col4, #T_13eb7_row8_col3, #T_13eb7_row8_col6, #T_13eb7_row10_col7 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_13eb7_row4_col5, #T_13eb7_row5_col8 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_13eb7_row4_col6, #T_13eb7_row6_col3, #T_13eb7_row6_col7, #T_13eb7_row9_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_13eb7_row4_col8, #T_13eb7_row6_col5 {
#   background-color: #c94202;
#   color: #f1f1f1;
# }
# #T_13eb7_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.2%, transparent 18.2%);
# }
# #T_13eb7_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.1%, transparent 36.1%);
# }
# #T_13eb7_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_13eb7_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.2%, transparent 4.2%);
# }
# #T_13eb7_row8_col5, #T_13eb7_row8_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_13eb7_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.2%, transparent 21.2%);
# }
# #T_13eb7_row9_col8 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_13eb7_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.3%, transparent 39.3%);
# }
# #T_13eb7_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.3%, transparent 49.3%);
# }
# #T_13eb7_row11_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_13eb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13eb7_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_13eb7_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_13eb7_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_13eb7_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_13eb7_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_13eb7_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_13eb7_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_13eb7_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_13eb7_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_13eb7_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13eb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13eb7_row0_col0" class="data row0 col0" >DecisionTreeClassifier</td>
#       <td id="T_13eb7_row0_col1" class="data row0 col1" ></td>
#       <td id="T_13eb7_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_13eb7_row0_col3" class="data row0 col3" >0.851</td>
#       <td id="T_13eb7_row0_col4" class="data row0 col4" >0.036</td>
#       <td id="T_13eb7_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_13eb7_row0_col6" class="data row0 col6" >5.15</td>
#       <td id="T_13eb7_row0_col7" class="data row0 col7" >1.26</td>
#       <td id="T_13eb7_row0_col8" class="data row0 col8" >12</td>
#       <td id="T_13eb7_row0_col9" class="data row0 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_13eb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13eb7_row1_col0" class="data row1 col0" >KNeighborsClassifier</td>
#       <td id="T_13eb7_row1_col1" class="data row1 col1" ></td>
#       <td id="T_13eb7_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_13eb7_row1_col3" class="data row1 col3" >0.934</td>
#       <td id="T_13eb7_row1_col4" class="data row1 col4" >0.031</td>
#       <td id="T_13eb7_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_13eb7_row1_col6" class="data row1 col6" >1.45</td>
#       <td id="T_13eb7_row1_col7" class="data row1 col7" >0.89</td>
#       <td id="T_13eb7_row1_col8" class="data row1 col8" >11</td>
#       <td id="T_13eb7_row1_col9" class="data row1 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_13eb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13eb7_row2_col0" class="data row2 col0" >RandomForestClassifier</td>
#       <td id="T_13eb7_row2_col1" class="data row2 col1" >'n_estimators': 100</td>
#       <td id="T_13eb7_row2_col2" class="data row2 col2" >25</td>
#       <td id="T_13eb7_row2_col3" class="data row2 col3" >0.974</td>
#       <td id="T_13eb7_row2_col4" class="data row2 col4" >0.022</td>
#       <td id="T_13eb7_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_13eb7_row2_col6" class="data row2 col6" >0.24</td>
#       <td id="T_13eb7_row2_col7" class="data row2 col7" >0.04</td>
#       <td id="T_13eb7_row2_col8" class="data row2 col8" >8</td>
#       <td id="T_13eb7_row2_col9" class="data row2 col9" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_13eb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13eb7_row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#       <td id="T_13eb7_row3_col1" class="data row3 col1" >'n_estimators': 200</td>
#       <td id="T_13eb7_row3_col2" class="data row3 col2" >25</td>
#       <td id="T_13eb7_row3_col3" class="data row3 col3" >0.976</td>
#       <td id="T_13eb7_row3_col4" class="data row3 col4" >0.019</td>
#       <td id="T_13eb7_row3_col5" class="data row3 col5" >6</td>
#       <td id="T_13eb7_row3_col6" class="data row3 col6" >0.24</td>
#       <td id="T_13eb7_row3_col7" class="data row3 col7" >0.04</td>
#       <td id="T_13eb7_row3_col8" class

# %% [markdown]
# # Shortlisted Best 3

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_14aa4_row0_col3, #T_14aa4_row0_col6, #T_14aa4_row2_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_14aa4_row0_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_14aa4_row0_col5, #T_14aa4_row0_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_14aa4_row0_col7, #T_14aa4_row4_col3, #T_14aa4_row4_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_14aa4_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.0%, transparent 19.0%);
# }
# #T_14aa4_row1_col3, #T_14aa4_row1_col6, #T_14aa4_row2_col4, #T_14aa4_row3_col4, #T_14aa4_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_14aa4_row1_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_14aa4_row1_col5, #T_14aa4_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_14aa4_row1_col7, #T_14aa4_row5_col3, #T_14aa4_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_14aa4_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.8%, transparent 36.8%);
# }
# #T_14aa4_row2_col3, #T_14aa4_row3_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_14aa4_row2_col5, #T_14aa4_row3_col5, #T_14aa4_row3_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_14aa4_row2_col6, #T_14aa4_row5_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_14aa4_row2_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_14aa4_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_14aa4_row3_col6, #T_14aa4_row4_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_14aa4_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_14aa4_row4_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_14aa4_row4_col5, #T_14aa4_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_14aa4_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.5%, transparent 46.5%);
# }
# #T_14aa4_row5_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_14aa4_row5_col5, #T_14aa4_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_14aa4_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_14aa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14aa4_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_14aa4_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_14aa4_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_14aa4_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_14aa4_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_14aa4_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_14aa4_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_14aa4_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_14aa4_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_14aa4_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14aa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14aa4_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_14aa4_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_14aa4_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_14aa4_row0_col3" class="data row0 col3" >0.993</td>
#       <td id="T_14aa4_row0_col4" class="data row0 col4" >0.010</td>
#       <td id="T_14aa4_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_14aa4_row0_col6" class="data row0 col6" >0.472</td>
#       <td id="T_14aa4_row0_col7" class="data row0 col7" >0.013</td>
#       <td id="T_14aa4_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_14aa4_row0_col9" class="data row0 col9" >16.1</td>
#     </tr>
#     <tr>
#       <th id="T_14aa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14aa4_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_14aa4_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_14aa4_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_14aa4_row1_col3" class="data row1 col3" >0.993</td>
#       <td id="T_14aa4_row1_col4" class="data row1 col4" >0.009</td>
#       <td id="T_14aa4_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_14aa4_row1_col6" class="data row1 col6" >0.476</td>
#       <td id="T_14aa4_row1_col7" class="data row1 col7" >0.013</td>
#       <td id="T_14aa4_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_14aa4_row1_col9" class="data row1 col9" >31.2</td>
#     </tr>
#     <tr>
#       <th id="T_14aa4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14aa4_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_14aa4_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_14aa4_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_14aa4_row2_col3" class="data row2 col3" >0.990</td>
#       <td id="T_14aa4_row2_col4" class="data row2 col4" >0.012</td>
#       <td id="T_14aa4_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_14aa4_row2_col6" class="data row2 col6" >0.186</td>
#       <td id="T_14aa4_row2_col7" class="data row2 col7" >0.142</td>
#       <td id="T_14aa4_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_14aa4_row2_col9" class="data row2 col9" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_14aa4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14aa4_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_14aa4_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_14aa4_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_14aa4_row3_col3" class="data row3 col3" >0.990</td>
#       <td id="T_14aa4_row3_col4" class="data row3 col4" >0.012</td>
#       <td id="T_14aa4_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_14aa4_row3_col6" class="data row3 col6" >0.186</td>
#       <td id="T_14aa4_row3_col7" class="data row3 col7" >0.142</td>
#       <td id="T_14aa4_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_14aa4_row3_col9" class="data row3 col9" >1.1</td>
#     </tr>
#     <tr>
#       <th id="T_14aa4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14aa4_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_14aa4_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_14aa4_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_14aa4_row4_col3" class="data row4 col3" >0.987</td>
#       <td id="T_14aa4_row4_col4" class="data row4 col4" >0.011</td>
#       <td id="T_14aa4_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_14aa4_row4_col6" class="data row4 col6" >0.165</td>
#       <td id="T_14aa4_row4_col7" class="data row4 col7" >0.050</td>
#       <td id="T_14aa4_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_14aa4_row4_col9" class="data row4 col9" >39.5</td>
#     </tr>
#     <tr>
#       <th id="T_14aa4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14aa4_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_14aa4_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_14aa4_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_14aa4_row5_col3" class="data row5 col3" >0.986</td>
#       <td id="T_14aa4_row5_col4" class="data row5 col4" >0.011</td>
#       <td id="T_14aa4_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_14aa4_row5_col6" class="data row5 col6" >0.163</td>
#       <td id="T_14aa4_row5_col7" class="data row5 col7" >0.053</td>
#       <td id="T_14aa4_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_14aa4_row5_col9" class="data row5 col9" >84.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_fe_df(list_of_list_of_models):
    df_all_fe = []
    
    for i, models_to_analyse in enumerate(list_of_list_of_models):
        feature_imp_for_model = []

        for j, m in enumerate(models_to_analyse[:3]):
            model_short_name = ''.join([l for l in m.__class__.__name__ if l.isupper()])

            if hasattr(m, 'feature_names_in_'):
                feature_names = m.feature_names_in_
            elif hasattr(m, 'feature_name_'):
                feature_names = m.feature_name_
            else:
                feature_names = m.feature_names_

            feature_imp_for_model.append(
                pd.Series(index = feature_names, data = m.feature_importances_, name=f'{model_short_name}_{i}_{j}')
            )

        df_f_imp = pd.concat(feature_imp_for_model, axis=1)
        df_f_imp[f'{model_short_name}_{i}_sum'] = df_f_imp.sum(axis=1)
        df_f_imp[f'{model_short_name}_{i}_rank'] = df_f_imp[f'{model_short_name}_{i}_sum'].rank().astype(int)

        # df_f_imp.sort_values(by=[f'{model_short_name}_sum'], ascending = False)
        df_all_fe.append(df_f_imp)

        df_final_fe = pd.concat(df_all_fe, axis=1)
        
        sum_cols = [col for col in df_final_fe.columns if col.endswith('_sum')]
    df_final_fe['sum'] = df_final_fe[sum_cols].sum(axis=1)
    df_final_fe = df_final_fe.sort_values(by='sum', ascending=False)


    rank_cols = [col for col in df_final_fe.columns if col.endswith('_rank')]
    styler = df_final_fe.style
    styler.background_gradient(subset=rank_cols, cmap=plt.cm.Oranges, vmin=-5)
    return styler

# %%
df_final_fe = get_fe_df(all_trained_models)
df_final_fe
# Out:
# <style type="text/css">
# #T_53d33_row0_col4, #T_53d33_row0_col9, #T_53d33_row0_col24, #T_53d33_row0_col29, #T_53d33_row2_col14, #T_53d33_row2_col19 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_53d33_row0_col14, #T_53d33_row0_col19, #T_53d33_row3_col24, #T_53d33_row3_col29, #T_53d33_row5_col4, #T_53d33_row5_col9 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_53d33_row1_col4, #T_53d33_row3_col9, #T_53d33_row6_col14, #T_53d33_row6_col19, #T_53d33_row18_col24, #T_53d33_row18_col29 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_53d33_row1_col9, #T_53d33_row3_col4, #T_53d33_row5_col14, #T_53d33_row5_col19, #T_53d33_row11_col24, #T_53d33_row11_col29 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_53d33_row1_col14, #T_53d33_row1_col19, #T_53d33_row1_col24, #T_53d33_row1_col29, #T_53d33_row2_col4, #T_53d33_row2_col9 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_53d33_row2_col24, #T_53d33_row8_col14, #T_53d33_row8_col19, #T_53d33_row12_col29, #T_53d33_row13_col4, #T_53d33_row13_col9 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_53d33_row2_col29, #T_53d33_row7_col14, #T_53d33_row7_col19, #T_53d33_row8_col4, #T_53d33_row8_col9, #T_53d33_row12_col24 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_53d33_row3_col14, #T_53d33_row3_col19, #T_53d33_row5_col29, #T_53d33_row6_col24, #T_53d33_row7_col4, #T_53d33_row7_col9 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_53d33_row4_col4, #T_53d33_row4_col9, #T_53d33_row14_col14, #T_53d33_row14_col19, #T_53d33_row17_col24, #T_53d33_row17_col29 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_53d33_row4_col14, #T_53d33_row4_col19, #T_53d33_row5_col24, #T_53d33_row6_col29, #T_53d33_row28_col4, #T_53d33_row28_col9 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_53d33_row4_col24, #T_53d33_row12_col14, #T_53d33_row12_col19, #T_53d33_row15_col4, #T_53d33_row19_col4, #T_53d33_row19_col29, #T_53d33_row21_col4, #T_53d33_row29_col9 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_53d33_row4_col29, #T_53d33_row6_col9, #T_53d33_row13_col14, #T_53d33_row13_col19, #T_53d33_row19_col24 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_53d33_row6_col4, #T_53d33_row8_col24, #T_53d33_row9_col29, #T_53d33_row10_col14, #T_53d33_row10_col19, #T_53d33_row11_col9 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_53d33_row7_col24, #T_53d33_row7_col29, #T_53d33_row11_col14, #T_53d33_row11_col19, #T_53d33_row19_col9 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_53d33_row8_col29, #T_53d33_row9_col14, #T_53d33_row9_col19, #T_53d33_row9_col24, #T_53d33_row11_col4, #T_53d33_row15_col9 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_53d33_row9_col4, #T_53d33_row33_col9, #T_53d33_row38_col4, #T_53d33_row57_col29, #T_53d33_row65_col24 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_53d33_row9_col9, #T_53d33_row26_col4, #T_53d33_row29_col14, #T_53d33_row29_col19, #T_53d33_row43_col29, #T_53d33_row51_col24 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_53d33_row10_col4, #T_53d33_row13_col29, #T_53d33_row15_col14, #T_53d33_row15_col19, #T_53d33_row16_col14, #T_53d33_row16_col19, #T_53d33_row22_col9, #T_53d33_row34_col24 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_53d33_row10_col9, #T_53d33_row14_col29, #T_53d33_row17_col14, #T_53d33_row17_col19, #T_53d33_row22_col4, #T_53d33_row32_col24 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_53d33_row10_col24, #T_53d33_row20_col14, #T_53d33_row20_col19, #T_53d33_row21_col14, #T_53d33_row21_col19, #T_53d33_row22_col29, #T_53d33_row25_col9, #T_53d33_row35_col4 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_53d33_row10_col29, #T_53d33_row26_col14, #T_53d33_row26_col19, #T_53d33_row30_col4, #T_53d33_row30_col9, #T_53d33_row30_col24, #T_53d33_row56_col9 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_53d33_row12_col4, #T_53d33_row25_col14, #T_53d33_row25_col19, #T_53d33_row30_col29, #T_53d33_row33_col24 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_53d33_row12_col9, #T_53d33_row18_col4, #T_53d33_row23_col14, #T_53d33_row23_col19, #T_53d33_row26_col24, #T_53d33_row47_col29 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_53d33_row13_col24, #T_53d33_row21_col9, #T_53d33_row29_col4, #T_53d33_row34_col29 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_53d33_row14_col4, #T_53d33_row16_col9, #T_53d33_row19_col14, #T_53d33_row19_col19, #T_53d33_row49_col24, #T_53d33_row49_col29 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_53d33_row14_col9, #T_53d33_row14_col24, #T_53d33_row16_col4, #T_53d33_row18_col14, #T_53d33_row18_col19, #T_53d33_row32_col29 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_53d33_row15_col24, #T_53d33_row29_col29, #T_53d33_row39_col14, #T_53d33_row39_col19, #T_53d33_row41_col14, #T_53d33_row41_col19 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_53d33_row15_col29, #T_53d33_row26_col9, #T_53d33_row30_col14, #T_53d33_row30_col19, #T_53d33_row31_col14, #T_53d33_row31_col19, #T_53d33_row43_col24 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_53d33_row16_col24, #T_53d33_row61_col29 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_53d33_row16_col29, #T_53d33_row48_col24, #T_53d33_row57_col14, #T_53d33_row57_col19, #T_53d33_row58_col14, #T_53d33_row58_col19, #T_53d33_row60_col14, #T_53d33_row60_col19, #T_53d33_row61_col14, #T_53d33_row61_col19 {
#   background-color: #fdd5ad;
#   color: #000000;
# }
# #T_53d33_row17_col4, #T_53d33_row18_col9, #T_53d33_row26_col29, #T_53d33_row47_col24 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_53d33_row17_col9, #T_53d33_row22_col14, #T_53d33_row22_col19, #T_53d33_row22_col24, #T_53d33_row25_col4, #T_53d33_row39_col29 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_53d33_row20_col4, #T_53d33_row38_col14, #T_53d33_row38_col19, #T_53d33_row58_col4, #T_53d33_row65_col29, #T_53d33_row69_col24 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_53d33_row20_col9, #T_53d33_row21_col29, #T_53d33_row40_col4, #T_53d33_row40_col9, #T_53d33_row46_col14, #T_53d33_row46_col19, #T_53d33_row54_col4, #T_53d33_row55_col9, #T_53d33_row58_col24 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_53d33_row20_col24, #T_53d33_row27_col4, #T_53d33_row33_col4, #T_53d33_row33_col29, #T_53d33_row38_col9 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_53d33_row20_col29, #T_53d33_row35_col24, #T_53d33_row44_col4, #T_53d33_row44_col9 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_53d33_row21_col24, #T_53d33_row27_col29, #T_53d33_row45_col4 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_53d33_row23_col4, #T_53d33_row23_col9, #T_53d33_row28_col14, #T_53d33_row28_col19, #T_53d33_row46_col24, #T_53d33_row68_col29 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_53d33_row23_col24, #T_53d33_row23_col29 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_53d33_row24_col4, #T_53d33_row24_col9, #T_53d33_row27_col14, #T_53d33_row27_col19, #T_53d33_row35_col29, #T_53d33_row68_col24 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_53d33_row24_col14, #T_53d33_row24_col19, #T_53d33_row35_col9, #T_53d33_row39_col24, #T_53d33_row46_col29, #T_53d33_row56_col4 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_53d33_row24_col24, #T_53d33_row31_col4, #T_53d33_row41_col4, #T_53d33_row41_col9, #T_53d33_row46_col4, #T_53d33_row53_col4, #T_53d33_row56_col29, #T_53d33_row62_col14, #T_53d33_row62_col19, #T_53d33_row63_col4, #T_53d33_row65_col4 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_53d33_row24_col29, #T_53d33_row54_col24, #T_53d33_row65_col14, #T_53d33_row65_col19, #T_53d33_row66_col14, #T_53d33_row66_col19 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_53d33_row25_col24, #T_53d33_row42_col4, #T_53d33_row43_col4, #T_53d33_row58_col29, #T_53d33_row62_col4, #T_53d33_row62_col9 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_53d33_row25_col29, #T_53d33_row32_col9, #T_53d33_row34_col9, #T_53d33_row40_col24, #T_53d33_row42_col14, #T_53d33_row42_col19, #T_53d33_row47_col4, #T_53d33_

# %% [markdown]
# ## Best 10 features

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X[df_final_fe.index.to_list()[:10]], y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_34b42_row0_col3, #T_34b42_row0_col6, #T_34b42_row3_col7, #T_34b42_row5_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_34b42_row0_col4, #T_34b42_row0_col7, #T_34b42_row4_col3, #T_34b42_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_34b42_row0_col5, #T_34b42_row0_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_34b42_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.1%, transparent 21.1%);
# }
# #T_34b42_row1_col3, #T_34b42_row1_col6, #T_34b42_row2_col7, #T_34b42_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_34b42_row1_col4, #T_34b42_row1_col7, #T_34b42_row4_col6, #T_34b42_row5_col3 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_34b42_row1_col5, #T_34b42_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_34b42_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.2%, transparent 40.2%);
# }
# #T_34b42_row2_col3, #T_34b42_row2_col4, #T_34b42_row3_col3, #T_34b42_row3_col4 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_34b42_row2_col5, #T_34b42_row3_col5, #T_34b42_row3_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_34b42_row2_col6, #T_34b42_row5_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_34b42_row2_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_34b42_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_34b42_row3_col6, #T_34b42_row4_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_34b42_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.3%, transparent 2.3%);
# }
# #T_34b42_row4_col5, #T_34b42_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_34b42_row4_col8, #T_34b42_row5_col5 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_34b42_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.3%, transparent 48.3%);
# }
# #T_34b42_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_34b42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34b42_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_34b42_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_34b42_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_34b42_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_34b42_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_34b42_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_34b42_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_34b42_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_34b42_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_34b42_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34b42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34b42_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_34b42_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_34b42_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_34b42_row0_col3" class="data row0 col3" >0.994</td>
#       <td id="T_34b42_row0_col4" class="data row0 col4" >0.005</td>
#       <td id="T_34b42_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_34b42_row0_col6" class="data row0 col6" >0.459</td>
#       <td id="T_34b42_row0_col7" class="data row0 col7" >0.020</td>
#       <td id="T_34b42_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_34b42_row0_col9" class="data row0 col9" >11.9</td>
#     </tr>
#     <tr>
#       <th id="T_34b42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34b42_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_34b42_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_34b42_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_34b42_row1_col3" class="data row1 col3" >0.995</td>
#       <td id="T_34b42_row1_col4" class="data row1 col4" >0.005</td>
#       <td id="T_34b42_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_34b42_row1_col6" class="data row1 col6" >0.459</td>
#       <td id="T_34b42_row1_col7" class="data row1 col7" >0.022</td>
#       <td id="T_34b42_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_34b42_row1_col9" class="data row1 col9" >22.6</td>
#     </tr>
#     <tr>
#       <th id="T_34b42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34b42_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_34b42_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_34b42_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_34b42_row2_col3" class="data row2 col3" >0.990</td>
#       <td id="T_34b42_row2_col4" class="data row2 col4" >0.009</td>
#       <td id="T_34b42_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_34b42_row2_col6" class="data row2 col6" >0.191</td>
#       <td id="T_34b42_row2_col7" class="data row2 col7" >0.124</td>
#       <td id="T_34b42_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_34b42_row2_col9" class="data row2 col9" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_34b42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34b42_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_34b42_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_34b42_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_34b42_row3_col3" class="data row3 col3" >0.990</td>
#       <td id="T_34b42_row3_col4" class="data row3 col4" >0.009</td>
#       <td id="T_34b42_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_34b42_row3_col6" class="data row3 col6" >0.191</td>
#       <td id="T_34b42_row3_col7" class="data row3 col7" >0.123</td>
#       <td id="T_34b42_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_34b42_row3_col9" class="data row3 col9" >1.3</td>
#     </tr>
#     <tr>
#       <th id="T_34b42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34b42_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_34b42_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_34b42_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_34b42_row4_col3" class="data row4 col3" >0.989</td>
#       <td id="T_34b42_row4_col4" class="data row4 col4" >0.011</td>
#       <td id="T_34b42_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_34b42_row4_col6" class="data row4 col6" >0.123</td>
#       <td id="T_34b42_row4_col7" class="data row4 col7" >0.043</td>
#       <td id="T_34b42_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_34b42_row4_col9" class="data row4 col9" >27.2</td>
#     </tr>
#     <tr>
#       <th id="T_34b42_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34b42_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_34b42_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_34b42_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_34b42_row5_col3" class="data row5 col3" >0.989</td>
#       <td id="T_34b42_row5_col4" class="data row5 col4" >0.010</td>
#       <td id="T_34b42_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_34b42_row5_col6" class="data row5 col6" >0.120</td>
#       <td id="T_34b42_row5_col7" class="data row5 col7" >0.043</td>
#       <td id="T_34b42_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_34b42_row5_col9" class="data row5 col9" >56.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Best 20 features

# %%
n_est_list = [800, 1600]
models_and_params = [
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2)
metrics = [ roc_auc_score, log_loss ]

r = t.grid_exec(
    lambda model: m.cv_classification(model, cv, X[df_final_fe.index.to_list()[:20]], y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)

all_trained_models = [res['models'] for res in r]
# Out:
# <style type="text/css">
# #T_18b6b_row0_col3, #T_18b6b_row0_col6, #T_18b6b_row3_col7 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_18b6b_row0_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_18b6b_row0_col5, #T_18b6b_row0_col8 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_18b6b_row0_col7, #T_18b6b_row4_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_18b6b_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.8%, transparent 17.8%);
# }
# #T_18b6b_row1_col3, #T_18b6b_row1_col6, #T_18b6b_row2_col4, #T_18b6b_row2_col7, #T_18b6b_row3_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_18b6b_row1_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_18b6b_row1_col5, #T_18b6b_row1_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_18b6b_row1_col7, #T_18b6b_row5_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_18b6b_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.5%, transparent 36.5%);
# }
# #T_18b6b_row2_col3, #T_18b6b_row3_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_18b6b_row2_col5, #T_18b6b_row2_col8, #T_18b6b_row3_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_18b6b_row2_col6, #T_18b6b_row4_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_18b6b_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_18b6b_row3_col6, #T_18b6b_row5_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_18b6b_row3_col8 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_18b6b_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.9%, transparent 1.9%);
# }
# #T_18b6b_row4_col3, #T_18b6b_row5_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_18b6b_row4_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_18b6b_row4_col5, #T_18b6b_row5_col5, #T_18b6b_row5_col8 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_18b6b_row4_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_18b6b_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.0%, transparent 47.0%);
# }
# #T_18b6b_row5_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_18b6b_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_18b6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18b6b_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_18b6b_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_18b6b_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_18b6b_level0_col3" class="col_heading level0 col3" >ROC_AUC_mean</th>
#       <th id="T_18b6b_level0_col4" class="col_heading level0 col4" >ROC_AUC_std</th>
#       <th id="T_18b6b_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_18b6b_level0_col6" class="col_heading level0 col6" >log_loss_mean</th>
#       <th id="T_18b6b_level0_col7" class="col_heading level0 col7" >log_loss_std</th>
#       <th id="T_18b6b_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_18b6b_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18b6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18b6b_row0_col0" class="data row0 col0" >AdaBoostClassifier</td>
#       <td id="T_18b6b_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_18b6b_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_18b6b_row0_col3" class="data row0 col3" >0.994</td>
#       <td id="T_18b6b_row0_col4" class="data row0 col4" >0.005</td>
#       <td id="T_18b6b_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_18b6b_row0_col6" class="data row0 col6" >0.455</td>
#       <td id="T_18b6b_row0_col7" class="data row0 col7" >0.019</td>
#       <td id="T_18b6b_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_18b6b_row0_col9" class="data row0 col9" >11.7</td>
#     </tr>
#     <tr>
#       <th id="T_18b6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18b6b_row1_col0" class="data row1 col0" >AdaBoostClassifier</td>
#       <td id="T_18b6b_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_18b6b_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_18b6b_row1_col3" class="data row1 col3" >0.995</td>
#       <td id="T_18b6b_row1_col4" class="data row1 col4" >0.006</td>
#       <td id="T_18b6b_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_18b6b_row1_col6" class="data row1 col6" >0.458</td>
#       <td id="T_18b6b_row1_col7" class="data row1 col7" >0.017</td>
#       <td id="T_18b6b_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_18b6b_row1_col9" class="data row1 col9" >24.0</td>
#     </tr>
#     <tr>
#       <th id="T_18b6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18b6b_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_18b6b_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_18b6b_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_18b6b_row2_col3" class="data row2 col3" >0.992</td>
#       <td id="T_18b6b_row2_col4" class="data row2 col4" >0.009</td>
#       <td id="T_18b6b_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_18b6b_row2_col6" class="data row2 col6" >0.140</td>
#       <td id="T_18b6b_row2_col7" class="data row2 col7" >0.122</td>
#       <td id="T_18b6b_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_18b6b_row2_col9" class="data row2 col9" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_18b6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18b6b_row3_col0" class="data row3 col0" >LGBMClassifier</td>
#       <td id="T_18b6b_row3_col1" class="data row3 col1" >'n_estimators': 1600</td>
#       <td id="T_18b6b_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_18b6b_row3_col3" class="data row3 col3" >0.992</td>
#       <td id="T_18b6b_row3_col4" class="data row3 col4" >0.009</td>
#       <td id="T_18b6b_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_18b6b_row3_col6" class="data row3 col6" >0.140</td>
#       <td id="T_18b6b_row3_col7" class="data row3 col7" >0.122</td>
#       <td id="T_18b6b_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_18b6b_row3_col9" class="data row3 col9" >1.3</td>
#     </tr>
#     <tr>
#       <th id="T_18b6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18b6b_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#       <td id="T_18b6b_row4_col1" class="data row4 col1" >'n_estimators': 800</td>
#       <td id="T_18b6b_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_18b6b_row4_col3" class="data row4 col3" >0.992</td>
#       <td id="T_18b6b_row4_col4" class="data row4 col4" >0.008</td>
#       <td id="T_18b6b_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_18b6b_row4_col6" class="data row4 col6" >0.123</td>
#       <td id="T_18b6b_row4_col7" class="data row4 col7" >0.038</td>
#       <td id="T_18b6b_row4_col8" class="data row4 col8" >2</td>
#       <td id="T_18b6b_row4_col9" class="data row4 col9" >30.8</td>
#     </tr>
#     <tr>
#       <th id="T_18b6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18b6b_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_18b6b_row5_col1" class="data row5 col1" >'n_estimators': 1600</td>
#       <td id="T_18b6b_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_18b6b_row5_col3" class="data row5 col3" >0.992</td>
#       <td id="T_18b6b_row5_col4" class="data row5 col4" >0.008</td>
#       <td id="T_18b6b_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_18b6b_row5_col6" class="data row5 col6" >0.121</td>
#       <td id="T_18b6b_row5_col7" class="data row5 col7" >0.040</td>
#       <td id="T_18b6b_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_18b6b_row5_col9" class="data row5 col9" >65.6</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final_fe.index.to_list()[:30]
# Out:
# ['x__skew',
#  'z__sum',
#  'z__skew',
#  'xyz__amin',
#  'y__sum',
#  'x__sum',
#  'x__kurtosis',
#  'y__skew',
#  'z__p99',
#  'x__p30',
#  'x__p70',
#  'z__mean',
#  'x__median',
#  'xyz__kurtosis',
#  'y__p70',
#  'x__amax',
#  'z__kurtosis',
#  'z__amax',
#  'x__mean',
#  'y__mean',
#  'z__p10',
#  'y__amin',
#  'z__p70',
#  'y__p30',
#  'y__median',
#  'z__amin',
#  'y__kurtosis',
#  'x__amin',
#  'y__p90',
#  'z__median']
