# %% [markdown]
# # Setup and Imports

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
import time

# %%
df_data = t.from_pkl(f'{processed_data_path}/df_clean.pkl')

df_data.shape
df_data.head(3)
# Out:
# (97323, 8)
#    make model  year  price transmission  mileage fuelType  engineSize
# 0  Audi    A1  2017  12500       Manual    15735   Petrol         1.4
# 1  Audi    A6  2016  16500    Automatic    36203   Diesel         2.0
# 2  Audi    A1  2016  11000       Manual    29946   Petrol         1.4

# %%
df_data.insert(0, 'car', df_data['make'] + '__' + df_data['model'])
df_data = df_data.drop(columns=['make', 'model'])

# %%
df_data.groupby(['car']).size().sort_values(ascending=False).head(10)
# Out:
# car
# Ford__Fiesta       6508
# Vw__Golf           4769
# Ford__Focus        4555
# Merc__C Class      3689
# Vauxhall__Corsa    3285
# Vw__Polo           3230
# Vauxhall__Astra    2655
# Merc__A Class      2474
# Bmw__3 Series      2413
# Ford__Kuga         2208
# dtype: int64

# %%
df_fiesta = df_data.loc[ (df_data['car'] == 'Ford__Fiesta') ].drop(columns=['car']).copy()
df_fiesta.head(3)
# Out:
#        year  price transmission  mileage fuelType  engineSize
# 21449  2017  12000    Automatic    15944   Petrol         1.0
# 21452  2019  17500       Manual    10460   Petrol         1.5
# 21453  2019  16500    Automatic     1482   Petrol         1.0

# %%
mileage_5k = ((df_fiesta['mileage'] / 5000).round(0) * 5000).astype(int)
r = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_5k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
r.columns = [c[1] for c in r.columns]

'mean group size: ', r['len'].mean()
'price std in group: ', r['std'].mean()
# Out:
# ('mean group size: ', 10.446227929373997)
# ('price std in group: ', 701.2696209252479)

# %%
mileage_10k = ((df_fiesta['mileage'] / 10000).round(0) * 10000).astype(int)
r = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_10k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
r.columns = [c[1] for c in r.columns]

'mean group size: ', r['len'].mean()
'price std in group: ', r['mad'].mean()
'price std in group: ', r['std'].mean()
# Out:
# ('mean group size: ', 15.349056603773585)
# ('price std in group: ', 343.64691608968064)
# ('price std in group: ', 729.4423273421423)

# %% [markdown]
# # Encode

# %%
m.ordinalEncode(df_fiesta, ['transmission', 'fuelType'])
df_fiesta
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0
# 21454  2015  10500             1    35432         1         1.6
# 21456  2017   9000             1    13054         1         1.2
# ...     ...    ...           ...      ...       ...         ...
# 39394  2019  15999             1     2813         1         1.0
# 39395  2015   8999             1    24546         1         1.0
# 39401  2017   9899             0    16303         1         1.0
# 39404  2018  12500             0     7047         1         1.0
# 39409  2016   7999             1    31348         1         1.2
#
# [6508 rows x 6 columns]

# %% [markdown]
# # X y

# %%
df_train = df_fiesta
df_train.head(3)
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0

# %%
X, y  = df_train.drop(columns='price'), df_train['price']

y.shape
X.shape
X.columns
X.head(2)
# Out:
# (6508,)
# (6508, 5)
# Index(['year', 'transmission', 'mileage', 'fuelType', 'engineSize'], dtype='object')
#        year  transmission  mileage  fuelType  engineSize
# 21449  2017             0    15944         1         1.0
# 21452  2019             1    10460         1         1.5

# %% [markdown]
# # Train model

# %%
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

# from sklearn.svm import SVC

# from lightgbm import LGBMRegressor
# from xgboost import XGBRegressor
# from catboost import CatBoostRegressor

from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# ## Linear Models

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import minmax_scale, normalize, scale, PolynomialFeatures

# %%
def booger_aids(X, y):
    models_and_params = [
        (LinearRegression, {}),
        # (Lasso, {'random_state': RS}),
        # (Ridge, {'random_state': RS}),
    ]
    cv = KFold(5)
    metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

    r = t.grid_exec(
        lambda model: m.cv_regression(model, cv, X, y, metrics), 
        models_and_params,
    )
    return r

# %% [markdown]
# ## Raw

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
r = booger_aids(X, y)
m.display_stats(r, False)
# Out:
# <style type="text/css">
# #T_8c13d_row0_col3, #T_8c13d_row0_col4, #T_8c13d_row0_col5, #T_8c13d_row0_col6, #T_8c13d_row0_col7, #T_8c13d_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8c13d_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_8c13d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c13d_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_8c13d_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_8c13d_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_8c13d_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_8c13d_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_8c13d_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_8c13d_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_8c13d_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_8c13d_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_8c13d_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c13d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c13d_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_8c13d_row0_col1" class="data row0 col1" ></td>
#       <td id="T_8c13d_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_8c13d_row0_col3" class="data row0 col3" >1269.885</td>
#       <td id="T_8c13d_row0_col4" class="data row0 col4" >120.543</td>
#       <td id="T_8c13d_row0_col5" class="data row0 col5" >1698.917</td>
#       <td id="T_8c13d_row0_col6" class="data row0 col6" >203.566</td>
#       <td id="T_8c13d_row0_col7" class="data row0 col7" >0.627</td>
#       <td id="T_8c13d_row0_col8" class="data row0 col8" >0.037</td>
#       <td id="T_8c13d_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Standard Scaled

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)
# Out:
# <style type="text/css">
# #T_9f9a4_row0_col3, #T_9f9a4_row0_col4, #T_9f9a4_row0_col5, #T_9f9a4_row0_col6, #T_9f9a4_row0_col7, #T_9f9a4_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9f9a4_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_9f9a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f9a4_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_9f9a4_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_9f9a4_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_9f9a4_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_9f9a4_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_9f9a4_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_9f9a4_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_9f9a4_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_9f9a4_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_9f9a4_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f9a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f9a4_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_9f9a4_row0_col1" class="data row0 col1" ></td>
#       <td id="T_9f9a4_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_9f9a4_row0_col3" class="data row0 col3" >1269.885</td>
#       <td id="T_9f9a4_row0_col4" class="data row0 col4" >120.543</td>
#       <td id="T_9f9a4_row0_col5" class="data row0 col5" >1698.917</td>
#       <td id="T_9f9a4_row0_col6" class="data row0 col6" >203.566</td>
#       <td id="T_9f9a4_row0_col7" class="data row0 col7" >0.627</td>
#       <td id="T_9f9a4_row0_col8" class="data row0 col8" >0.037</td>
#       <td id="T_9f9a4_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Normalized

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = normalize(X)
r = booger_aids(X, y)
m.display_stats(r, False)
# Out:
# <style type="text/css">
# #T_74447_row0_col3, #T_74447_row0_col4, #T_74447_row0_col5, #T_74447_row0_col6, #T_74447_row0_col7, #T_74447_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_74447_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_74447">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74447_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_74447_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_74447_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_74447_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_74447_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_74447_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_74447_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_74447_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_74447_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_74447_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74447_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74447_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_74447_row0_col1" class="data row0 col1" ></td>
#       <td id="T_74447_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_74447_row0_col3" class="data row0 col3" >1686.642</td>
#       <td id="T_74447_row0_col4" class="data row0 col4" >134.771</td>
#       <td id="T_74447_row0_col5" class="data row0 col5" >2169.482</td>
#       <td id="T_74447_row0_col6" class="data row0 col6" >204.145</td>
#       <td id="T_74447_row0_col7" class="data row0 col7" >0.392</td>
#       <td id="T_74447_row0_col8" class="data row0 col8" >0.021</td>
#       <td id="T_74447_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Min Max

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = minmax_scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)
# Out:
# <style type="text/css">
# #T_eb1fb_row0_col3, #T_eb1fb_row0_col4, #T_eb1fb_row0_col5, #T_eb1fb_row0_col6, #T_eb1fb_row0_col7, #T_eb1fb_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_eb1fb_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_eb1fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb1fb_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_eb1fb_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_eb1fb_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_eb1fb_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_eb1fb_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_eb1fb_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_eb1fb_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_eb1fb_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_eb1fb_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_eb1fb_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb1fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb1fb_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_eb1fb_row0_col1" class="data row0 col1" ></td>
#       <td id="T_eb1fb_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_eb1fb_row0_col3" class="data row0 col3" >1269.885</td>
#       <td id="T_eb1fb_row0_col4" class="data row0 col4" >120.543</td>
#       <td id="T_eb1fb_row0_col5" class="data row0 col5" >1698.917</td>
#       <td id="T_eb1fb_row0_col6" class="data row0 col6" >203.566</td>
#       <td id="T_eb1fb_row0_col7" class="data row0 col7" >0.627</td>
#       <td id="T_eb1fb_row0_col8" class="data row0 col8" >0.037</td>
#       <td id="T_eb1fb_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Poly

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)
# Out:
# <style type="text/css">
# #T_f8a93_row0_col3, #T_f8a93_row1_col7, #T_f8a93_row6_col4, #T_f8a93_row6_col5, #T_f8a93_row6_col6, #T_f8a93_row6_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f8a93_row0_col4, #T_f8a93_row1_col3, #T_f8a93_row4_col7, #T_f8a93_row5_col5, #T_f8a93_row5_col6, #T_f8a93_row5_col8 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_f8a93_row0_col5, #T_f8a93_row3_col3, #T_f8a93_row4_col6, #T_f8a93_row4_col8, #T_f8a93_row5_col4, #T_f8a93_row5_col7 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_f8a93_row0_col6, #T_f8a93_row0_col8, #T_f8a93_row2_col3, #T_f8a93_row2_col5, #T_f8a93_row3_col7, #T_f8a93_row4_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_f8a93_row0_col7, #T_f8a93_row2_col4, #T_f8a93_row2_col6, #T_f8a93_row2_col8, #T_f8a93_row4_col5, #T_f8a93_row5_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_f8a93_row0_col9, #T_f8a93_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.4%, transparent 3.4%);
# }
# #T_f8a93_row1_col4, #T_f8a93_row1_col5, #T_f8a93_row1_col6, #T_f8a93_row1_col8, #T_f8a93_row4_col3, #T_f8a93_row6_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_f8a93_row2_col7, #T_f8a93_row3_col4, #T_f8a93_row3_col5, #T_f8a93_row3_col6, #T_f8a93_row3_col8, #T_f8a93_row6_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_f8a93_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.1%, transparent 5.1%);
# }
# #T_f8a93_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.3%, transparent 9.3%);
# }
# #T_f8a93_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.5%, transparent 18.5%);
# }
# #T_f8a93_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.2%, transparent 38.2%);
# }
# #T_f8a93_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_f8a93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8a93_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f8a93_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_f8a93_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_f8a93_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_f8a93_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_f8a93_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_f8a93_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_f8a93_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_f8a93_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_f8a93_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8a93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8a93_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_f8a93_row0_col1" class="data row0 col1" ></td>
#       <td id="T_f8a93_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_f8a93_row0_col3" class="data row0 col3" >2239</td>
#       <td id="T_f8a93_row0_col4" class="data row0 col4" >297</td>
#       <td id="T_f8a93_row0_col5" class="data row0 col5" >2919</td>
#       <td id="T_f8a93_row0_col6" class="data row0 col6" >375</td>
#       <td id="T_f8a93_row0_col7" class="data row0 col7" >-0</td>
#       <td id="T_f8a93_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f8a93_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8a93_row1_col0" class="data row1 col0" >LinearRegression</td>
#       <td id="T_f8a93_row1_col1" class="data row1 col1" ></td>
#       <td id="T_f8a93_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_f8a93_row1_col3" class="data row1 col3" >1270</td>
#       <td id="T_f8a93_row1_col4" class="data row1 col4" >121</td>
#       <td id="T_f8a93_row1_col5" class="data row1 col5" >1699</td>
#       <td id="T_f8a93_row1_col6" class="data row1 col6" >204</td>
#       <td id="T_f8a93_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_f8a93_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_f8a93_row1_col9" class="data row1 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8a93_row2_col0" class="data row2 col0" >LinearRegression</td>
#       <td id="T_f8a93_row2_col1" class="data row2 col1" ></td>
#       <td id="T_f8a93_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_f8a93_row2_col3" class="data row2 col3" >1181</td>
#       <td id="T_f8a93_row2_col4" class="data row2 col4" >240</td>
#       <td id="T_f8a93_row2_col5" class="data row2 col5" >2146</td>
#       <td id="T_f8a93_row2_col6" class="data row2 col6" >1522</td>
#       <td id="T_f8a93_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_f8a93_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_f8a93_row2_col9" class="data row2 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8a93_row3_col0" class="data row3 col0" >LinearRegression</td>
#       <td id="T_f8a93_row3_col1" class="data row3 col1" ></td>
#       <td id="T_f8a93_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_f8a93_row3_col3" class="data row3 col3" >1644</td>
#       <td id="T_f8a93_row3_col4" class="data row3 col4" >960</td>
#       <td id="T_f8a93_row3_col5" class="data row3 col5" >3426</td>
#       <td id="T_f8a93_row3_col6" class="data row3 col6" >3578</td>
#       <td id="T_f8a93_row3_col7" class="data row3 col7" >-2</td>
#       <td id="T_f8a93_row3_col8" class="data row3 col8" >5</td>
#       <td id="T_f8a93_row3_col9" class="data row3 col9" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8a93_row4_col0" class="data row4 col0" >LinearRegression</td>
#       <td id="T_f8a93_row4_col1" class="data row4 col1" ></td>
#       <td id="T_f8a93_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_f8a93_row4_col3" class="data row4 col3" >1141</td>
#       <td id="T_f8a93_row4_col4" class="data row4 col4" >208</td>
#       <td id="T_f8a93_row4_col5" class="data row4 col5" >2194</td>
#       <td id="T_f8a93_row4_col6" class="data row4 col6" >1709</td>
#       <td id="T_f8a93_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_f8a93_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_f8a93_row4_col9" class="data row4 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8a93_row5_col0" class="data row5 col0" >LinearRegression</td>
#       <td id="T_f8a93_row5_col1" class="data row5 col1" ></td>
#       <td id="T_f8a93_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_f8a93_row5_col3" class="data row5 col3" >1263</td>
#       <td id="T_f8a93_row5_col4" class="data row5 col4" >344</td>
#       <td id="T_f8a93_row5_col5" class="data row5 col5" >2214</td>
#       <td id="T_f8a93_row5_col6" class="data row5 col6" >1586</td>
#       <td id="T_f8a93_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_f8a93_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_f8a93_row5_col9" class="data row5 col9" >0.3</td>
#     </tr>
#     <tr>
#       <th id="T_f8a93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8a93_row6_col0" class="data row6 col0" >LinearRegression</td>
#       <td id="T_f8a93_row6_col1" class="data row6 col1" ></td>
#       <td id="T_f8a93_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_f8a93_row6_col3" class="data row6 col3" >1824</td>
#       <td id="T_f8a93_row6_col4" class="data row6 col4" >1140</td>
#       <td id="T_f8a93_row6_col5" class="data row6 col5" >5713</td>
#       <td id="T_f8a93_row6_col6" class="data row6 col6" >8047</td>
#       <td id="T_f8a93_row6_col7" class="data row6 col7"

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)
# Out:
# <style type="text/css">
# #T_cb651_row0_col3, #T_cb651_row3_col4, #T_cb651_row3_col5, #T_cb651_row3_col6, #T_cb651_row3_col7, #T_cb651_row3_col8 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_cb651_row0_col4, #T_cb651_row0_col5, #T_cb651_row2_col6, #T_cb651_row2_col8, #T_cb651_row3_col3, #T_cb651_row4_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_cb651_row0_col6, #T_cb651_row0_col8, #T_cb651_row1_col3, #T_cb651_row2_col4, #T_cb651_row2_col5, #T_cb651_row5_col7 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_cb651_row0_col7, #T_cb651_row4_col3, #T_cb651_row4_col4, #T_cb651_row4_col5, #T_cb651_row4_col6, #T_cb651_row4_col8 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_cb651_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_cb651_row1_col4, #T_cb651_row1_col5, #T_cb651_row1_col6, #T_cb651_row1_col8, #T_cb651_row2_col3, #T_cb651_row6_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_cb651_row1_col7, #T_cb651_row6_col3, #T_cb651_row6_col4, #T_cb651_row6_col5, #T_cb651_row6_col6, #T_cb651_row6_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cb651_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_cb651_row2_col7, #T_cb651_row5_col3, #T_cb651_row5_col4, #T_cb651_row5_col5, #T_cb651_row5_col6, #T_cb651_row5_col8 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_cb651_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.7%, transparent 4.7%);
# }
# #T_cb651_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.0%, transparent 7.0%);
# }
# #T_cb651_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.0%, transparent 16.0%);
# }
# #T_cb651_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.9%, transparent 36.9%);
# }
# #T_cb651_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_cb651">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb651_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_cb651_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_cb651_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_cb651_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_cb651_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_cb651_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_cb651_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_cb651_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_cb651_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_cb651_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb651_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb651_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_cb651_row0_col1" class="data row0 col1" ></td>
#       <td id="T_cb651_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_cb651_row0_col3" class="data row0 col3" >2239</td>
#       <td id="T_cb651_row0_col4" class="data row0 col4" >297</td>
#       <td id="T_cb651_row0_col5" class="data row0 col5" >2919</td>
#       <td id="T_cb651_row0_col6" class="data row0 col6" >375</td>
#       <td id="T_cb651_row0_col7" class="data row0 col7" >-0</td>
#       <td id="T_cb651_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_cb651_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb651_row1_col0" class="data row1 col0" >LinearRegression</td>
#       <td id="T_cb651_row1_col1" class="data row1 col1" ></td>
#       <td id="T_cb651_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_cb651_row1_col3" class="data row1 col3" >1270</td>
#       <td id="T_cb651_row1_col4" class="data row1 col4" >121</td>
#       <td id="T_cb651_row1_col5" class="data row1 col5" >1699</td>
#       <td id="T_cb651_row1_col6" class="data row1 col6" >204</td>
#       <td id="T_cb651_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_cb651_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_cb651_row1_col9" class="data row1 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb651_row2_col0" class="data row2 col0" >LinearRegression</td>
#       <td id="T_cb651_row2_col1" class="data row2 col1" ></td>
#       <td id="T_cb651_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_cb651_row2_col3" class="data row2 col3" >1181</td>
#       <td id="T_cb651_row2_col4" class="data row2 col4" >240</td>
#       <td id="T_cb651_row2_col5" class="data row2 col5" >2146</td>
#       <td id="T_cb651_row2_col6" class="data row2 col6" >1522</td>
#       <td id="T_cb651_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_cb651_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_cb651_row2_col9" class="data row2 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb651_row3_col0" class="data row3 col0" >LinearRegression</td>
#       <td id="T_cb651_row3_col1" class="data row3 col1" ></td>
#       <td id="T_cb651_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_cb651_row3_col3" class="data row3 col3" >1919</td>
#       <td id="T_cb651_row3_col4" class="data row3 col4" >2146</td>
#       <td id="T_cb651_row3_col5" class="data row3 col5" >9718</td>
#       <td id="T_cb651_row3_col6" class="data row3 col6" >17214</td>
#       <td id="T_cb651_row3_col7" class="data row3 col7" >-45</td>
#       <td id="T_cb651_row3_col8" class="data row3 col8" >91</td>
#       <td id="T_cb651_row3_col9" class="data row3 col9" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb651_row4_col0" class="data row4 col0" >LinearRegression</td>
#       <td id="T_cb651_row4_col1" class="data row4 col1" ></td>
#       <td id="T_cb651_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_cb651_row4_col3" class="data row4 col3" >6301644411</td>
#       <td id="T_cb651_row4_col4" class="data row4 col4" >12603287292</td>
#       <td id="T_cb651_row4_col5" class="data row4 col5" >127195250790</td>
#       <td id="T_cb651_row4_col6" class="data row4 col6" >254390499551</td>
#       <td id="T_cb651_row4_col7" class="data row4 col7" >-9466413776816030</td>
#       <td id="T_cb651_row4_col8" class="data row4 col8" >18932827553632060</td>
#       <td id="T_cb651_row4_col9" class="data row4 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb651_row5_col0" class="data row5 col0" >LinearRegression</td>
#       <td id="T_cb651_row5_col1" class="data row5 col1" ></td>
#       <td id="T_cb651_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_cb651_row5_col3" class="data row5 col3" >75362562040</td>
#       <td id="T_cb651_row5_col4" class="data row5 col4" >150725122555</td>
#       <td id="T_cb651_row5_col5" class="data row5 col5" >1437048288940</td>
#       <td id="T_cb651_row5_col6" class="data row5 col6" >2874096575803</td>
#       <td id="T_cb651_row5_col7" class="data row5 col7" >-1208332399438686464</td>
#       <td id="T_cb651_row5_col8" class="data row5 col8" >2416664798877372928</td>
#       <td id="T_cb651_row5_col9" class="data row5 col9" >0.3</td>
#     </tr>
#     <tr>
#       <th id="T_cb651_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb651_row6_col0" class="data row6 col0" >LinearRegression</td>
#       <td id="T_cb651_row6_col1" class="data row6 col1" ></td>
#       <td id="T_cb651_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_cb651_row6_col3" class="data row6 col3" >316918391633</td>
#       <td id="T_cb651_r

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = normalize(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)
# Out:
# <style type="text/css">
# #T_21566_row0_col3, #T_21566_row1_col7, #T_21566_row4_col6, #T_21566_row4_col8, #T_21566_row5_col4, #T_21566_row5_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_21566_row0_col4, #T_21566_row0_col5, #T_21566_row0_col6, #T_21566_row0_col8, #T_21566_row1_col3, #T_21566_row4_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_21566_row0_col7, #T_21566_row4_col4, #T_21566_row4_col5, #T_21566_row5_col3, #T_21566_row5_col6, #T_21566_row5_col8 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_21566_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_21566_row1_col4, #T_21566_row1_col5, #T_21566_row2_col6, #T_21566_row2_col8, #T_21566_row3_col3, #T_21566_row5_col7 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_21566_row1_col6, #T_21566_row1_col8, #T_21566_row2_col3, #T_21566_row2_col4, #T_21566_row2_col5, #T_21566_row6_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_21566_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.9%, transparent 2.9%);
# }
# #T_21566_row2_col7, #T_21566_row6_col3, #T_21566_row6_col4, #T_21566_row6_col5, #T_21566_row6_col6, #T_21566_row6_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_21566_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.6%, transparent 4.6%);
# }
# #T_21566_row3_col4, #T_21566_row3_col5, #T_21566_row3_col6, #T_21566_row3_col7, #T_21566_row3_col8, #T_21566_row4_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_21566_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.2%, transparent 9.2%);
# }
# #T_21566_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_21566_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.4%, transparent 48.4%);
# }
# #T_21566_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_21566">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21566_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_21566_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_21566_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_21566_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_21566_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_21566_level0_col5" class="col_heading level0 col5" >RMSE_mean</th>
#       <th id="T_21566_level0_col6" class="col_heading level0 col6" >RMSE_std</th>
#       <th id="T_21566_level0_col7" class="col_heading level0 col7" >R2_mean</th>
#       <th id="T_21566_level0_col8" class="col_heading level0 col8" >R2_std</th>
#       <th id="T_21566_level0_col9" class="col_heading level0 col9" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21566_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21566_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_21566_row0_col1" class="data row0 col1" ></td>
#       <td id="T_21566_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_21566_row0_col3" class="data row0 col3" >2239</td>
#       <td id="T_21566_row0_col4" class="data row0 col4" >297</td>
#       <td id="T_21566_row0_col5" class="data row0 col5" >2919</td>
#       <td id="T_21566_row0_col6" class="data row0 col6" >375</td>
#       <td id="T_21566_row0_col7" class="data row0 col7" >-0</td>
#       <td id="T_21566_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_21566_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21566_row1_col0" class="data row1 col0" >LinearRegression</td>
#       <td id="T_21566_row1_col1" class="data row1 col1" ></td>
#       <td id="T_21566_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_21566_row1_col3" class="data row1 col3" >1687</td>
#       <td id="T_21566_row1_col4" class="data row1 col4" >135</td>
#       <td id="T_21566_row1_col5" class="data row1 col5" >2169</td>
#       <td id="T_21566_row1_col6" class="data row1 col6" >204</td>
#       <td id="T_21566_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_21566_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_21566_row1_col9" class="data row1 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21566_row2_col0" class="data row2 col0" >LinearRegression</td>
#       <td id="T_21566_row2_col1" class="data row2 col1" ></td>
#       <td id="T_21566_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_21566_row2_col3" class="data row2 col3" >1499</td>
#       <td id="T_21566_row2_col4" class="data row2 col4" >118</td>
#       <td id="T_21566_row2_col5" class="data row2 col5" >1957</td>
#       <td id="T_21566_row2_col6" class="data row2 col6" >221</td>
#       <td id="T_21566_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_21566_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_21566_row2_col9" class="data row2 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21566_row3_col0" class="data row3 col0" >LinearRegression</td>
#       <td id="T_21566_row3_col1" class="data row3 col1" ></td>
#       <td id="T_21566_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_21566_row3_col3" class="data row3 col3" >1523</td>
#       <td id="T_21566_row3_col4" class="data row3 col4" >606</td>
#       <td id="T_21566_row3_col5" class="data row3 col5" >5993</td>
#       <td id="T_21566_row3_col6" class="data row3 col6" >7436</td>
#       <td id="T_21566_row3_col7" class="data row3 col7" >-10</td>
#       <td id="T_21566_row3_col8" class="data row3 col8" >20</td>
#       <td id="T_21566_row3_col9" class="data row3 col9" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21566_row4_col0" class="data row4 col0" >LinearRegression</td>
#       <td id="T_21566_row4_col1" class="data row4 col1" ></td>
#       <td id="T_21566_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_21566_row4_col3" class="data row4 col3" >1692</td>
#       <td id="T_21566_row4_col4" class="data row4 col4" >1116</td>
#       <td id="T_21566_row4_col5" class="data row4 col5" >12999</td>
#       <td id="T_21566_row4_col6" class="data row4 col6" >16488</td>
#       <td id="T_21566_row4_col7" class="data row4 col7" >-52</td>
#       <td id="T_21566_row4_col8" class="data row4 col8" >94</td>
#       <td id="T_21566_row4_col9" class="data row4 col9" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21566_row5_col0" class="data row5 col0" >LinearRegression</td>
#       <td id="T_21566_row5_col1" class="data row5 col1" ></td>
#       <td id="T_21566_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_21566_row5_col3" class="data row5 col3" >2028</td>
#       <td id="T_21566_row5_col4" class="data row5 col4" >1254</td>
#       <td id="T_21566_row5_col5" class="data row5 col5" >18709</td>
#       <td id="T_21566_row5_col6" class="data row5 col6" >15837</td>
#       <td id="T_21566_row5_col7" class="data row5 col7" >-79</td>
#       <td id="T_21566_row5_col8" class="data row5 col8" >90</td>
#       <td id="T_21566_row5_col9" class="data row5 col9" >0.4</td>
#     </tr>
#     <tr>
#       <th id="T_21566_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21566_row6_col0" class="data row6 col0" >LinearRegression</td>
#       <td id="T_21566_row6_col1" class="data row6 col1" ></td>
#       <td id="T_21566_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_21566_row6_col3" class="data row6 col3" >3833</td>
#       <td id="T_21566_row6_col4" class="data row6 col4" >2812</td>
#       <td id="T_21566_row6_col5" class="data row6 col5" >59776</td>
#       <td id="T_2156

# %%
all_r = []
for i in range(1, 20):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = minmax_scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %% [markdown]
# ## Trees

# %%
n_est_list = [100]
models_and_params = [
    # (LinearRegression, {}),
    # (Lasso, {'random_state': RS}),
    # (Ridge, {'random_state': RS}),
    (DecisionTreeRegressor, {}),
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

r = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(r)
)
