# %% [markdown]
# # Setup

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (1.6.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.0.6)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost) (1.8.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.22.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.5.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.4.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.10.0)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.0.1)

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport transformations

# %aimport transformations
# %aimport f
# Out:
# transformations loaded, version: 0.1
# framework loaded, version: 0.1

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import time

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113

import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.preprocessing import StandardScaler, PowerTransformer

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture

RS = 35577 # global random state seed
data_path = './data-raw/'

# %%
(X, y) = f.from_pkl(f'data-processed/all_b1_b2.data.pkl')

X.shape
X.columns

y.shape
y.value_counts()
# Out:
# (200, 36)
# Index(['x__amin', 'x__amax', 'x__sum', 'x__median', 'x__mean', 'x__std',
#        'x__var', 'x__q1', 'x__q3', 'x__iqr', 'x__kurtosis', 'x__skew',
#        'y__amin', 'y__amax', 'y__sum', 'y__median', 'y__mean', 'y__std',
#        'y__var', 'y__q1', 'y__q3', 'y__iqr', 'y__kurtosis', 'y__skew',
#        'z__amin', 'z__amax', 'z__sum', 'z__median', 'z__mean', 'z__std',
#        'z__var', 'z__q1', 'z__q3', 'z__iqr', 'z__kurtosis', 'z__skew'],
#       dtype='object')
# (200,)
# 1    100
# 0    100
# Name: status, dtype: int64

# %% [markdown]
# # CV

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
import itertools

def grid_exec(func, *args):
    return [func(*element) for element in itertools.product(*args)]

def grid_exec_callback(func, callback, *args):
    return [ callback(func(*element)) for element in itertools.product(*args)]

# %%
all_trained_models = []

def cross_val(model_and_params, X, y, n_folds = 5, n_fold_repeats = 1, n_model_repeats = 1):
    np.random.seed(RS)
    get_random = lambda  : np.random.randint(1, 2**16)
    cv_scores = []
    n_folds_completed = 0
    
    start_time = time.perf_counter()
    
    cv = RepeatedStratifiedKFold(n_splits=n_folds, n_repeats=n_fold_repeats, random_state=get_random())
    for i_fold, (idx_train, idx_test) in enumerate(cv.split(X, y)):
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        X_test, y_test = X.iloc[idx_test], y.iloc[idx_test]

        model_scores = []
        cv_scores.append(model_scores)
        n_folds_completed += 1

        for i_model in range(n_model_repeats):
            constructor, params_dic = model_and_params
            
            if 'random_state' in params_dic.keys():
                params_dic['random_state'] = get_random()
            
            model = constructor(**params_dic)
            all_trained_models.append(model)
            
            model.fit(X_train, y_train)
            
            y_pred = model.predict_proba(X_test)[:, 1]
            score = roc_auc_score(y_test, y_pred)
            model_scores.append(score)

        model_name = model.__class__.__name__
        model_params = params_dic.copy()
        
    total_elapsed_time = time.perf_counter() - start_time
    return model_name, model_params, n_folds_completed, n_model_repeats, total_elapsed_time, np.array(cv_scores)

# %%
def get_stats_df(cv_results):
    ret_list = []
    
    for result in cv_results:
        model_params = result[1]
        model_params.pop('random_state', None)
        model_params.pop('silent', None)
        
        stats_ = result[5]
        
        ret_list.append(
            {
                'model' : result[0],
                # '#' : None,
                '#1' : None,
                '#2' : None,
                'params' : str(model_params).strip('{').strip('}'),
                'n_folds' : result[2],    
                'n_model_repeats' : result[3],

                'min': stats_.min(),
                'mean': stats_.mean(),
                'max': stats_.max(),
                'std': stats_.std(),

                'folds_min': stats_.mean(axis=1).min(),
                'folds_mean': stats_.mean(axis=1).mean(),
                'folds_max': stats_.mean(axis=1).max(),
                'folds_std': stats_.mean(axis=1).std(),
                
                'time': round(result[4], 1), 
            })
    df = pd.DataFrame(ret_list)
    
    # df['#'] = df.groupby('model', group_keys=False).apply(
    #             lambda df: (df['mean'].rank(ascending = False) \
    #                       + df['min'].rank(ascending = False) \
    #                       + df['folds_mean_std'].rank(ascending = True)
    #                        ).rank()).astype(int)
    
    df['#1'] = (df['mean'].rank(ascending = False) \
                      + df['min'].rank(ascending = False) \
                      + df['folds_std'].rank(ascending = True)
                       ).rank().astype(int)
    
    df['#2'] = (
        minmax_scale(df['mean'].values.reshape(-1, 1))
        + minmax_scale(df['min'].values.reshape(-1, 1))
        + (1 - minmax_scale(df['folds_std'].values.reshape(-1, 1)))
          )
    
    df['#2'] = df['#2'].rank(ascending=False).astype(int)
    
    return df

def display_stats(df_stats):
    styler = df_stats.style
    styler.format('{:,.3f}', df_stats.columns[6:])\
          .format('{:,.1f}', df_stats.columns[-1])\
          .background_gradient(cmap='Oranges', subset=['#1', '#2'], axis=0)
    
    for c in df_stats.columns[6:10]:
        styler.background_gradient(cmap='Blues', subset=c, gmap=df_stats[c].rank())
        
    for c in df_stats.columns[10:-1]:
        styler.background_gradient(cmap='Greens', subset=c, gmap=df_stats[c].rank())      
    styler.bar(subset='time')
    display(styler)
    
# def display_stats_v1(df_stats):
#     display(df_stats.style\
#             .format('{:,.3f}', df_stats.columns[5:])\
#             .format('{:,.1f}', df_stats.columns[-1])\
#             .background_gradient(cmap='Reds', subset=['#1', '#2'], axis=0)\
#             .background_gradient(cmap='Blues', subset=df_stats.columns[6:10], axis=0)\
#             .background_gradient(cmap='Greens', subset=df_stats.columns[10:-1], axis=0)\
#            )

# %% [markdown]
# ## Multiple Models

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# ## First Run

# %%
all_results = []

def on_1_completed(results):
    all_results.append(results)
    clear_output(wait=True)
    get_stats_df(all_results)
    display_stats(get_stats_df(all_results))

grid_func = lambda factory, n_folds, n_fold_repeats, n_model_repeats: cross_val(factory, X, y, n_folds, n_fold_repeats, n_model_repeats)

# %%
n_est_list = [50, 200, 400]

all_models = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]

n_folds_list = [5]
n_fold_repeats_list = [2]
n_model_repeats_list = [5]

_ = grid_exec_callback(grid_func, on_1_completed, 
                       all_models, n_folds_list, n_fold_repeats_list, n_model_repeats_list)
# Out:
# <style type="text/css">
# #T_da338_row0_col1, #T_da338_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_da338_row0_col6, #T_da338_row0_col7, #T_da338_row0_col8, #T_da338_row7_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_da338_row0_col9, #T_da338_row2_col8, #T_da338_row3_col8, #T_da338_row4_col8, #T_da338_row5_col8, #T_da338_row6_col8, #T_da338_row7_col6, #T_da338_row7_col7, #T_da338_row7_col8, #T_da338_row8_col8, #T_da338_row9_col8, #T_da338_row10_col8, #T_da338_row11_col8, #T_da338_row12_col8, #T_da338_row13_col8, #T_da338_row14_col8, #T_da338_row15_col8, #T_da338_row16_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_da338_row0_col10, #T_da338_row0_col11, #T_da338_row0_col12, #T_da338_row7_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_da338_row0_col13, #T_da338_row2_col12, #T_da338_row3_col12, #T_da338_row4_col12, #T_da338_row5_col12, #T_da338_row6_col12, #T_da338_row7_col10, #T_da338_row7_col11, #T_da338_row7_col12, #T_da338_row8_col12, #T_da338_row9_col12, #T_da338_row10_col12, #T_da338_row11_col12, #T_da338_row12_col12, #T_da338_row13_col12, #T_da338_row14_col12, #T_da338_row15_col12, #T_da338_row16_col12 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_da338_row0_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_da338_row1_col1, #T_da338_row1_col2 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_da338_row1_col6, #T_da338_row1_col7, #T_da338_row8_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_da338_row1_col8 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_da338_row1_col9, #T_da338_row9_col6, #T_da338_row16_col7 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_da338_row1_col10, #T_da338_row1_col11, #T_da338_row8_col13 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_da338_row1_col12 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_da338_row1_col13, #T_da338_row9_col10, #T_da338_row16_col11 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_da338_row1_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_da338_row2_col1, #T_da338_row2_col2 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_da338_row2_col6, #T_da338_row5_col7, #T_da338_row15_col9 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_da338_row2_col7, #T_da338_row6_col9, #T_da338_row14_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_da338_row2_col9, #T_da338_row5_col6, #T_da338_row14_col7 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_da338_row2_col10, #T_da338_row3_col13, #T_da338_row4_col11 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_da338_row2_col11, #T_da338_row14_col13 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_da338_row2_col13, #T_da338_row3_col10, #T_da338_row6_col11 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_da338_row2_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.8%, transparent 4.8%);
# }
# #T_da338_row3_col1, #T_da338_row3_col2 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_da338_row3_col6, #T_da338_row4_col6 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_da338_row3_col7, #T_da338_row14_col9 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_da338_row3_col9, #T_da338_row4_col7 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_da338_row3_col11, #T_da338_row6_col13 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_da338_row3_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.3%, transparent 17.3%);
# }
# #T_da338_row4_col1, #T_da338_row4_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_da338_row4_col9, #T_da338_row8_col7 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_da338_row4_col10, #T_da338_row9_col11, #T_da338_row11_col13 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_da338_row4_col13, #T_da338_row8_col11, #T_da338_row16_col10 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_da338_row4_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.6%, transparent 33.6%);
# }
# #T_da338_row5_col1, #T_da338_row5_col2 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_da338_row5_col9, #T_da338_row6_col7 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_da338_row5_col10, #T_da338_row15_col10 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_da338_row5_col11, #T_da338_row14_col10, #T_da338_row15_col13 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_da338_row5_col13, #T_da338_row6_col10, #T_da338_row14_col11 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_da338_row5_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.7%, transparent 4.7%);
# }
# #T_da338_row6_col1, #T_da338_row6_col2 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_da338_row6_col6, #T_da338_row9_col7, #T_da338_row11_col9 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_da338_row6_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_da338_row7_col1, #T_da338_row7_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_da338_row7_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.0%, transparent 38.0%);
# }
# #T_da338_row8_col1, #T_da338_row10_col2, #T_da338_row16_col1 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_da338_row8_col2, #T_da338_row10_col1 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_da338_row8_col6, #T_da338_row10_col6, #T_da338_row12_col9, #T_da338_row13_col9 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_da338_row8_col10, #T_da338_row10_col10, #T_da338_row12_col13, #T_da338_row13_col13 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_da338_row8_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.1%, transparent 1.1%);
# }
# #T_da338_row9_col1, #T_da338_row9_col2 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_da338_row9_col9, #T_da338_row11_col7 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_da338_row9_col13, #T_da338_row11_col11 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_da338_row9_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.5%, transparent 2.5%);
# }
# #T_da338_row10_col7 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_da338_row10_col9 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_da338_row10_col11 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_da338_row10_col13 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_da338_row10_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.3%, transparent 3.3%);
# }
# #T_da338_row11_col1, #T_da338_row11_col2 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_da338_row11_col6, #T_da338_row16_col9 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_da338_row11_col10, #T_da338_row16_col13 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_da338_row11_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.0%, transparent 8.0%);
# }
# #T_da338_row12_col1, #T_da338_row12_col2, #T_da338_row13_col1, #T_da338_row13_col2 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_da338_row12_col6, #T_da338_row13_col6 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_da338_row12_col7, #T_da338_row13_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_da338_row12_col10, #T_da338_row13_col10 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_da338_row12_col11, #T_da338_row13_col11 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_da338_row12_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_da338_row13_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.0%, transparent 49.0%);
# }
# #T_da338_row14_col1, #T_da338_row14_col2 {
#   background-color: #fd9d53;
#   color: #000000;
# }
# #T_da338_row14_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.2%, transparent 14.2%);
# }
# #T_da338_row15_col1, #T_da338_row15_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_da338_row15_col6, #T_da338_row16_col6

# %% [markdown]
# ## Second Run

# %%
all_results2 = []

def on_1_completed(results):
    all_results2.append(results)
    clear_output(wait=True)
    get_stats_df(all_results2)
    display_stats(get_stats_df(all_results2))

grid_func = lambda factory, n_folds, n_fold_repeats, n_model_repeats: cross_val(factory, X, y, n_folds, n_fold_repeats, n_model_repeats)

# %%
n_est_list = [50, 200, 400]

all_models = [
    (DecisionTreeClassifier, {}),
    (KNeighborsClassifier, {}),
    
    *[ (RandomForestClassifier, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostClassifier,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMClassifier,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBClassifier,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostClassifier,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]

n_folds_list = [5]
n_fold_repeats_list = [5]
n_model_repeats_list = [20]

_ = grid_exec_callback(grid_func, on_1_completed, 
                       all_models, n_folds_list, n_fold_repeats_list, n_model_repeats_list)
# Out:
# <style type="text/css">
# #T_35ee2_row0_col1, #T_35ee2_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_35ee2_row0_col6, #T_35ee2_row0_col7, #T_35ee2_row0_col8, #T_35ee2_row9_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_35ee2_row0_col9, #T_35ee2_row2_col8, #T_35ee2_row3_col8, #T_35ee2_row4_col8, #T_35ee2_row5_col8, #T_35ee2_row6_col8, #T_35ee2_row7_col7, #T_35ee2_row7_col8, #T_35ee2_row8_col8, #T_35ee2_row9_col6, #T_35ee2_row9_col8, #T_35ee2_row10_col8, #T_35ee2_row11_col8, #T_35ee2_row12_col8, #T_35ee2_row13_col8, #T_35ee2_row14_col8, #T_35ee2_row15_col8, #T_35ee2_row16_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_35ee2_row0_col10, #T_35ee2_row0_col11, #T_35ee2_row0_col12, #T_35ee2_row7_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_35ee2_row0_col13, #T_35ee2_row3_col12, #T_35ee2_row4_col12, #T_35ee2_row5_col12, #T_35ee2_row6_col12, #T_35ee2_row7_col11, #T_35ee2_row7_col12, #T_35ee2_row8_col12, #T_35ee2_row9_col12, #T_35ee2_row10_col12, #T_35ee2_row11_col12, #T_35ee2_row12_col12, #T_35ee2_row13_col12, #T_35ee2_row14_col12, #T_35ee2_row15_col12, #T_35ee2_row16_col10, #T_35ee2_row16_col12 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_35ee2_row0_col14, #T_35ee2_row1_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_35ee2_row1_col1, #T_35ee2_row1_col2 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_35ee2_row1_col6, #T_35ee2_row1_col7, #T_35ee2_row7_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_35ee2_row1_col8 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_35ee2_row1_col9, #T_35ee2_row10_col6, #T_35ee2_row16_col7 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_35ee2_row1_col10, #T_35ee2_row1_col11, #T_35ee2_row9_col13 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_35ee2_row1_col12 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_35ee2_row1_col13, #T_35ee2_row15_col10, #T_35ee2_row16_col11 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_35ee2_row2_col1, #T_35ee2_row2_col2 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_35ee2_row2_col6, #T_35ee2_row5_col7, #T_35ee2_row15_col9 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_35ee2_row2_col7, #T_35ee2_row3_col6, #T_35ee2_row8_col9 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_35ee2_row2_col9, #T_35ee2_row4_col6, #T_35ee2_row14_col7 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_35ee2_row2_col10, #T_35ee2_row3_col11, #T_35ee2_row8_col13 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_35ee2_row2_col11, #T_35ee2_row4_col13, #T_35ee2_row7_col10 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_35ee2_row2_col12 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_35ee2_row2_col13, #T_35ee2_row3_col10, #T_35ee2_row4_col11 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_35ee2_row2_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_35ee2_row3_col1, #T_35ee2_row3_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_35ee2_row3_col7, #T_35ee2_row4_col9, #T_35ee2_row5_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_35ee2_row3_col9, #T_35ee2_row4_col7, #T_35ee2_row14_col6 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_35ee2_row3_col13, #T_35ee2_row4_col10, #T_35ee2_row14_col11 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_35ee2_row3_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.5%, transparent 14.5%);
# }
# #T_35ee2_row4_col1, #T_35ee2_row4_col2 {
#   background-color: #fd9d53;
#   color: #000000;
# }
# #T_35ee2_row4_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.8%, transparent 28.8%);
# }
# #T_35ee2_row5_col1, #T_35ee2_row5_col2 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_35ee2_row5_col9, #T_35ee2_row6_col7, #T_35ee2_row7_col6 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_35ee2_row5_col10, #T_35ee2_row8_col11, #T_35ee2_row14_col13 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_35ee2_row5_col11, #T_35ee2_row8_col10, #T_35ee2_row15_col13 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_35ee2_row5_col13, #T_35ee2_row6_col10, #T_35ee2_row6_col11 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_35ee2_row5_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.0%, transparent 4.0%);
# }
# #T_35ee2_row6_col1, #T_35ee2_row6_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_35ee2_row6_col6, #T_35ee2_row12_col9, #T_35ee2_row13_col9, #T_35ee2_row15_col6 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_35ee2_row6_col9 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_35ee2_row6_col13, #T_35ee2_row11_col10 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_35ee2_row6_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.8%, transparent 15.8%);
# }
# #T_35ee2_row7_col1, #T_35ee2_row9_col1, #T_35ee2_row9_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_35ee2_row7_col2 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_35ee2_row7_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.1%, transparent 32.1%);
# }
# #T_35ee2_row8_col1, #T_35ee2_row8_col2 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_35ee2_row8_col6, #T_35ee2_row8_col7, #T_35ee2_row14_col9 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_35ee2_row8_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_35ee2_row9_col7 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_35ee2_row9_col10, #T_35ee2_row11_col13, #T_35ee2_row15_col11 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_35ee2_row9_col11, #T_35ee2_row10_col10 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_35ee2_row9_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.7%, transparent 1.7%);
# }
# #T_35ee2_row10_col1, #T_35ee2_row16_col1, #T_35ee2_row16_col2 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_35ee2_row10_col2 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_35ee2_row10_col7 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_35ee2_row10_col9, #T_35ee2_row11_col7 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_35ee2_row10_col11, #T_35ee2_row14_col10 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_35ee2_row10_col13, #T_35ee2_row11_col11 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_35ee2_row10_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.5%, transparent 2.5%);
# }
# #T_35ee2_row11_col1, #T_35ee2_row11_col2 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_35ee2_row11_col6, #T_35ee2_row16_col9 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_35ee2_row11_col9, #T_35ee2_row15_col7, #T_35ee2_row16_col6 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_35ee2_row11_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.8%, transparent 5.8%);
# }
# #T_35ee2_row12_col1, #T_35ee2_row12_col2, #T_35ee2_row13_col1, #T_35ee2_row13_col2 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_35ee2_row12_col6, #T_35ee2_row13_col6 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_35ee2_row12_col7, #T_35ee2_row13_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_35ee2_row12_col10, #T_35ee2_row13_col10 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_35ee2_row12_col11, #T_35ee2_row13_col11 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_35ee2_row12_col13, #T_35ee2_row13_col13 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_35ee2_row12_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_35ee2_row13_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.1%, transparent 39.1%);
# }
# #T_35ee2_row14_col1, #T_35ee2_row14_col2 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_35ee2_row14_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.4%, transparent 13.4%);
# }
# #T_35ee2_row15_col1, #T_35ee2_row15_col2 {
#   background-color: #fdd0a2;
#   color: #0000

# %% [markdown]
# ## Shortlist models

# %% [markdown]
# ## Shortlist based on [model_repeat_n]

# %% [markdown]
# ## Shortlist based on [model_repeat_n] v2

# %% [markdown]
# ## Shortlist based on [cv_repeat_n]

# %% [markdown]
# ## Shortlist based on [folds_n]

# %% [markdown]
# ## Shortlist

# %%
# m = all_trained_models[0]
# pd.Series(data = m.feature_importances_, index = m.feature_names_in_).sort_values(ascending=False)

# m = all_trained_models[6]
# pd.Series(data = m.feature_importances_, index = m.feature_names_in_).sort_values(ascending=False)

# m = all_trained_models[12]
# pd.Series(data = m.feature_importances_, index = m.feature_name_).sort_values(ascending=False)

# %%
# all_fe = []

# for m in all_trained_models:
#     if 'feature_names_in_' in m.__dict__.keys():
#         all_fe.append(
#             pd.Series(data = m.feature_importances_, index = m.feature_names_in_).rank().astype(int)
#         )
#     else:
#         all_fe.append(
#             pd.Series(data = m.feature_importances_, index = m.feature_name_).rank().astype(int)
#         )

# fe = pd.concat(all_fe, axis=1).sort_values(by=[0, 1, 2], ascending=False).head(15)
# fe

# %%
# all_fe = []

# for i, m in enumerate(all_trained_models):
#     if 'feature_names_in_' in m.__dict__.keys():
#         all_fe.append(
#             pd.Series(data = m.feature_importances_, index = m.feature_names_in_, name=f'{m.__class__.__name__[0]}_{i}')#.rank().astype(int)
#         )
#     else:
#         all_fe.append(
#             pd.Series(data = m.feature_importances_, index = m.feature_name_, name=f'{m.__class__.__name__[0]}_{i}')
#         )

# fe = pd.concat(all_fe, axis=1)
# fe['sum_1'] = fe.iloc[:, :6].sum(axis=1)
# fe['sum_2'] = fe.iloc[:, 6:12].sum(axis=1)
# fe['sum_3'] = fe.iloc[:, 12:].sum(axis=1)
# fe.sort_values(by=['sum_1', 'sum_2', 'sum_3'], ascending=False)\
#     .round(2)\
#     .style\
#     .format('{:,.2f}', subset=fe.columns[:12])\
#     .format('{:,.2f}', subset=fe.columns[-3:])\
#     .highlight_max(color='green')\
#     .highlight_min(color='blue')\
#     .highlight_max(color='red', subset=['sum_1', 'sum_2', 'sum_3'])
