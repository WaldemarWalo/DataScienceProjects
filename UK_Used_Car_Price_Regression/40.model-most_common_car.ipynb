# %% [markdown]
# # Setup and Imports

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
import time

# %%
df_data = t.from_pkl(f'{processed_data_path}/df_clean.pkl')

df_data.shape
df_data.head(3)
# Out:
# (97323, 8)
#    make model  year  price transmission  mileage fuelType  engineSize
# 0  Audi    A1  2017  12500       Manual    15735   Petrol         1.4
# 1  Audi    A6  2016  16500    Automatic    36203   Diesel         2.0
# 2  Audi    A1  2016  11000       Manual    29946   Petrol         1.4

# %%
df_data.insert(0, 'car', df_data['make'] + '__' + df_data['model'])
df_data = df_data.drop(columns=['make', 'model'])

# %%
df_data.groupby(['car']).size().sort_values(ascending=False).head(10)
# Out:
# car
# Ford__Fiesta       6508
# Vw__Golf           4769
# Ford__Focus        4555
# Merc__C Class      3689
# Vauxhall__Corsa    3285
# Vw__Polo           3230
# Vauxhall__Astra    2655
# Merc__A Class      2474
# Bmw__3 Series      2413
# Ford__Kuga         2208
# dtype: int64

# %%
df_fiesta = df_data.loc[ (df_data['car'] == 'Ford__Fiesta') ].drop(columns=['car']).copy()
df_fiesta.head(3)
# Out:
#        year  price transmission  mileage fuelType  engineSize
# 21449  2017  12000    Automatic    15944   Petrol         1.0
# 21452  2019  17500       Manual    10460   Petrol         1.5
# 21453  2019  16500    Automatic     1482   Petrol         1.0

# %%
mileage_5k = ((df_fiesta['mileage'] / 5000).round(0) * 5000).astype(int)
df_fiesta_grp = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_5k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
df_fiesta_grp.columns = [c[1] for c in df_fiesta_grp.columns]

'mean group size: ', df_fiesta_grp['len'].mean()
'price mad in 5k groups: ', df_fiesta_grp['mad'].mean()
'price std in 5k groups: ', df_fiesta_grp['std'].mean()
# Out:
# ('mean group size: ', 10.446227929373997)
# ('price mad in 5k groups: ', 323.66491789552254)
# ('price std in 5k groups: ', 701.2696209252479)

# %%
mileage_10k = ((df_fiesta['mileage'] / 10000).round(0) * 10000).astype(int)
df_fiesta_grp = df_fiesta.drop(columns='mileage').groupby(['year', 'transmission', mileage_10k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad])
df_fiesta_grp.columns = [c[1] for c in df_fiesta_grp.columns]

'mean group size: ', df_fiesta_grp['len'].mean()
'price mad in 10k groups: ', df_fiesta_grp['mad'].mean()
'price std in 10k groups: ', df_fiesta_grp['std'].mean()
# Out:
# ('mean group size: ', 15.349056603773585)
# ('price mad in 10k groups: ', 343.64691608968064)
# ('price std in 10k groups: ', 729.4423273421423)

# %% [markdown]
# # Encode

# %%
m.ordinalEncode(df_fiesta, ['transmission', 'fuelType'])
df_fiesta
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0
# 21454  2015  10500             1    35432         1         1.6
# 21456  2017   9000             1    13054         1         1.2
# ...     ...    ...           ...      ...       ...         ...
# 39394  2019  15999             1     2813         1         1.0
# 39395  2015   8999             1    24546         1         1.0
# 39401  2017   9899             0    16303         1         1.0
# 39404  2018  12500             0     7047         1         1.0
# 39409  2016   7999             1    31348         1         1.2
#
# [6508 rows x 6 columns]

# %% [markdown]
# # X y

# %%
df_train = df_fiesta
df_train.head(3)
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0

# %%
X, y  = df_train.drop(columns='price'), df_train['price']

y.shape
X.shape
X.columns
X.head(2)
# Out:
# (6508,)
# (6508, 5)
# Index(['year', 'transmission', 'mileage', 'fuelType', 'engineSize'], dtype='object')
#        year  transmission  mileage  fuelType  engineSize
# 21449  2017             0    15944         1         1.0
# 21452  2019             1    10460         1         1.5

# %% [markdown]
# # Train model

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %% [markdown]
# ## Linear Models

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import minmax_scale, normalize, scale, PolynomialFeatures

# %%
def booger_aids(X, y):
    models_and_params = [
        (LinearRegression, {}),
        # (Lasso, {'random_state': RS}),
        # (Ridge, {'random_state': RS}),
    ]
    cv = KFold(5)
    metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

    r = t.grid_exec(
        lambda model: m.cv_regression(model, cv, X, y, metrics), 
        models_and_params,
    )
    return r

# %% [markdown]
# ### Raw

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Standard Scaled

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Normalized

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = normalize(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Min Max

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = minmax_scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Poly

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = normalize(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(1, 20):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = minmax_scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %% [markdown]
# ## Trees

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %%
n_est_list = [100, 200, 400]
models_and_params = [
    (DecisionTreeRegressor, {}),
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_9a678_row0_col3, #T_9a678_row0_col6, #T_9a678_row0_col10 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_9a678_row0_col4, #T_9a678_row0_col7, #T_9a678_row4_col3, #T_9a678_row4_col6, #T_9a678_row4_col10, #T_9a678_row5_col3, #T_9a678_row5_col6, #T_9a678_row5_col10, #T_9a678_row6_col3, #T_9a678_row6_col6, #T_9a678_row6_col10, #T_9a678_row14_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9a678_row0_col5, #T_9a678_row0_col8, #T_9a678_row0_col11 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_9a678_row0_col9, #T_9a678_row7_col4, #T_9a678_row7_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_9a678_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_9a678_row1_col3, #T_9a678_row1_col6, #T_9a678_row2_col10 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_9a678_row1_col4, #T_9a678_row1_col7, #T_9a678_row15_col9 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_9a678_row1_col5, #T_9a678_row1_col8, #T_9a678_row1_col11 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_9a678_row1_col9, #T_9a678_row13_col4, #T_9a678_row13_col7 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_9a678_row1_col10, #T_9a678_row12_col3, #T_9a678_row12_col6 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_9a678_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_9a678_row2_col3, #T_9a678_row2_col6, #T_9a678_row3_col10 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_9a678_row2_col4, #T_9a678_row2_col7, #T_9a678_row13_col9 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_9a678_row2_col5, #T_9a678_row2_col8, #T_9a678_row2_col11 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_9a678_row2_col9, #T_9a678_row14_col4, #T_9a678_row14_col7 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_9a678_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.8%, transparent 48.8%);
# }
# #T_9a678_row3_col3, #T_9a678_row3_col6, #T_9a678_row12_col10 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9a678_row3_col4, #T_9a678_row3_col7, #T_9a678_row7_col9 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_9a678_row3_col5, #T_9a678_row3_col8, #T_9a678_row3_col11 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_9a678_row3_col9, #T_9a678_row10_col7, #T_9a678_row15_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_9a678_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_9a678_row4_col4, #T_9a678_row4_col7, #T_9a678_row4_col9, #T_9a678_row5_col4, #T_9a678_row5_col7, #T_9a678_row5_col9, #T_9a678_row6_col4, #T_9a678_row6_col7, #T_9a678_row6_col9 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_9a678_row4_col5, #T_9a678_row4_col8, #T_9a678_row4_col11, #T_9a678_row5_col5, #T_9a678_row5_col8, #T_9a678_row5_col11, #T_9a678_row6_col5, #T_9a678_row6_col8, #T_9a678_row6_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_9a678_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.0%, transparent 8.0%);
# }
# #T_9a678_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.1%, transparent 8.1%);
# }
# #T_9a678_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.2%, transparent 8.2%);
# }
# #T_9a678_row7_col3, #T_9a678_row7_col6, #T_9a678_row13_col10 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_9a678_row7_col5, #T_9a678_row7_col8, #T_9a678_row7_col11 {
#   background-color: #fdb475;
#   color: #000000;
# }
# #T_9a678_row7_col10, #T_9a678_row14_col3, #T_9a678_row14_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_9a678_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_9a678_row8_col3, #T_9a678_row8_col6, #T_9a678_row10_col10 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_9a678_row8_col4, #T_9a678_row11_col9, #T_9a678_row15_col7 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_9a678_row8_col5, #T_9a678_row8_col8, #T_9a678_row8_col11 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_9a678_row8_col7, #T_9a678_row10_col4, #T_9a678_row12_col9 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_9a678_row8_col9, #T_9a678_row9_col4, #T_9a678_row11_col7 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_9a678_row8_col10, #T_9a678_row15_col3, #T_9a678_row15_col6 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_9a678_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.1%, transparent 6.1%);
# }
# #T_9a678_row9_col3, #T_9a678_row9_col6, #T_9a678_row14_col10 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_9a678_row9_col5, #T_9a678_row9_col8, #T_9a678_row9_col11 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_9a678_row9_col7, #T_9a678_row10_col9, #T_9a678_row11_col4 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_9a678_row9_col9, #T_9a678_row12_col4, #T_9a678_row12_col7 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_9a678_row9_col10, #T_9a678_row13_col3, #T_9a678_row13_col6 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_9a678_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.0%, transparent 12.0%);
# }
# #T_9a678_row10_col3, #T_9a678_row10_col6, #T_9a678_row15_col10 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_9a678_row10_col5, #T_9a678_row10_col8, #T_9a678_row10_col11 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_9a678_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.5%, transparent 16.5%);
# }
# #T_9a678_row11_col3, #T_9a678_row11_col6, #T_9a678_row11_col10 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_9a678_row11_col5, #T_9a678_row11_col8, #T_9a678_row11_col11 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_9a678_row11_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.6%, transparent 34.6%);
# }
# #T_9a678_row12_col5, #T_9a678_row12_col8, #T_9a678_row12_col11 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_9a678_row12_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.9%, transparent 71.9%);
# }
# #T_9a678_row13_col5, #T_9a678_row13_col8, #T_9a678_row13_col11 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_9a678_row13_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.7%, transparent 5.7%);
# }
# #T_9a678_row14_col5, #T_9a678_row14_col8, #T_9a678_row14_col11 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_9a678_row14_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.7%, transparent 11.7%);
# }
# #T_9a678_row15_col5, #T_9a678_row15_col8, #T_9a678_row15_col11 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_9a678_row15_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.8%, transparent 22.8%);
# }
# </style>
# <table id="T_9a678">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a678_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_9a678_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_9a678_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_9a678_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_9a678_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_9a678_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_9a678_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_9a678_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_9a678_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_9a678_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_9a678_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_9a678_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_9a678_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_

# %%
n_est_list = [100, 200, 400]
models_and_params = [
    (DecisionTreeRegressor, {}),
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(8)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_17604_row0_col3, #T_17604_row0_col6 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_17604_row0_col4, #T_17604_row0_col7, #T_17604_row0_col10, #T_17604_row4_col3, #T_17604_row4_col6, #T_17604_row5_col3, #T_17604_row5_col6, #T_17604_row6_col3, #T_17604_row6_col6, #T_17604_row14_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_17604_row0_col5, #T_17604_row0_col8, #T_17604_row0_col11 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_17604_row0_col9, #T_17604_row14_col10, #T_17604_row15_col4, #T_17604_row15_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_17604_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_17604_row1_col3, #T_17604_row1_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_17604_row1_col4, #T_17604_row1_col7, #T_17604_row13_col9 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_17604_row1_col5, #T_17604_row1_col8, #T_17604_row1_col11 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_17604_row1_col9, #T_17604_row8_col4, #T_17604_row9_col10 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_17604_row1_col10, #T_17604_row8_col9, #T_17604_row12_col7 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_17604_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.7%, transparent 24.7%);
# }
# #T_17604_row2_col3, #T_17604_row2_col6 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_17604_row2_col4, #T_17604_row2_col7, #T_17604_row4_col10, #T_17604_row5_col10, #T_17604_row6_col10, #T_17604_row15_col9 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_17604_row2_col5, #T_17604_row2_col8, #T_17604_row2_col11 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_17604_row2_col9, #T_17604_row4_col7, #T_17604_row5_col7, #T_17604_row6_col7, #T_17604_row10_col4, #T_17604_row15_col10 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_17604_row2_col10, #T_17604_row10_col7, #T_17604_row10_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_17604_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.9%, transparent 48.9%);
# }
# #T_17604_row3_col3, #T_17604_row3_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_17604_row3_col4, #T_17604_row3_col7, #T_17604_row7_col9 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_17604_row3_col5, #T_17604_row3_col8, #T_17604_row3_col11 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_17604_row3_col9, #T_17604_row9_col4, #T_17604_row10_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_17604_row3_col10, #T_17604_row4_col4, #T_17604_row5_col4, #T_17604_row6_col4, #T_17604_row9_col9, #T_17604_row11_col7 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_17604_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_17604_row4_col5, #T_17604_row4_col8, #T_17604_row4_col11, #T_17604_row5_col5, #T_17604_row5_col8, #T_17604_row5_col11, #T_17604_row6_col5, #T_17604_row6_col8, #T_17604_row6_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_17604_row4_col9, #T_17604_row5_col9, #T_17604_row6_col9, #T_17604_row7_col7, #T_17604_row8_col10, #T_17604_row13_col4 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_17604_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.2%, transparent 8.2%);
# }
# #T_17604_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_17604_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.5%, transparent 8.5%);
# }
# #T_17604_row7_col3, #T_17604_row7_col6 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_17604_row7_col4, #T_17604_row13_col10, #T_17604_row14_col7 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_17604_row7_col5, #T_17604_row7_col8, #T_17604_row7_col11 {
#   background-color: #fdb475;
#   color: #000000;
# }
# #T_17604_row7_col10, #T_17604_row13_col7, #T_17604_row14_col4 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_17604_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.6%, transparent 3.6%);
# }
# #T_17604_row8_col3, #T_17604_row8_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_17604_row8_col5, #T_17604_row8_col8, #T_17604_row8_col11 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_17604_row8_col7, #T_17604_row11_col4, #T_17604_row11_col10, #T_17604_row12_col9 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_17604_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.2%, transparent 6.2%);
# }
# #T_17604_row9_col3, #T_17604_row9_col6 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_17604_row9_col5, #T_17604_row9_col8, #T_17604_row9_col11 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_17604_row9_col7, #T_17604_row11_col9, #T_17604_row12_col4, #T_17604_row12_col10 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_17604_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.7%, transparent 10.7%);
# }
# #T_17604_row10_col3, #T_17604_row10_col6 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_17604_row10_col5, #T_17604_row10_col8, #T_17604_row10_col11 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_17604_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.0%, transparent 17.0%);
# }
# #T_17604_row11_col3, #T_17604_row11_col6 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_17604_row11_col5, #T_17604_row11_col8, #T_17604_row11_col11 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_17604_row11_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.7%, transparent 32.7%);
# }
# #T_17604_row12_col3, #T_17604_row12_col6 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_17604_row12_col5, #T_17604_row12_col8, #T_17604_row12_col11 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_17604_row12_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.8%, transparent 65.8%);
# }
# #T_17604_row13_col3, #T_17604_row13_col6 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_17604_row13_col5, #T_17604_row13_col8, #T_17604_row13_col11 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_17604_row13_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_17604_row14_col3, #T_17604_row14_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_17604_row14_col5, #T_17604_row14_col8, #T_17604_row14_col11 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_17604_row14_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.5%, transparent 10.5%);
# }
# #T_17604_row15_col3, #T_17604_row15_col6 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_17604_row15_col5, #T_17604_row15_col8, #T_17604_row15_col11 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_17604_row15_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.0%, transparent 20.0%);
# }
# </style>
# <table id="T_17604">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17604_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_17604_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_17604_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_17604_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_17604_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_17604_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_17604_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_17604_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_17604_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_17604_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_17604_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_17604_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_17604_level0_col12"

# %%
('price mad in 5k groups: ', 323.66491789552254)
('price std in 5k groups: ', 701.2696209252479)

('price mad in 10k groups: ', 343.64691608968064)
('price std in 10k groups: ', 729.4423273421423)

# %%
n_est_list = [800, 1600]

models_and_params = [
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_53bcc_row0_col3, #T_53bcc_row0_col6, #T_53bcc_row0_col10 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_53bcc_row0_col4, #T_53bcc_row0_col7, #T_53bcc_row3_col3, #T_53bcc_row3_col6, #T_53bcc_row3_col10, #T_53bcc_row4_col3, #T_53bcc_row4_col6, #T_53bcc_row4_col10, #T_53bcc_row9_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_53bcc_row0_col5, #T_53bcc_row0_col8, #T_53bcc_row0_col11 {
#   background-color: #993103;
#   color: #f1f1f1;
# }
# #T_53bcc_row0_col9, #T_53bcc_row10_col4, #T_53bcc_row10_col7 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_53bcc_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_53bcc_row1_col3, #T_53bcc_row1_col6, #T_53bcc_row1_col10 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_53bcc_row1_col4, #T_53bcc_row1_col7, #T_53bcc_row5_col9 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_53bcc_row1_col5, #T_53bcc_row1_col8, #T_53bcc_row1_col11 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_53bcc_row1_col9, #T_53bcc_row7_col7, #T_53bcc_row8_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_53bcc_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.4%, transparent 49.4%);
# }
# #T_53bcc_row2_col3, #T_53bcc_row2_col6, #T_53bcc_row2_col10 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_53bcc_row2_col4, #T_53bcc_row2_col7, #T_53bcc_row10_col9 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_53bcc_row2_col5, #T_53bcc_row2_col8, #T_53bcc_row2_col11 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_53bcc_row2_col9, #T_53bcc_row5_col4, #T_53bcc_row5_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_53bcc_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_53bcc_row3_col4, #T_53bcc_row3_col7, #T_53bcc_row3_col9, #T_53bcc_row4_col4, #T_53bcc_row4_col7, #T_53bcc_row4_col9 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_53bcc_row3_col5, #T_53bcc_row3_col8, #T_53bcc_row3_col11, #T_53bcc_row4_col5, #T_53bcc_row4_col8, #T_53bcc_row4_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_53bcc_row3_col12, #T_53bcc_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_53bcc_row5_col3, #T_53bcc_row5_col6, #T_53bcc_row10_col10 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_53bcc_row5_col5, #T_53bcc_row5_col8, #T_53bcc_row5_col11 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_53bcc_row5_col10, #T_53bcc_row9_col3, #T_53bcc_row9_col6 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_53bcc_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.5%, transparent 6.5%);
# }
# #T_53bcc_row6_col3, #T_53bcc_row6_col6, #T_53bcc_row9_col10 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_53bcc_row6_col4, #T_53bcc_row6_col7, #T_53bcc_row6_col9 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_53bcc_row6_col5, #T_53bcc_row6_col8, #T_53bcc_row6_col11 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_53bcc_row6_col10, #T_53bcc_row10_col3, #T_53bcc_row10_col6 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_53bcc_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.3%, transparent 11.3%);
# }
# #T_53bcc_row7_col3, #T_53bcc_row7_col6, #T_53bcc_row7_col10 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_53bcc_row7_col4, #T_53bcc_row7_col9, #T_53bcc_row9_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_53bcc_row7_col5, #T_53bcc_row7_col8, #T_53bcc_row7_col11 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_53bcc_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.3%, transparent 32.3%);
# }
# #T_53bcc_row8_col3, #T_53bcc_row8_col6, #T_53bcc_row8_col10 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_53bcc_row8_col5, #T_53bcc_row8_col8, #T_53bcc_row8_col11 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_53bcc_row8_col7, #T_53bcc_row8_col9, #T_53bcc_row9_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_53bcc_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.9%, transparent 67.9%);
# }
# #T_53bcc_row9_col5, #T_53bcc_row9_col8, #T_53bcc_row9_col11 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_53bcc_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.8%, transparent 10.8%);
# }
# #T_53bcc_row10_col5, #T_53bcc_row10_col8, #T_53bcc_row10_col11 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_53bcc_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.5%, transparent 21.5%);
# }
# </style>
# <table id="T_53bcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53bcc_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_53bcc_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_53bcc_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_53bcc_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_53bcc_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_53bcc_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_53bcc_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_53bcc_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_53bcc_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_53bcc_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_53bcc_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_53bcc_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_53bcc_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53bcc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53bcc_row0_col0" class="data row0 col0" >DecisionTreeRegressor</td>
#       <td id="T_53bcc_row0_col1" class="data row0 col1" ></td>
#       <td id="T_53bcc_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_53bcc_row0_col3" class="data row0 col3" >1016</td>
#       <td id="T_53bcc_row0_col4" class="data row0 col4" >75</td>
#       <td id="T_53bcc_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_53bcc_row0_col6" class="data row0 col6" >1362</td>
#       <td id="T_53bcc_row0_col7" class="data row0 col7" >102</td>
#       <td id="T_53bcc_row0_col8" class="data row0 col8" >9</td>
#       <td id="T_53bcc_row0_col9" class="data row0 col9" >0.758</td>
#       <td id="T_53bcc_row0_col10" class="data row0 col10" >0.032</td>
#       <td id="T_53bcc_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_53bcc_row0_col12" class="data row0 col12" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_53bcc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53bcc_row1_col0" class="data row1 col0" >RandomForestRegressor</td>
#       <td id="T_53bcc_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_53bcc_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_53bcc_row1_col3" class="data row1 col3" >873</td>
#       <td id="T_53bcc_row1_col4" class="data row1 col4" >63</td>
#       <td id="T_53bcc_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_53bcc_row1_col6" class="data row1 col6" >1167</td>
#       <td id="T_53bcc_row1_col7" class="data row1 col7" >87</td>
#       <td id="T_53bcc_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_53bcc_row1_col9" class="data row1 col9" >0.823</td>
#       <td id="T_53bcc_row1_col10" class="data row1 col10" >0.019</td>
#       <td id="T_53bcc_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_53bcc_row1_col12" class="data row1 col12" >23.9</td>
#     </tr>
#     <tr>
#       <th id="T_53bcc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53bcc_row2_col0" class="data row2 col0" >RandomForestRegressor</td>
#       <td id="T_53bcc_row2_col1" class="data row2 col1" >'n_estimators': 1600</td>
#       <td id=

# %%
n_est_list = [800, 1600]

models_and_params = [
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(8)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_f5ada_row0_col3, #T_f5ada_row0_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col4, #T_f5ada_row2_col3, #T_f5ada_row2_col6, #T_f5ada_row3_col3, #T_f5ada_row3_col6, #T_f5ada_row6_col7, #T_f5ada_row7_col10, #T_f5ada_row8_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col5, #T_f5ada_row0_col8, #T_f5ada_row0_col11 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col7, #T_f5ada_row9_col9 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col9, #T_f5ada_row1_col10, #T_f5ada_row4_col7, #T_f5ada_row6_col4 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col10, #T_f5ada_row1_col9, #T_f5ada_row5_col7, #T_f5ada_row7_col4 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_f5ada_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.1%, transparent 51.1%);
# }
# #T_f5ada_row1_col3, #T_f5ada_row1_col6 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_f5ada_row1_col4, #T_f5ada_row5_col9, #T_f5ada_row6_col10, #T_f5ada_row7_col7 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_f5ada_row1_col5, #T_f5ada_row1_col8, #T_f5ada_row1_col11 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_f5ada_row1_col7, #T_f5ada_row4_col9 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_f5ada_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f5ada_row2_col4, #T_f5ada_row2_col10, #T_f5ada_row3_col4, #T_f5ada_row3_col10 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_f5ada_row2_col5, #T_f5ada_row2_col8, #T_f5ada_row2_col11, #T_f5ada_row3_col5, #T_f5ada_row3_col8, #T_f5ada_row3_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f5ada_row2_col7, #T_f5ada_row3_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_f5ada_row2_col9, #T_f5ada_row3_col9 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_f5ada_row2_col12, #T_f5ada_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_f5ada_row4_col3, #T_f5ada_row4_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_f5ada_row4_col4, #T_f5ada_row4_col10, #T_f5ada_row7_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_f5ada_row4_col5, #T_f5ada_row4_col8, #T_f5ada_row4_col11 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_f5ada_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.1%, transparent 5.1%);
# }
# #T_f5ada_row5_col3, #T_f5ada_row5_col6 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_f5ada_row5_col4, #T_f5ada_row5_col10, #T_f5ada_row6_col9, #T_f5ada_row9_col7 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_f5ada_row5_col5, #T_f5ada_row5_col8, #T_f5ada_row5_col11 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_f5ada_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.8%, transparent 10.8%);
# }
# #T_f5ada_row6_col3, #T_f5ada_row6_col6 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_f5ada_row6_col5, #T_f5ada_row6_col8, #T_f5ada_row6_col11 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_f5ada_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.2%, transparent 37.2%);
# }
# #T_f5ada_row7_col3, #T_f5ada_row7_col6 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_f5ada_row7_col5, #T_f5ada_row7_col8, #T_f5ada_row7_col11 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_f5ada_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.4%, transparent 68.4%);
# }
# #T_f5ada_row8_col3, #T_f5ada_row8_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_f5ada_row8_col4, #T_f5ada_row8_col7, #T_f5ada_row8_col10 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_f5ada_row8_col5, #T_f5ada_row8_col8, #T_f5ada_row8_col11 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_f5ada_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.5%, transparent 10.5%);
# }
# #T_f5ada_row9_col3, #T_f5ada_row9_col6 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_f5ada_row9_col4, #T_f5ada_row9_col10 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_f5ada_row9_col5, #T_f5ada_row9_col8, #T_f5ada_row9_col11 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_f5ada_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.6%, transparent 20.6%);
# }
# </style>
# <table id="T_f5ada">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5ada_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f5ada_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_f5ada_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_f5ada_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_f5ada_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_f5ada_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_f5ada_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_f5ada_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_f5ada_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_f5ada_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_f5ada_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_f5ada_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_f5ada_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5ada_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5ada_row0_col0" class="data row0 col0" >RandomForestRegressor</td>
#       <td id="T_f5ada_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_f5ada_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_f5ada_row0_col3" class="data row0 col3" >874</td>
#       <td id="T_f5ada_row0_col4" class="data row0 col4" >67</td>
#       <td id="T_f5ada_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_f5ada_row0_col6" class="data row0 col6" >1170</td>
#       <td id="T_f5ada_row0_col7" class="data row0 col7" >81</td>
#       <td id="T_f5ada_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_f5ada_row0_col9" class="data row0 col9" >0.817</td>
#       <td id="T_f5ada_row0_col10" class="data row0 col10" >0.030</td>
#       <td id="T_f5ada_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_f5ada_row0_col12" class="data row0 col12" >42.2</td>
#     </tr>
#     <tr>
#       <th id="T_f5ada_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5ada_row1_col0" class="data row1 col0" >RandomForestRegressor</td>
#       <td id="T_f5ada_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_f5ada_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_f5ada_row1_col3" class="data row1 col3" >873</td>
#       <td id="T_f5ada_row1_col4" class="data row1 col4" >66</td>
#       <td id="T_f5ada_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_f5ada_row1_col6" class="data row1 col6" >1169</td>
#       <td id="T_f5ada_row1_col7" class="data row1 col7" >81</td>
#       <td id="T_f5ada_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_f5ada_row1_col9" class="data row1 col9" >0.817</td>
#       <td id="T_f5ada_row1_col10" class="data row1 col10" >0.030</td>
#       <td id="T_f5ada_row1_col11" class="data row1 col11" >5</td>
#       <td id="T_f5ada_row1_col12" class="data row1 col12" >82.7</td>
#     </tr>
#     <tr>
#       <th id="T_f5ada_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5ada_row2_col0" class="data row2 col0" >AdaBoostRegressor</td>
#       <td id="T_f5ada_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_f5ada_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_f5ada_row2_col3" class="data row2 col3" >1159</td>
#       <td id="T_f5ada_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_f5ada_row2_col5" class="data row2 col5

# %%
700/1000
# Out:
# 0.7

# %%
1000/700
# Out:
# 1.4285714285714286
