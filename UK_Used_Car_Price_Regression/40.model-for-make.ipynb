# %% [markdown]
# # Setup and Imports

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
import time

# %%
df_data = t.from_pkl(f'{processed_data_path}/df_clean.pkl')

df_data.shape
df_data.head(3)
# Out:
# (97323, 8)
#    make model  year  price transmission  mileage fuelType  engineSize
# 0  Audi    A1  2017  12500       Manual    15735   Petrol         1.4
# 1  Audi    A6  2016  16500    Automatic    36203   Diesel         2.0
# 2  Audi    A1  2016  11000       Manual    29946   Petrol         1.4

# %%
df_data.groupby(['make'])['model'].nunique()
# Out:
# make
# Audi        21
# Bmw         22
# Ford        19
# Hyundi      11
# Merc        20
# Skoda       12
# Toyota      15
# Vauxhall    17
# Vw          22
# Name: model, dtype: int64

# %%
df_data.loc[df_data['make'] == 'Hyundi']['model'].value_counts()
# Out:
# Tucson      1279
# I10         1061
# I30          535
# I20          487
# Kona         322
# Ioniq        273
# Santa Fe     244
# IX20         202
# I40          120
# IX35         118
# I800         117
# Name: model, dtype: int64

# %%
df_hyundi = df_data.loc[df_data['make'] == 'Hyundi'].drop(columns=['make']).copy()
df_hyundi
# Out:
#         model  year  price transmission  mileage fuelType  engineSize
# 39414     I20  2017   7999       Manual    17307   Petrol         1.2
# 39415  Tucson  2016  14499    Automatic    25233   Diesel         2.0
# 39416  Tucson  2016  11399       Manual    37877   Diesel         1.7
# 39417     I10  2016   6499       Manual    23789   Petrol         1.0
# 39418    IX35  2015  10199       Manual    33177   Diesel         2.0
# ...       ...   ...    ...          ...      ...      ...         ...
# 44269     I30  2016   8680       Manual    25906   Diesel         1.6
# 44270     I40  2015   7830       Manual    59508   Diesel         1.7
# 44271     I10  2017   6830       Manual    13810   Petrol         1.0
# 44272  Tucson  2018  13994       Manual    23313   Petrol         1.6
# 44273  Tucson  2016  15999    Automatic    11472   Diesel         1.7
#
# [4758 rows x 7 columns]

# %%
df_to_group = df_hyundi

# %%
mileage_5k = ((df_to_group['mileage'] / 5000).round(0) * 5000).astype(int)
df_grp = df_to_group.drop(columns='mileage').groupby(['model', 'year', 'transmission', mileage_5k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad]).copy()
df_grp.columns = [c[1] for c in df_grp.columns]

'mean group size: ', df_grp['len'].mean()
'price mad in 5k groups: ', df_grp['mad'].mean()
'price std in 5k groups: ', df_grp['std'].mean()
# Out:
# ('mean group size: ', 3.7702060221870046)
# ('price mad in 5k groups: ', 315.97138099375206)
# ('price std in 5k groups: ', 849.4404889166979)

# %%
mileage_10k = ((df_to_group['mileage'] / 10000).round(0) * 10000).astype(int)
df_grp = df_to_group.drop(columns='mileage').groupby(['model', 'year', 'transmission', mileage_10k, 'fuelType', 'engineSize']).agg([len, np.mean, np.std, m.mad]).copy()
df_grp.columns = [c[1] for c in df_grp.columns]

'mean group size: ', df_grp['len'].mean()
'price mad in 10k groups: ', df_grp['mad'].mean()
'price std in 10k groups: ', df_grp['std'].mean()
# Out:
# ('mean group size: ', 5.228571428571429)
# ('price mad in 10k groups: ', 378.451221207289)
# ('price std in 10k groups: ', 894.6484135765044)

# %% [markdown]
# # Encode

# %%
df_hyundi = df_hyundi.drop(columns='model')
df_hyundi
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 39414  2017   7999             1    17307         2         1.2
# 39415  2016  14499             0    25233         0         2.0
# 39416  2016  11399             1    37877         0         1.7
# 39417  2016   6499             1    23789         2         1.0
# 39418  2015  10199             1    33177         0         2.0
# ...     ...    ...           ...      ...       ...         ...
# 44269  2016   8680             1    25906         0         1.6
# 44270  2015   7830             1    59508         0         1.7
# 44271  2017   6830             1    13810         2         1.0
# 44272  2018  13994             1    23313         2         1.6
# 44273  2016  15999             0    11472         0         1.7
#
# [4758 rows x 6 columns]

# %%
m.ordinalEncode(df_hyundi, ['transmission', 'fuelType'])
df_hyundi
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 39414  2017   7999             1    17307         2         1.2
# 39415  2016  14499             0    25233         0         2.0
# 39416  2016  11399             1    37877         0         1.7
# 39417  2016   6499             1    23789         2         1.0
# 39418  2015  10199             1    33177         0         2.0
# ...     ...    ...           ...      ...       ...         ...
# 44269  2016   8680             1    25906         0         1.6
# 44270  2015   7830             1    59508         0         1.7
# 44271  2017   6830             1    13810         2         1.0
# 44272  2018  13994             1    23313         2         1.6
# 44273  2016  15999             0    11472         0         1.7
#
# [4758 rows x 6 columns]

# %% [markdown]
# # X y

# %%
df_train = df_hyundi
df_train.head(3)
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 39414  2017   7999             1    17307         2         1.2
# 39415  2016  14499             0    25233         0         2.0
# 39416  2016  11399             1    37877         0         1.7

# %%
X, y  = df_train.drop(columns='price'), df_train['price']

y.shape
X.shape
X.columns
X.head(2)
# Out:
# (4758,)
# (4758, 5)
# Index(['year', 'transmission', 'mileage', 'fuelType', 'engineSize'], dtype='object')
#        year  transmission  mileage  fuelType  engineSize
# 39414  2017             1    17307         2         1.2
# 39415  2016             0    25233         0         2.0

# %% [markdown]
# # Train model

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import minmax_scale, normalize, scale, PolynomialFeatures

# %%
def booger_aids(X, y):
    models_and_params = [
        (LinearRegression, {}),
        # (Lasso, {'random_state': RS}),
        # (Ridge, {'random_state': RS}),
    ]
    cv = KFold(5)
    metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

    r = t.grid_exec(
        lambda model: m.cv_regression(model, cv, X, y, metrics), 
        models_and_params,
    )
    return r

# %% [markdown]
# ### Raw

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Standard Scaled

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Normalized

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = normalize(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Min Max

# %%
X, y  = df_train.drop(columns='price'), df_train['price']
X[X.columns] = minmax_scale(X)
r = booger_aids(X, y)
m.display_stats(r, False)

# %% [markdown]
# ### Poly

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(7):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = normalize(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %%
all_r = []
for i in range(1, 20):
    X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()
    X[X.columns] = minmax_scale(X)
    X_poly = m.polynomialFeatures(X, i)
    r = booger_aids(X_poly, y)
    all_r.extend(r)

m.display_stats(all_r, False)

# %% [markdown]
# ## Trees

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %%
n_est_list = [100, 200, 400]
models_and_params = [
    (DecisionTreeRegressor, {}),
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_c4f60_row0_col3, #T_c4f60_row0_col6, #T_c4f60_row7_col7, #T_c4f60_row11_col4 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_c4f60_row0_col4, #T_c4f60_row10_col3, #T_c4f60_row10_col6, #T_c4f60_row14_col7 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_c4f60_row0_col5, #T_c4f60_row0_col8, #T_c4f60_row0_col11 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_c4f60_row0_col7, #T_c4f60_row8_col6, #T_c4f60_row9_col4, #T_c4f60_row14_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_c4f60_row0_col9, #T_c4f60_row10_col10 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_c4f60_row0_col10, #T_c4f60_row4_col3, #T_c4f60_row4_col4, #T_c4f60_row4_col6, #T_c4f60_row4_col7, #T_c4f60_row5_col3, #T_c4f60_row5_col4, #T_c4f60_row5_col6, #T_c4f60_row5_col7, #T_c4f60_row6_col3, #T_c4f60_row6_col4, #T_c4f60_row6_col6, #T_c4f60_row6_col7, #T_c4f60_row7_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c4f60_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.7%, transparent 0.7%);
# }
# #T_c4f60_row1_col3, #T_c4f60_row2_col6, #T_c4f60_row8_col7, #T_c4f60_row10_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col4, #T_c4f60_row2_col7, #T_c4f60_row11_col3, #T_c4f60_row11_col6 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col5, #T_c4f60_row2_col8, #T_c4f60_row2_col11 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col6, #T_c4f60_row2_col3, #T_c4f60_row2_col4, #T_c4f60_row9_col7 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col7, #T_c4f60_row9_col3, #T_c4f60_row14_col6, #T_c4f60_row15_col4 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c4f60_row1_col8, #T_c4f60_row1_col11, #T_c4f60_row2_col5 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col9, #T_c4f60_row15_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_c4f60_row1_col10, #T_c4f60_row12_col9 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c4f60_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.1%, transparent 25.1%);
# }
# #T_c4f60_row2_col9, #T_c4f60_row3_col10 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_c4f60_row2_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_c4f60_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.4%, transparent 48.4%);
# }
# #T_c4f60_row3_col3, #T_c4f60_row3_col4, #T_c4f60_row3_col6, #T_c4f60_row13_col7 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_c4f60_row3_col5, #T_c4f60_row3_col8, #T_c4f60_row3_col11 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_c4f60_row3_col7, #T_c4f60_row8_col3, #T_c4f60_row13_col4, #T_c4f60_row15_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_c4f60_row3_col9, #T_c4f60_row13_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c4f60_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_c4f60_row4_col5, #T_c4f60_row4_col8, #T_c4f60_row4_col11, #T_c4f60_row5_col5, #T_c4f60_row5_col8, #T_c4f60_row5_col11, #T_c4f60_row6_col5, #T_c4f60_row6_col8, #T_c4f60_row6_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_c4f60_row4_col9, #T_c4f60_row5_col9, #T_c4f60_row6_col9, #T_c4f60_row12_col10 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_c4f60_row4_col10, #T_c4f60_row5_col10, #T_c4f60_row6_col10, #T_c4f60_row13_col9 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_c4f60_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.9%, transparent 9.9%);
# }
# #T_c4f60_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.6%, transparent 9.6%);
# }
# #T_c4f60_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_c4f60_row7_col3, #T_c4f60_row7_col4, #T_c4f60_row9_col6, #T_c4f60_row10_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c4f60_row7_col5, #T_c4f60_row9_col8, #T_c4f60_row9_col11 {
#   background-color: #fdb475;
#   color: #000000;
# }
# #T_c4f60_row7_col6, #T_c4f60_row12_col7, #T_c4f60_row14_col4, #T_c4f60_row15_col3 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_c4f60_row7_col8, #T_c4f60_row7_col11, #T_c4f60_row15_col5 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_c4f60_row7_col10, #T_c4f60_row14_col9 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_c4f60_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.3%, transparent 4.3%);
# }
# #T_c4f60_row8_col4, #T_c4f60_row11_col7, #T_c4f60_row13_col3, #T_c4f60_row13_col6 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_c4f60_row8_col5, #T_c4f60_row15_col8, #T_c4f60_row15_col11 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_c4f60_row8_col8, #T_c4f60_row8_col11, #T_c4f60_row14_col5 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_c4f60_row8_col9 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_c4f60_row8_col10, #T_c4f60_row10_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_c4f60_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.0%, transparent 7.0%);
# }
# #T_c4f60_row9_col5, #T_c4f60_row14_col8, #T_c4f60_row14_col11 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_c4f60_row9_col9 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_c4f60_row9_col10, #T_c4f60_row11_col9 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_c4f60_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.4%, transparent 14.4%);
# }
# #T_c4f60_row10_col5, #T_c4f60_row10_col8, #T_c4f60_row10_col11 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_c4f60_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.0%, transparent 21.0%);
# }
# #T_c4f60_row11_col5, #T_c4f60_row11_col8, #T_c4f60_row11_col11 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_c4f60_row11_col10 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_c4f60_row11_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.2%, transparent 35.2%);
# }
# #T_c4f60_row12_col3, #T_c4f60_row12_col4, #T_c4f60_row12_col6, #T_c4f60_row15_col7 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_c4f60_row12_col5, #T_c4f60_row12_col8, #T_c4f60_row12_col11 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_c4f60_row12_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 73.5%, transparent 73.5%);
# }
# #T_c4f60_row13_col5, #T_c4f60_row13_col8, #T_c4f60_row13_col11 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_c4f60_row13_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.0%, transparent 6.0%);
# }
# #T_c4f60_row14_col10, #T_c4f60_row15_col9 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_c4f60_row14_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.3%, transparent 11.3%);
# }
# #T_c4f60_row15_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.9%, transparent 22.9%);
# }
# </style>
# <table id="T_c4f60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4f60_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_c4f60_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_c4f60_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_c4f60_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_c4f60_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_c4f60_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_c4f60_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_c4f60_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_c4f60_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_c4f60_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_c4f60_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_c4f60_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_c4f60_level0_col12

# %%
n_est_list = [100, 200, 400]
models_and_params = [
    (DecisionTreeRegressor, {}),
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(8)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_971c7_row0_col3, #T_971c7_row0_col4, #T_971c7_row0_col6 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_971c7_row0_col5, #T_971c7_row0_col8, #T_971c7_row0_col11 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_971c7_row0_col7, #T_971c7_row0_col10, #T_971c7_row5_col3, #T_971c7_row5_col4, #T_971c7_row5_col6, #T_971c7_row6_col3, #T_971c7_row6_col4, #T_971c7_row6_col6, #T_971c7_row15_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_971c7_row0_col9, #T_971c7_row3_col10, #T_971c7_row4_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_971c7_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_971c7_row1_col3, #T_971c7_row2_col6, #T_971c7_row11_col4 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col4, #T_971c7_row3_col3, #T_971c7_row12_col6 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col5, #T_971c7_row2_col8, #T_971c7_row2_col11 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col6, #T_971c7_row2_col3, #T_971c7_row12_col4 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col7, #T_971c7_row3_col9, #T_971c7_row15_col10 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_971c7_row1_col8, #T_971c7_row1_col11, #T_971c7_row2_col5 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col9, #T_971c7_row2_col7, #T_971c7_row14_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_971c7_row1_col10 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_971c7_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.4%, transparent 25.4%);
# }
# #T_971c7_row2_col4, #T_971c7_row9_col3, #T_971c7_row13_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_971c7_row2_col9, #T_971c7_row8_col10, #T_971c7_row9_col7 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_971c7_row2_col10, #T_971c7_row13_col7 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_971c7_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.6%, transparent 50.6%);
# }
# #T_971c7_row3_col4, #T_971c7_row11_col3, #T_971c7_row11_col6 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_971c7_row3_col5, #T_971c7_row12_col8, #T_971c7_row12_col11 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_971c7_row3_col6, #T_971c7_row10_col4, #T_971c7_row12_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_971c7_row3_col7, #T_971c7_row11_col9, #T_971c7_row12_col10 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_971c7_row3_col8, #T_971c7_row3_col11, #T_971c7_row12_col5 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_971c7_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_971c7_row4_col3, #T_971c7_row4_col4, #T_971c7_row4_col6 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_971c7_row4_col5, #T_971c7_row4_col8, #T_971c7_row4_col11 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_971c7_row4_col9, #T_971c7_row9_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_971c7_row4_col10, #T_971c7_row8_col9, #T_971c7_row12_col7 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_971c7_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.4%, transparent 11.4%);
# }
# #T_971c7_row5_col5, #T_971c7_row5_col8, #T_971c7_row5_col11, #T_971c7_row6_col5, #T_971c7_row6_col8, #T_971c7_row6_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_971c7_row5_col7, #T_971c7_row6_col7 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_971c7_row5_col9, #T_971c7_row6_col9 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_971c7_row5_col10, #T_971c7_row6_col10 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_971c7_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.3%, transparent 12.3%);
# }
# #T_971c7_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.2%, transparent 12.2%);
# }
# #T_971c7_row7_col3, #T_971c7_row7_col4, #T_971c7_row8_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_971c7_row7_col5, #T_971c7_row8_col8, #T_971c7_row8_col11 {
#   background-color: #fdb475;
#   color: #000000;
# }
# #T_971c7_row7_col6, #T_971c7_row9_col4, #T_971c7_row14_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_971c7_row7_col7, #T_971c7_row10_col9, #T_971c7_row10_col10 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_971c7_row7_col8, #T_971c7_row14_col5, #T_971c7_row14_col11 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_971c7_row7_col9, #T_971c7_row11_col7 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_971c7_row7_col10, #T_971c7_row8_col7, #T_971c7_row12_col9 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_971c7_row7_col11, #T_971c7_row13_col5, #T_971c7_row14_col8 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_971c7_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.6%, transparent 5.6%);
# }
# #T_971c7_row8_col3, #T_971c7_row9_col6, #T_971c7_row14_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_971c7_row8_col4, #T_971c7_row13_col3, #T_971c7_row14_col6 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_971c7_row8_col5, #T_971c7_row9_col8, #T_971c7_row9_col11 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_971c7_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_971c7_row9_col5, #T_971c7_row13_col8, #T_971c7_row13_col11 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_971c7_row9_col9, #T_971c7_row13_col10, #T_971c7_row14_col7 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_971c7_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.5%, transparent 16.5%);
# }
# #T_971c7_row10_col3, #T_971c7_row10_col6, #T_971c7_row15_col4 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_971c7_row10_col5, #T_971c7_row10_col8, #T_971c7_row10_col11 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_971c7_row10_col7, #T_971c7_row14_col9 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_971c7_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.2%, transparent 22.2%);
# }
# #T_971c7_row11_col5, #T_971c7_row11_col8, #T_971c7_row11_col11 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_971c7_row11_col10, #T_971c7_row13_col9, #T_971c7_row15_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_971c7_row11_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.6%, transparent 42.6%);
# }
# #T_971c7_row12_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.4%, transparent 81.4%);
# }
# #T_971c7_row13_col4, #T_971c7_row15_col3, #T_971c7_row15_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_971c7_row13_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.0%, transparent 6.0%);
# }
# #T_971c7_row14_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.7%, transparent 11.7%);
# }
# #T_971c7_row15_col5, #T_971c7_row15_col8, #T_971c7_row15_col11 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_971c7_row15_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.1%, transparent 24.1%);
# }
# </style>
# <table id="T_971c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_971c7_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_971c7_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_971c7_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_971c7_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_971c7_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_971c7_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_971c7_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_971c7_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_971c7_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_971c7

# %%
('price mad in 5k groups: ', 323.66491789552254)
('price std in 5k groups: ', 701.2696209252479)

('price mad in 10k groups: ', 343.64691608968064)
('price std in 10k groups: ', 729.4423273421423)

# %%
n_est_list = [800, 1600]

models_and_params = [
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_909fd_row0_col3, #T_909fd_row0_col6, #T_909fd_row1_col4, #T_909fd_row5_col7, #T_909fd_row8_col10 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_909fd_row0_col4, #T_909fd_row1_col3, #T_909fd_row1_col6, #T_909fd_row4_col7, #T_909fd_row9_col10 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_909fd_row0_col5, #T_909fd_row0_col8, #T_909fd_row0_col11 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_909fd_row0_col7, #T_909fd_row5_col3, #T_909fd_row5_col6, #T_909fd_row7_col10, #T_909fd_row9_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_909fd_row0_col9 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_909fd_row0_col10, #T_909fd_row4_col4, #T_909fd_row6_col7, #T_909fd_row8_col6, #T_909fd_row9_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_909fd_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.4%, transparent 49.4%);
# }
# #T_909fd_row1_col5, #T_909fd_row1_col8, #T_909fd_row1_col11 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_909fd_row1_col7, #T_909fd_row4_col3, #T_909fd_row4_col6, #T_909fd_row6_col10, #T_909fd_row8_col4 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_909fd_row1_col9 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_909fd_row1_col10, #T_909fd_row5_col4, #T_909fd_row7_col7, #T_909fd_row8_col3, #T_909fd_row9_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_909fd_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_909fd_row2_col3, #T_909fd_row2_col4, #T_909fd_row2_col6, #T_909fd_row2_col7, #T_909fd_row2_col10, #T_909fd_row3_col3, #T_909fd_row3_col4, #T_909fd_row3_col6, #T_909fd_row3_col7, #T_909fd_row3_col10, #T_909fd_row9_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_909fd_row2_col5, #T_909fd_row2_col8, #T_909fd_row2_col11, #T_909fd_row3_col5, #T_909fd_row3_col8, #T_909fd_row3_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_909fd_row2_col9, #T_909fd_row3_col9 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_909fd_row2_col12, #T_909fd_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.4%, transparent 2.4%);
# }
# #T_909fd_row4_col5, #T_909fd_row4_col8, #T_909fd_row4_col11 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_909fd_row4_col9 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_909fd_row4_col10, #T_909fd_row6_col3, #T_909fd_row6_col6, #T_909fd_row7_col4, #T_909fd_row8_col7 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_909fd_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.1%, transparent 7.1%);
# }
# #T_909fd_row5_col5, #T_909fd_row5_col8, #T_909fd_row5_col11 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_909fd_row5_col9 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_909fd_row5_col10, #T_909fd_row6_col4, #T_909fd_row7_col3, #T_909fd_row7_col6, #T_909fd_row9_col7 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_909fd_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.2%, transparent 15.2%);
# }
# #T_909fd_row6_col5, #T_909fd_row6_col8, #T_909fd_row6_col11 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_909fd_row6_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_909fd_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.4%, transparent 39.4%);
# }
# #T_909fd_row7_col5, #T_909fd_row7_col8, #T_909fd_row7_col11 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_909fd_row7_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_909fd_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.6%, transparent 74.6%);
# }
# #T_909fd_row8_col5, #T_909fd_row9_col8, #T_909fd_row9_col11 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_909fd_row8_col8, #T_909fd_row8_col11, #T_909fd_row9_col5 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_909fd_row8_col9 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_909fd_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.0%, transparent 11.0%);
# }
# #T_909fd_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.1%, transparent 23.1%);
# }
# </style>
# <table id="T_909fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_909fd_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_909fd_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_909fd_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_909fd_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_909fd_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_909fd_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_909fd_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_909fd_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_909fd_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_909fd_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_909fd_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_909fd_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_909fd_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_909fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_909fd_row0_col0" class="data row0 col0" >RandomForestRegressor</td>
#       <td id="T_909fd_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_909fd_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_909fd_row0_col3" class="data row0 col3" >1517</td>
#       <td id="T_909fd_row0_col4" class="data row0 col4" >139</td>
#       <td id="T_909fd_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_909fd_row0_col6" class="data row0 col6" >2504</td>
#       <td id="T_909fd_row0_col7" class="data row0 col7" >467</td>
#       <td id="T_909fd_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_909fd_row0_col9" class="data row0 col9" >0.814</td>
#       <td id="T_909fd_row0_col10" class="data row0 col10" >0.053</td>
#       <td id="T_909fd_row0_col11" class="data row0 col11" >5</td>
#       <td id="T_909fd_row0_col12" class="data row0 col12" >20.1</td>
#     </tr>
#     <tr>
#       <th id="T_909fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_909fd_row1_col0" class="data row1 col0" >RandomForestRegressor</td>
#       <td id="T_909fd_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_909fd_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_909fd_row1_col3" class="data row1 col3" >1518</td>
#       <td id="T_909fd_row1_col4" class="data row1 col4" >139</td>
#       <td id="T_909fd_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_909fd_row1_col6" class="data row1 col6" >2506</td>
#       <td id="T_909fd_row1_col7" class="data row1 col7" >467</td>
#       <td id="T_909fd_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_909fd_row1_col9" class="data row1 col9" >0.813</td>
#       <td id="T_909fd_row1_col10" class="data row1 col10" >0.053</td>
#       <td id="T_909fd_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_909fd_row1_col12" class="data row1 col12" >40.6</td>
#     </tr>
#     <tr>
#       <th id="T_909fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_909fd_row2_col0" class="data row2 col0" >AdaBoostRegressor</td>
#       <td id="T_909fd_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_909fd_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_909fd_row2_col3" class="data row2 col3" >2510</td>
#       <td id="T_909fd_row2_col4" class="data row2 col4" >316</td>
#       <td id="T_909fd_row2_col5" class="data row2 col5" >9</td>
#       <td id="T_909fd_row2_col6" class="data row2 col6" >3366</td>
#       <td id="T_909fd_row2_col7" class="data row2 col7" >660</td>
#       <td id="T_909fd_row2_col8" class="data row2

# %%
n_est_list = [800, 1600]

models_and_params = [
    *[ (RandomForestRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,             {'random_state': RS, 'n_estimators': n_e}) for n_e in  n_est_list],
    *[ (LGBMRegressor,                 {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,                  {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,             {'random_state': RS, 'n_estimators': n_e, 'silent': True, 'allow_writing_files': False}) for n_e in n_est_list ],
]
cv = KFold(8)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score]

_ = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda results_1_run: m.display_stats(results_1_run, reverse_rank_idx=[2])
)
# Out:
# <style type="text/css">
# #T_e8c50_row0_col3, #T_e8c50_row0_col4, #T_e8c50_row0_col6, #T_e8c50_row1_col10 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_e8c50_row0_col5, #T_e8c50_row0_col8, #T_e8c50_row0_col11 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_e8c50_row0_col7, #T_e8c50_row8_col9 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_e8c50_row0_col9, #T_e8c50_row7_col7 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_e8c50_row0_col10, #T_e8c50_row1_col3, #T_e8c50_row5_col6, #T_e8c50_row9_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_e8c50_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.0%, transparent 51.0%);
# }
# #T_e8c50_row1_col4, #T_e8c50_row1_col6, #T_e8c50_row5_col3, #T_e8c50_row8_col10 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_e8c50_row1_col5, #T_e8c50_row5_col8, #T_e8c50_row5_col11 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_e8c50_row1_col7, #T_e8c50_row2_col3, #T_e8c50_row2_col4, #T_e8c50_row2_col6, #T_e8c50_row2_col10, #T_e8c50_row3_col3, #T_e8c50_row3_col4, #T_e8c50_row3_col6, #T_e8c50_row3_col10, #T_e8c50_row9_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e8c50_row1_col8, #T_e8c50_row1_col11, #T_e8c50_row5_col5 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_e8c50_row1_col9, #T_e8c50_row8_col7 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_e8c50_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_e8c50_row2_col5, #T_e8c50_row2_col8, #T_e8c50_row2_col11, #T_e8c50_row3_col5, #T_e8c50_row3_col8, #T_e8c50_row3_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_e8c50_row2_col7, #T_e8c50_row2_col9, #T_e8c50_row3_col7, #T_e8c50_row3_col9 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_e8c50_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.0%, transparent 3.0%);
# }
# #T_e8c50_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.9%, transparent 2.9%);
# }
# #T_e8c50_row4_col3, #T_e8c50_row4_col6, #T_e8c50_row8_col4, #T_e8c50_row9_col10 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_e8c50_row4_col4, #T_e8c50_row5_col10, #T_e8c50_row9_col3, #T_e8c50_row9_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_e8c50_row4_col5, #T_e8c50_row4_col8, #T_e8c50_row4_col11 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_e8c50_row4_col7, #T_e8c50_row6_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e8c50_row4_col9, #T_e8c50_row6_col7 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_e8c50_row4_col10, #T_e8c50_row5_col4, #T_e8c50_row8_col3, #T_e8c50_row8_col6 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_e8c50_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.7%, transparent 5.7%);
# }
# #T_e8c50_row5_col7, #T_e8c50_row7_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_e8c50_row5_col9, #T_e8c50_row9_col7 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_e8c50_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.4%, transparent 11.4%);
# }
# #T_e8c50_row6_col3, #T_e8c50_row6_col6, #T_e8c50_row7_col4, #T_e8c50_row7_col10 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_e8c50_row6_col4, #T_e8c50_row6_col10, #T_e8c50_row7_col3, #T_e8c50_row7_col6 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_e8c50_row6_col5, #T_e8c50_row6_col8, #T_e8c50_row6_col11 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_e8c50_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.8%, transparent 33.8%);
# }
# #T_e8c50_row7_col5, #T_e8c50_row7_col8, #T_e8c50_row7_col11 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_e8c50_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.6%, transparent 70.6%);
# }
# #T_e8c50_row8_col5, #T_e8c50_row8_col8, #T_e8c50_row8_col11 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_e8c50_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.6%, transparent 10.6%);
# }
# #T_e8c50_row9_col5, #T_e8c50_row9_col8, #T_e8c50_row9_col11 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_e8c50_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.9%, transparent 20.9%);
# }
# </style>
# <table id="T_e8c50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8c50_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_e8c50_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_e8c50_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_e8c50_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_e8c50_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_e8c50_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_e8c50_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_e8c50_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_e8c50_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_e8c50_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_e8c50_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_e8c50_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_e8c50_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8c50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8c50_row0_col0" class="data row0 col0" >RandomForestRegressor</td>
#       <td id="T_e8c50_row0_col1" class="data row0 col1" >'n_estimators': 800</td>
#       <td id="T_e8c50_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_e8c50_row0_col3" class="data row0 col3" >1505</td>
#       <td id="T_e8c50_row0_col4" class="data row0 col4" >181</td>
#       <td id="T_e8c50_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_e8c50_row0_col6" class="data row0 col6" >2429</td>
#       <td id="T_e8c50_row0_col7" class="data row0 col7" >672</td>
#       <td id="T_e8c50_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_e8c50_row0_col9" class="data row0 col9" >0.822</td>
#       <td id="T_e8c50_row0_col10" class="data row0 col10" >0.058</td>
#       <td id="T_e8c50_row0_col11" class="data row0 col11" >5</td>
#       <td id="T_e8c50_row0_col12" class="data row0 col12" >33.7</td>
#     </tr>
#     <tr>
#       <th id="T_e8c50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8c50_row1_col0" class="data row1 col0" >RandomForestRegressor</td>
#       <td id="T_e8c50_row1_col1" class="data row1 col1" >'n_estimators': 1600</td>
#       <td id="T_e8c50_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_e8c50_row1_col3" class="data row1 col3" >1505</td>
#       <td id="T_e8c50_row1_col4" class="data row1 col4" >181</td>
#       <td id="T_e8c50_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_e8c50_row1_col6" class="data row1 col6" >2430</td>
#       <td id="T_e8c50_row1_col7" class="data row1 col7" >673</td>
#       <td id="T_e8c50_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_e8c50_row1_col9" class="data row1 col9" >0.822</td>
#       <td id="T_e8c50_row1_col10" class="data row1 col10" >0.058</td>
#       <td id="T_e8c50_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_e8c50_row1_col12" class="data row1 col12" >66.1</td>
#     </tr>
#     <tr>
#       <th id="T_e8c50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8c50_row2_col0" class="data row2 col0" >AdaBoostRegressor</td>
#       <td id="T_e8c50_row2_col1" class="data row2 col1" >'n_estimators': 800</td>
#       <td id="T_e8c50_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_e8c50_row2_col3" class="data row2 col3" >2532</td>
#       <td id="T_e8c50_row2_col4" class="data row2 col4" >308</td>
#       <td id="T_e8c50_row2_col5" class="data row2 col5" >9</td>
#       <td id="T_e8c50_row2_col6" class="data row2 col6" >3500</td>
#       <td id="T_e8c50_row2_c
