# %% [markdown]
# # Setup and Imports

# %%
import sys
if '../Toolkit' not in sys.path: sys.path.append('../Toolkit')

# %load_ext autoreload
# %autoreload 1

# %aimport tools
# %aimport models

import tools as t
import models as m

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython.display import clear_output

import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 113
import matplotlib.pyplot as plt
import seaborn as sns

RS = 35577 # global random state seed
raw_data_path = 'data-raw'
processed_data_path = 'data-processed'

# %%
import time

# %%
df_data = t.from_pkl(f'{processed_data_path}/df_clean.pkl')

df_data.shape
df_data.head(3)
# Out:
# (97053, 8)
#    make model  year  price transmission  mileage fuelType  engineSize
# 0  Audi    A1  2017  12500       Manual    15735   Petrol         1.4
# 1  Audi    A6  2016  16500    Automatic    36203   Diesel         2.0
# 2  Audi    A1  2016  11000       Manual    29946   Petrol         1.4

# %%
df_data.insert(0, 'car', df_data['make'] + '__' + df_data['model'])
df_data = df_data.drop(columns=['make', 'model'])
df_data.groupby(['car']).size().sort_values(ascending=False).head(10)

# %%
df_1_car = df_data.loc[ (df_data['car'] == 'Ford__Fiesta') ].drop(columns=['car']).copy()
df_1_car.head(3)

mileage_5k = ((df_1_car['mileage'] / 5000).round(0) * 5000).astype(int)
df_grp = df_1_car.drop(columns='mileage').groupby(['year', 'transmission', mileage_5k, 'fuelType', 'engineSize'])['price'].agg([len, np.mean, np.std, m.mad])

'mean group size: ', df_grp['len'].mean()
'price mad in 5k groups: ', df_grp['mad'].mean()
'price std in 5k groups: ', df_grp['std'].mean()
# Out:
#        year  price transmission  mileage fuelType  engineSize
# 21449  2017  12000    Automatic    15944   Petrol         1.0
# 21452  2019  17500       Manual    10460   Petrol         1.5
# 21453  2019  16500    Automatic     1482   Petrol         1.0
# ('mean group size: ', 15.711864406779661)
# ('price mad in 5k groups: ', 344.2007726118433)
# ('price std in 5k groups: ', 722.0580288841817)

# %% [markdown]
# # Encode

# %%
m.ordinalEncode(df_1_car, ['transmission', 'fuelType'])
df_1_car.head(3)
# Out:
#        year  price  transmission  mileage  fuelType  engineSize
# 21449  2017  12000             0    15944         1         1.0
# 21452  2019  17500             1    10460         1         1.5
# 21453  2019  16500             0     1482         1         1.0

# %% [markdown]
# ## X, y

# %%
df_train = df_1_car
X, y  = df_train.drop(columns='price').copy(), df_train['price'].copy()

y.shape
X.shape
X.columns
X.head(3)
y.head(3)
# Out:
# (6489,)
# (6489, 5)
# Index(['year', 'transmission', 'mileage', 'fuelType', 'engineSize'], dtype='object')
#        year  transmission  mileage  fuelType  engineSize
# 21449  2017             0    15944         1         1.0
# 21452  2019             1    10460         1         1.5
# 21453  2019             0     1482         1         1.0
# 21449    12000
# 21452    17500
# 21453    16500
# Name: price, dtype: int64

# %% [markdown]
# # Train model

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold, RepeatedKFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.preprocessing import minmax_scale, normalize, scale, PolynomialFeatures

# %%
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %% [markdown]
# ## First Run

# %%
n_est_list = [100, 400]
models_and_params = [
    (DecisionTreeRegressor, {}),
    
    *[ (RandomForestRegressor, {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (AdaBoostRegressor,     {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    
    *[ (LGBMRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedKFold(n_splits=6, n_repeats=1)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score ]

ret = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['R2_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_f1e3f_row0_col3, #T_f1e3f_row0_col6, #T_f1e3f_row0_col10, #T_f1e3f_row1_col4, #T_f1e3f_row3_col7, #T_f1e3f_row10_col9 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_f1e3f_row0_col4, #T_f1e3f_row1_col3, #T_f1e3f_row1_col6, #T_f1e3f_row2_col7, #T_f1e3f_row2_col10, #T_f1e3f_row9_col9 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_f1e3f_row0_col5, #T_f1e3f_row0_col8, #T_f1e3f_row10_col11 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_f1e3f_row0_col7, #T_f1e3f_row1_col10, #T_f1e3f_row2_col3, #T_f1e3f_row2_col4, #T_f1e3f_row2_col6, #T_f1e3f_row8_col9 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_f1e3f_row0_col9, #T_f1e3f_row4_col7, #T_f1e3f_row8_col10, #T_f1e3f_row9_col4, #T_f1e3f_row10_col3, #T_f1e3f_row10_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f1e3f_row0_col11, #T_f1e3f_row10_col5, #T_f1e3f_row10_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f1e3f_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.9%, transparent 64.9%);
# }
# #T_f1e3f_row1_col5, #T_f1e3f_row1_col8, #T_f1e3f_row9_col11 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_f1e3f_row1_col7, #T_f1e3f_row5_col3, #T_f1e3f_row5_col6, #T_f1e3f_row5_col9, #T_f1e3f_row5_col10, #T_f1e3f_row6_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_f1e3f_row1_col9, #T_f1e3f_row8_col7, #T_f1e3f_row9_col3, #T_f1e3f_row9_col6, #T_f1e3f_row9_col10, #T_f1e3f_row10_col4 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_f1e3f_row1_col11, #T_f1e3f_row9_col5, #T_f1e3f_row9_col8 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_f1e3f_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.9%, transparent 16.9%);
# }
# #T_f1e3f_row2_col5, #T_f1e3f_row2_col8, #T_f1e3f_row8_col11 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_f1e3f_row2_col9, #T_f1e3f_row5_col7, #T_f1e3f_row6_col10, #T_f1e3f_row8_col3, #T_f1e3f_row8_col4, #T_f1e3f_row8_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_f1e3f_row2_col11, #T_f1e3f_row8_col5, #T_f1e3f_row8_col8 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_f1e3f_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.4%, transparent 4.4%);
# }
# #T_f1e3f_row3_col3, #T_f1e3f_row3_col4, #T_f1e3f_row3_col6, #T_f1e3f_row3_col10, #T_f1e3f_row7_col9, #T_f1e3f_row10_col7 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_f1e3f_row3_col5, #T_f1e3f_row3_col8, #T_f1e3f_row7_col11 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_f1e3f_row3_col9, #T_f1e3f_row4_col4, #T_f1e3f_row6_col7, #T_f1e3f_row7_col3, #T_f1e3f_row7_col6, #T_f1e3f_row7_col10 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_f1e3f_row3_col11, #T_f1e3f_row7_col5, #T_f1e3f_row7_col8 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_f1e3f_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.8%, transparent 16.8%);
# }
# #T_f1e3f_row4_col3, #T_f1e3f_row4_col6, #T_f1e3f_row4_col10, #T_f1e3f_row5_col4, #T_f1e3f_row6_col9, #T_f1e3f_row9_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_f1e3f_row4_col5, #T_f1e3f_row4_col8, #T_f1e3f_row6_col11 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_f1e3f_row4_col9, #T_f1e3f_row6_col3, #T_f1e3f_row6_col6, #T_f1e3f_row7_col4, #T_f1e3f_row7_col7, #T_f1e3f_row10_col10 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_f1e3f_row4_col11, #T_f1e3f_row6_col5, #T_f1e3f_row6_col8 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_f1e3f_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.0%, transparent 20.0%);
# }
# #T_f1e3f_row5_col5, #T_f1e3f_row5_col8, #T_f1e3f_row5_col11 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_f1e3f_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.8%, transparent 74.8%);
# }
# #T_f1e3f_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_f1e3f_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.1%, transparent 25.1%);
# }
# #T_f1e3f_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_f1e3f_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.7%, transparent 7.7%);
# }
# #T_f1e3f_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.8%, transparent 9.8%);
# }
# </style>
# <table id="T_f1e3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1e3f_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f1e3f_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_f1e3f_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_f1e3f_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_f1e3f_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_f1e3f_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_f1e3f_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_f1e3f_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_f1e3f_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_f1e3f_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_f1e3f_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_f1e3f_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_f1e3f_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1e3f_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_f1e3f_row0_col0" class="data row0 col0" >CatBoostRegressor</td>
#       <td id="T_f1e3f_row0_col1" class="data row0 col1" >'n_estimators': 400</td>
#       <td id="T_f1e3f_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_f1e3f_row0_col3" class="data row0 col3" >730.929</td>
#       <td id="T_f1e3f_row0_col4" class="data row0 col4" >13.654</td>
#       <td id="T_f1e3f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_f1e3f_row0_col6" class="data row0 col6" >979.683</td>
#       <td id="T_f1e3f_row0_col7" class="data row0 col7" >21.595</td>
#       <td id="T_f1e3f_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_f1e3f_row0_col9" class="data row0 col9" >0.885</td>
#       <td id="T_f1e3f_row0_col10" class="data row0 col10" >0.001</td>
#       <td id="T_f1e3f_row0_col11" class="data row0 col11" >11</td>
#       <td id="T_f1e3f_row0_col12" class="data row0 col12" >9.5</td>
#     </tr>
#     <tr>
#       <th id="T_f1e3f_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_f1e3f_row1_col0" class="data row1 col0" >CatBoostRegressor</td>
#       <td id="T_f1e3f_row1_col1" class="data row1 col1" >'n_estimators': 100</td>
#       <td id="T_f1e3f_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_f1e3f_row1_col3" class="data row1 col3" >732.701</td>
#       <td id="T_f1e3f_row1_col4" class="data row1 col4" >12.989</td>
#       <td id="T_f1e3f_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_f1e3f_row1_col6" class="data row1 col6" >980.766</td>
#       <td id="T_f1e3f_row1_col7" class="data row1 col7" >23.179</td>
#       <td id="T_f1e3f_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_f1e3f_row1_col9" class="data row1 col9" >0.885</td>
#       <td id="T_f1e3f_row1_col10" class="data row1 col10" >0.002</td>
#       <td id="T_f1e3f_row1_col11" class="data row1 col11" >10</td>
#       <td id="T_f1e3f_row1_col12" class="data row1 col12" >2.5</td>
#     </tr>
#     <tr>
#       <th id="T_f1e3f_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_f1e3f_row2_col0" class="data row2 col0" >LGBMRegressor</td>
#       <td id="T_f1e3f_row2_col1" class="data row2 col1" >'n_estimators': 100</td>
#       <td id="T_f1e3f_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_f1e3f_row2_col3" class="data row2 col3" >742.663</td>
#       <td id="T_f1e3f_row2_col4" class="data row2 col4" >14.525</td>
#       <td id="T_f1e3f_row2_col5" class="

# %% [markdown]
# ## Best 3 models

# %%
trained_models = []
n_est_list = [400, 800, 1200]
models_and_params = [
    *[ (LGBMRegressor,         {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (XGBRegressor,          {'random_state': RS, 'n_estimators': n_e}) for n_e in n_est_list ],
    *[ (CatBoostRegressor,     {'random_state': RS, 'n_estimators': n_e, 'silent': True}) for n_e in n_est_list ],
]
cv = RepeatedKFold(n_splits=6, n_repeats=5)
metrics = [ mean_absolute_error, m.root_mean_squared_error, r2_score ]

ret = t.grid_exec(
    lambda model: m.cv_regression(model, cv, X, y, metrics, trained_models), 
    models_and_params, 
    on1Completed = lambda r: m.display_stats(pd.DataFrame(r).sort_values(by=['R2_mean'], ascending=False))
)
# Out:
# <style type="text/css">
# #T_a459b_row0_col3, #T_a459b_row0_col4, #T_a459b_row0_col6, #T_a459b_row0_col10, #T_a459b_row5_col7, #T_a459b_row8_col9 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_a459b_row0_col5, #T_a459b_row0_col8, #T_a459b_row8_col11 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_a459b_row0_col7, #T_a459b_row1_col4, #T_a459b_row2_col3, #T_a459b_row2_col6, #T_a459b_row2_col10, #T_a459b_row6_col9 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_a459b_row0_col9, #T_a459b_row8_col3, #T_a459b_row8_col4, #T_a459b_row8_col6, #T_a459b_row8_col7, #T_a459b_row8_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a459b_row0_col11, #T_a459b_row8_col5, #T_a459b_row8_col8 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a459b_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.6%, transparent 30.6%);
# }
# #T_a459b_row1_col3, #T_a459b_row1_col6, #T_a459b_row2_col4, #T_a459b_row3_col10, #T_a459b_row4_col7, #T_a459b_row7_col9 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_a459b_row1_col5, #T_a459b_row1_col8, #T_a459b_row7_col11 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_a459b_row1_col7, #T_a459b_row3_col9, #T_a459b_row5_col3, #T_a459b_row5_col4, #T_a459b_row5_col6, #T_a459b_row5_col10 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_a459b_row1_col9, #T_a459b_row7_col3, #T_a459b_row7_col4, #T_a459b_row7_col6, #T_a459b_row7_col7, #T_a459b_row7_col10 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_a459b_row1_col10, #T_a459b_row2_col7, #T_a459b_row4_col3, #T_a459b_row4_col4, #T_a459b_row4_col6, #T_a459b_row4_col9 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_a459b_row1_col11, #T_a459b_row7_col5, #T_a459b_row7_col8 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_a459b_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.0%, transparent 67.0%);
# }
# #T_a459b_row2_col5, #T_a459b_row2_col8, #T_a459b_row6_col11 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_a459b_row2_col9, #T_a459b_row6_col3, #T_a459b_row6_col4, #T_a459b_row6_col6, #T_a459b_row6_col7, #T_a459b_row6_col10 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_a459b_row2_col11, #T_a459b_row6_col5, #T_a459b_row6_col8 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_a459b_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.2%, transparent 98.2%);
# }
# #T_a459b_row3_col3, #T_a459b_row3_col4, #T_a459b_row3_col6, #T_a459b_row3_col7, #T_a459b_row4_col10, #T_a459b_row5_col9 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_a459b_row3_col5, #T_a459b_row3_col8, #T_a459b_row5_col11 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_a459b_row3_col11, #T_a459b_row5_col5, #T_a459b_row5_col8 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_a459b_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.4%, transparent 5.4%);
# }
# #T_a459b_row4_col5, #T_a459b_row4_col8, #T_a459b_row4_col11 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_a459b_row4_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.2%, transparent 12.2%);
# }
# #T_a459b_row5_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_a459b_row6_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.8%, transparent 33.8%);
# }
# #T_a459b_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.3%, transparent 71.3%);
# }
# #T_a459b_row8_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_a459b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a459b_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_a459b_level0_col1" class="col_heading level0 col1" >params</th>
#       <th id="T_a459b_level0_col2" class="col_heading level0 col2" >n_folds</th>
#       <th id="T_a459b_level0_col3" class="col_heading level0 col3" >MAE_mean</th>
#       <th id="T_a459b_level0_col4" class="col_heading level0 col4" >MAE_std</th>
#       <th id="T_a459b_level0_col5" class="col_heading level0 col5" >#1</th>
#       <th id="T_a459b_level0_col6" class="col_heading level0 col6" >RMSE_mean</th>
#       <th id="T_a459b_level0_col7" class="col_heading level0 col7" >RMSE_std</th>
#       <th id="T_a459b_level0_col8" class="col_heading level0 col8" >#2</th>
#       <th id="T_a459b_level0_col9" class="col_heading level0 col9" >R2_mean</th>
#       <th id="T_a459b_level0_col10" class="col_heading level0 col10" >R2_std</th>
#       <th id="T_a459b_level0_col11" class="col_heading level0 col11" >#3</th>
#       <th id="T_a459b_level0_col12" class="col_heading level0 col12" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a459b_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_a459b_row0_col0" class="data row0 col0" >CatBoostRegressor</td>
#       <td id="T_a459b_row0_col1" class="data row0 col1" >'n_estimators': 400</td>
#       <td id="T_a459b_row0_col2" class="data row0 col2" >30</td>
#       <td id="T_a459b_row0_col3" class="data row0 col3" >728.937</td>
#       <td id="T_a459b_row0_col4" class="data row0 col4" >16.576</td>
#       <td id="T_a459b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_a459b_row0_col6" class="data row0 col6" >978.806</td>
#       <td id="T_a459b_row0_col7" class="data row0 col7" >24.285</td>
#       <td id="T_a459b_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_a459b_row0_col9" class="data row0 col9" >0.885</td>
#       <td id="T_a459b_row0_col10" class="data row0 col10" >0.003</td>
#       <td id="T_a459b_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_a459b_row0_col12" class="data row0 col12" >55.7</td>
#     </tr>
#     <tr>
#       <th id="T_a459b_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_a459b_row1_col0" class="data row1 col0" >CatBoostRegressor</td>
#       <td id="T_a459b_row1_col1" class="data row1 col1" >'n_estimators': 800</td>
#       <td id="T_a459b_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_a459b_row1_col3" class="data row1 col3" >729.828</td>
#       <td id="T_a459b_row1_col4" class="data row1 col4" >17.167</td>
#       <td id="T_a459b_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_a459b_row1_col6" class="data row1 col6" >980.374</td>
#       <td id="T_a459b_row1_col7" class="data row1 col7" >24.745</td>
#       <td id="T_a459b_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_a459b_row1_col9" class="data row1 col9" >0.885</td>
#       <td id="T_a459b_row1_col10" class="data row1 col10" >0.003</td>
#       <td id="T_a459b_row1_col11" class="data row1 col11" >8</td>
#       <td id="T_a459b_row1_col12" class="data row1 col12" >121.9</td>
#     </tr>
#     <tr>
#       <th id="T_a459b_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_a459b_row2_col0" class="data row2 col0" >CatBoostRegressor</td>
#       <td id="T_a459b_row2_col1" class="data row2 col1" >'n_estimators': 1200</td>
#       <td id="T_a459b_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_a459b_row2_col3" class="data row2 col3" >730.126</td>
#       <td id="T_a459b_row2_col4" class="data row2 col4" >16.743</td>
#       <td id="T_a459b_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_a459b_row2_col6" class="data row2 col6" >981.005</td>
#       <td id="T_a459b_row2_col7" class="data row2 col7" >24.697</td>
#       <td id="T_a459b_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_a459b_row2_col9" class="data row2 col9" >0.884</td>
#       <td id="T_a459b_row2_col10" class="data row2 col10" >0.003</td>
#       <td id="T_a459b_row2_col11" class="data row2 col11" >7</td>
#       <td id="T_a459b_row2_col12" class="data row2 col12" >178.5</td>
#     </tr>
#     <tr>
#       <th id="T_a459b_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_a459b_row3_col0" class="data row3 col0" >LGBMRegressor</td>
#       <td id="T_a459b_row3_col1" class="data row3 col1" >'n_estimators': 400</td>
#       <td id="T_a459b_row3_co

# %%
m.get_fe_df(trained_models)
# Out:
# <style type="text/css">
# #T_0936e_row0_col0, #T_0936e_row0_col1, #T_0936e_row0_col2, #T_0936e_row1_col3, #T_0936e_row1_col4, #T_0936e_row1_col5, #T_0936e_row1_col6, #T_0936e_row1_col7, #T_0936e_row1_col8 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_0936e_row0_col3, #T_0936e_row0_col4, #T_0936e_row0_col5, #T_0936e_row0_col6, #T_0936e_row0_col7, #T_0936e_row0_col8, #T_0936e_row0_col9, #T_0936e_row2_col0, #T_0936e_row2_col1, #T_0936e_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_0936e_row1_col0, #T_0936e_row1_col1, #T_0936e_row1_col2, #T_0936e_row2_col6, #T_0936e_row2_col7, #T_0936e_row2_col8, #T_0936e_row3_col3, #T_0936e_row3_col4, #T_0936e_row3_col5 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_0936e_row1_col9 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_0936e_row2_col3, #T_0936e_row2_col4, #T_0936e_row2_col5, #T_0936e_row3_col0, #T_0936e_row3_col1, #T_0936e_row3_col2, #T_0936e_row4_col6, #T_0936e_row4_col7, #T_0936e_row4_col8 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_0936e_row2_col9 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_0936e_row3_col6, #T_0936e_row3_col7, #T_0936e_row3_col8, #T_0936e_row4_col0, #T_0936e_row4_col1, #T_0936e_row4_col2, #T_0936e_row4_col3, #T_0936e_row4_col4, #T_0936e_row4_col5 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_0936e_row3_col9 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_0936e_row4_col9 {
#   background-color: #fda159;
#   color: #000000;
# }
# </style>
# <table id="T_0936e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0936e_level0_col0" class="col_heading level0 col0" >LGBMR_0_rank</th>
#       <th id="T_0936e_level0_col1" class="col_heading level0 col1" >LGBMR_1_rank</th>
#       <th id="T_0936e_level0_col2" class="col_heading level0 col2" >LGBMR_2_rank</th>
#       <th id="T_0936e_level0_col3" class="col_heading level0 col3" >XGBR_3_rank</th>
#       <th id="T_0936e_level0_col4" class="col_heading level0 col4" >XGBR_4_rank</th>
#       <th id="T_0936e_level0_col5" class="col_heading level0 col5" >XGBR_5_rank</th>
#       <th id="T_0936e_level0_col6" class="col_heading level0 col6" >CBR_6_rank</th>
#       <th id="T_0936e_level0_col7" class="col_heading level0 col7" >CBR_7_rank</th>
#       <th id="T_0936e_level0_col8" class="col_heading level0 col8" >CBR_8_rank</th>
#       <th id="T_0936e_level0_col9" class="col_heading level0 col9" >sum_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0936e_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_0936e_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_0936e_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_0936e_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_0936e_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_0936e_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_0936e_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_0936e_row0_col6" class="data row0 col6" >5</td>
#       <td id="T_0936e_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_0936e_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_0936e_row0_col9" class="data row0 col9" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0936e_level0_row1" class="row_heading level0 row1" >engineSize</th>
#       <td id="T_0936e_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_0936e_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_0936e_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_0936e_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_0936e_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_0936e_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_0936e_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_0936e_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_0936e_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_0936e_row1_col9" class="data row1 col9" >33</td>
#     </tr>
#     <tr>
#       <th id="T_0936e_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_0936e_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_0936e_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_0936e_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_0936e_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_0936e_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_0936e_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_0936e_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_0936e_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_0936e_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_0936e_row2_col9" class="data row2 col9" >27</td>
#     </tr>
#     <tr>
#       <th id="T_0936e_level0_row3" class="row_heading level0 row3" >fuelType</th>
#       <td id="T_0936e_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_0936e_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_0936e_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_0936e_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_0936e_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_0936e_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_0936e_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_0936e_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_0936e_row3_col8" class="data row3 col8" >2</td>
#       <td id="T_0936e_row3_col9" class="data row3 col9" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0936e_level0_row4" class="row_heading level0 row4" >transmission</th>
#       <td id="T_0936e_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_0936e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_0936e_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_0936e_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_0936e_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_0936e_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_0936e_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_0936e_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_0936e_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_0936e_row4_col9" class="data row4 col9" >15</td>
#     </tr>
#   </tbody>
# </table>
